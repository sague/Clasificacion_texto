# %%
from math import log
from numpy import argmax, log, exp
import os
from random import shuffle

# %%
def elimina_simbolos(palabra):
    palabra = "".join(k for k in palabra if k.isalpha())
    return palabra.lower()

def obtener_frecuencias(archivo, clase, clases, frecuencias= dict(), frecuencias_clases= dict()):
    print("abriendo archivos ", archivo)
    f=open(archivo)
    print("cargando texto")
    libro=f.read()
    print("generando lista palabras")
    palabras = libro.split() # este paso puede ser caro en archivos grandes

    for i in palabras:
        i = "".join(k for k in i if k.isalpha())
        i = i.lower()
        try:
            frecuencias[i][clase] += 1 
        except:
            frecuencias[i] = dict((c, 0) for c in clases)
            frecuencias[i][clase] += 1 
            
        try:
            frecuencias_clases[clase] += 1
        except:
            frecuencias_clases[clase] = 1

    return frecuencias, frecuencias_clases

# %%
range(10)[5:]
# Out:
# range(5, 10)

# %%
clases = ["scifi", "love", "math", "biology", "astronomy", "cook"]


todos_los_libros = dict( (c, []) for c in clases )
libros_train = dict( (c, []) for c in clases )
libros_test = dict( (c, []) for c in clases )

for clase in clases:
    i = 1
    while True:
        archivo_txt = "books/"+clase+str(i)+".txt"
        #
        
        if not os.path.exists(archivo_txt):
            break
        
        todos_los_libros[clase].append(archivo_txt)
        i += 1
    
    idx = list(range(1, 1+len(todos_los_libros[clase])))
    shuffle(idx)
    n = int(len(idx)*0.8)
    libros_train[clase] = idx[:n]
    libros_test[clase] = idx[n:]

# %%
todos_los_libros
# Out:
# {'astronomy': ['books/astronomy1.txt',
#   'books/astronomy2.txt',
#   'books/astronomy3.txt',
#   'books/astronomy4.txt',
#   'books/astronomy5.txt',
#   'books/astronomy6.txt',
#   'books/astronomy7.txt',
#   'books/astronomy8.txt',
#   'books/astronomy9.txt',
#   'books/astronomy10.txt',
#   'books/astronomy11.txt',
#   'books/astronomy12.txt',
#   'books/astronomy13.txt',
#   'books/astronomy14.txt',
#   'books/astronomy15.txt',
#   'books/astronomy16.txt'],
#  'biology': ['books/biology1.txt',
#   'books/biology2.txt',
#   'books/biology3.txt',
#   'books/biology4.txt',
#   'books/biology5.txt',
#   'books/biology6.txt',
#   'books/biology7.txt',
#   'books/biology8.txt',
#   'books/biology9.txt',
#   'books/biology10.txt',
#   'books/biology11.txt',
#   'books/biology12.txt',
#   'books/biology13.txt',
#   'books/biology14.txt',
#   'books/biology15.txt',
#   'books/biology16.txt'],
#  'cook': ['books/cook1.txt',
#   'books/cook2.txt',
#   'books/cook3.txt',
#   'books/cook4.txt',
#   'books/cook5.txt',
#   'books/cook6.txt',
#   'books/cook7.txt',
#   'books/cook8.txt',
#   'books/cook9.txt',
#   'books/cook10.txt',
#   'books/cook11.txt',
#   'books/cook12.txt',
#   'books/cook13.txt',
#   'books/cook14.txt',
#   'books/cook15.txt',
#   'books/cook16.txt'],
#  'love': ['books/love1.txt',
#   'books/love2.txt',
#   'books/love3.txt',
#   'books/love4.txt',
#   'books/love5.txt',
#   'books/love6.txt',
#   'books/love7.txt',
#   'books/love8.txt'],
#  'math': ['books/math1.txt',
#   'books/math2.txt',
#   'books/math3.txt',
#   'books/math4.txt',
#   'books/math5.txt',
#   'books/math6.txt',
#   'books/math7.txt',
#   'books/math8.txt',
#   'books/math9.txt',
#   'books/math10.txt'],
#  'scifi': ['books/scifi1.txt',
#   'books/scifi2.txt',
#   'books/scifi3.txt',
#   'books/scifi4.txt',
#   'books/scifi5.txt',
#   'books/scifi6.txt',
#   'books/scifi7.txt',
#   'books/scifi8.txt',
#   'books/scifi9.txt',
#   'books/scifi10.txt',
#   'books/scifi11.txt',
#   'books/scifi12.txt',
#   'books/scifi13.txt',
#   'books/scifi14.txt',
#   'books/scifi15.txt']}

# %%
libros_test
# Out:
# {'astronomy': [15, 1, 4, 3],
#  'biology': [16, 2, 3, 9],
#  'cook': [14, 1, 15, 13],
#  'love': [4, 7],
#  'math': [1, 10],
#  'scifi': [11, 3, 13]}

# %%
libros_train
# Out:
# {'astronomy': [6, 8, 13, 2, 5, 14, 16, 10, 12, 7, 9, 11],
#  'biology': [8, 4, 13, 10, 6, 12, 11, 14, 1, 7, 15, 5],
#  'cook': [11, 3, 4, 2, 16, 6, 7, 9, 5, 10, 8, 12],
#  'love': [1, 5, 2, 3, 6, 8],
#  'math': [6, 4, 3, 8, 7, 5, 9, 2],
#  'scifi': [9, 7, 5, 12, 10, 6, 2, 8, 14, 15, 4, 1]}

# %%
frecuencias = dict()
frecuencias_clases = dict()

for clase in clases:
    for i in libros_train[clase]:
        archivo_txt = todos_los_libros[clase][i-1]
        print(archivo_txt)
        frecuencias, frecuencias_clases = obtener_frecuencias(archivo_txt, clase,clases, frecuencias, frecuencias_clases)
# Out:
# books/scifi9.txt
# abriendo archivos  books/scifi9.txt
# cargando texto
# generando lista palabras
# books/scifi7.txt
# abriendo archivos  books/scifi7.txt
# cargando texto
# generando lista palabras
# books/scifi5.txt
# abriendo archivos  books/scifi5.txt
# cargando texto
# generando lista palabras
# books/scifi12.txt
# abriendo archivos  books/scifi12.txt
# cargando texto
# generando lista palabras
# books/scifi10.txt
# abriendo archivos  books/scifi10.txt
# cargando texto
# generando lista palabras
# books/scifi6.txt
# abriendo archivos  books/scifi6.txt
# cargando texto
# generando lista palabras
# books/scifi2.txt
# abriendo archivos  books/scifi2.txt
# cargando texto
# generando lista palabras
# books/scifi8.txt
# abriendo archivos  books/scifi8.txt
# cargando texto
# generando lista palabras
# books/scifi14.txt
# abriendo archivos  books/scifi14.txt
# cargando texto
# generando lista palabras
# books/scifi15.txt
# abriendo archivos  books/scifi15.txt
# cargando texto
# generando lista palabras
# books/scifi4.txt
# abriendo archivos  books/scifi4.txt
# cargando texto
# generando lista palabras
# books/scifi1.txt
# abriendo archivos  books/scifi1.txt
# cargando texto
# generando lista palabras
# books/love1.txt
# abriendo archivos  books/love1.txt
# cargando texto
# generando lista palabras
# books/love5.txt
# abriendo archivos  books/love5.txt
# cargando texto
# generando lista palabras
# books/love2.txt
# abriendo archivos  books/love2.txt
# cargando texto
# generando lista palabras
# books/love3.txt
# abriendo archivos  books/love3.txt
# cargando texto
# generando lista palabras
# books/love6.txt
# abriendo archivos  books/love6.txt
# cargando texto
# generando lista palabras
# books/love8.txt
# abriendo archivos  books/love8.txt
# cargando texto
# generando lista palabras
# books/math6.txt
# abriendo archivos  books/math6.txt
# cargando texto
# generando lista palabras
# books/math4.txt
# abriendo archivos  books/math4.txt
# cargando texto
# generando lista palabras
# books/math3.txt
# abriendo archivos  books/math3.txt
# cargando texto
# generando lista palabras
# books/math8.txt
# abriendo archivos  books/math8.txt
# cargando texto
# generando lista palabras
# books/math7.txt
# abriendo archivos  books/math7.txt
# cargando texto
# generando lista palabras
# books/math5.txt
# abriendo archivos  books/math5.txt
# cargando texto
# generando lista palabras
# books/math9.txt
# abriendo archivos  books/math9.txt
# cargando texto
# generando lista palabras
# books/math2.txt
# abriendo archivos  books/math2.txt
# cargando texto
# generando lista palabras
# books/biology8.txt
# abriendo archivos  books/biology8.txt
# cargando texto
# generando lista palabras
# books/biology4.txt
# abriendo archivos  books/biology4.txt
# cargando texto
# generando lista palabras
# books/biology13.txt
# abriendo archivos  books/biology13.txt
# cargando texto
# generando lista palabras
# books/biology10.txt
# abriendo archivos  books/biology10.txt
# cargando texto
# generando lista palabras
# books/biology6.txt
# abriendo archivos  books/biology6.txt
# cargando texto
# generando lista palabras
# books/biology12.txt
# abriendo archivos  books/biology12.txt
# cargando texto
# generando lista palabras
# books/biology11.txt
# abriendo archivos  books/biology11.txt
# cargando texto
# generando lista palabras
# books/biology14.txt
# abriendo archivos  books/biology14.txt
# cargando texto
# generando lista palabras
# books/biology1.txt
# abriendo archivos  books/biology1.txt
# cargando texto
# generando lista palabras
# books/biology7.txt
# abriendo archivos  books/biology7.txt
# cargando texto
# generando lista palabras
# books/biology15.txt
# abriendo archivos  books/biology15.txt
# cargando texto
# generando lista palabras
# books/biology5.txt
# abriendo archivos  books/biology5.txt
# cargando texto
# generando lista palabras
# books/astronomy6.txt
# abriendo archivos  books/astronomy6.txt
# cargando texto
# generando lista palabras
# books/astronomy8.txt
# abriendo archivos  books/astronomy8.txt
# cargando texto
# generando lista palabras
# books/astronomy13.txt
# abriendo archivos  books/astronomy13.txt
# cargando texto
# generando lista palabras
# books/astronomy2.txt
# abriendo archivos  books/astronomy2.txt
# cargando texto
# generando lista palabras
# books/astronomy5.txt
# abriendo archivos  books/astronomy5.txt
# cargando texto
# generando lista palabras
# books/astronomy14.txt
# abriendo archivos  books/astronomy14.txt
# cargando texto
# generando lista palabras
# books/astronomy16.txt
# abriendo archivos  books/astronomy16.txt
# cargando texto
# generando lista palabras
# books/astronomy10.txt
# abriendo archivos  books/astronomy10.txt
# cargando texto
# generando lista palabras
# books/astronomy12.txt
# abriendo archivos  books/astronomy12.txt
# cargando texto
# generando lista palabras
# books/astronomy7.txt
# abriendo archivos  books/astronomy7.txt
# cargando texto
# generando lista palabras
# books/astronomy9.txt
# abriendo archivos  books/astronomy9.txt
# cargando texto
# generando lista palabras
# books/astronomy11.txt
# abriendo archivos  books/astronomy11.txt
# cargando texto
# generando lista palabras
# books/cook11.txt
# abriendo archivos  books/cook11.txt
# cargando texto
# generando lista palabras
# books/cook3.txt
# abriendo archivos  books/cook3.txt
# cargando texto
# generando lista palabras
# books/cook4.txt
# abriendo archivos  books/cook4.txt
# cargando texto
# generando lista palabras
# books/cook2.txt
# abriendo archivos  books/cook2.txt
# cargando texto
# generando lista palabras
# books/cook16.txt
# abriendo archivos  books/cook16.txt
# cargando texto
# generando lista palabras
# books/cook6.txt
# abriendo archivos  books/cook6.txt
# cargando texto
# generando lista palabras
# books/cook7.txt
# abriendo archivos  books/cook7.txt
# cargando texto
# generando lista palabras
# books/cook9.txt
# abriendo archivos  books/cook9.txt
# cargando texto
# generando lista palabras
# books/cook5.txt
# abriendo archivos  books/cook5.txt
# cargando texto
# generando lista palabras
# books/cook10.txt
# abriendo archivos  books/cook10.txt
# cargando texto
# generando lista palabras
# books/cook8.txt
# abriendo archivos  books/cook8.txt
# cargando texto
# generando lista palabras
# books/cook12.txt
# abriendo archivos  books/cook12.txt
# cargando texto
# generando lista palabras

# %%
libros_train
# Out:
# {'astronomy': [6, 8, 13, 2, 5, 14, 16, 10, 12, 7, 9, 11],
#  'biology': [8, 4, 13, 10, 6, 12, 11, 14, 1, 7, 15, 5],
#  'cook': [11, 3, 4, 2, 16, 6, 7, 9, 5, 10, 8, 12],
#  'love': [1, 5, 2, 3, 6, 8],
#  'math': [6, 4, 3, 8, 7, 5, 9, 2],
#  'scifi': [9, 7, 5, 12, 10, 6, 2, 8, 14, 15, 4, 1]}

# %%
def probabilidad(palabra, clase, frecuencias, frecuencas_clases):
    try:
        a = frecuencias[palabra][clase]
    except:
        a = 0
    b = frecuencias_clases[clase] # frecuencias de la clase
    return a/b

# %%
def clasifica(libro, frecuencias, frecuencias_clases, clases):

    verosimilutudes = []

    for clase in clases:
        log_verosimilitud = 0.0

        for palabra in libro:
            palabra = elimina_simbolos(palabra)
            log_verosimilitud += log(probabilidad(palabra, clase, frecuencias, frecuencias_clases)) #* 1 / len(clases)

        verosimilutudes.append(log_verosimilitud)

    return clases[argmax(verosimilutudes)], (verosimilutudes)

# %% [markdown]
# ## Clasificación de una frase o palabra
#
# Al entrenar nuestro algoritmo se realiza una prueba con una palabra o frase.

# %%
clasifica_pred = "positive definite matrices are stated and proved".split()
clase_pred = clasifica(clasifica_pred, frecuencias, frecuencias_clases, clases)
# Out:
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:10: RuntimeWarning: divide by zero encountered in log
#   # Remove the CWD from sys.path while we load stuff.

# %%
clasifica_pred
# Out:
# ['positive', 'definite', 'matrices', 'are', 'stated', 'and', 'proved']

# %%
frecuencias
# Out:
# {'the': {'astronomy': 81220,
#   'biology': 103577,
#   'cook': 30271,
#   'love': 22577,
#   'math': 48700,
#   'scifi': 66478},
#  'project': {'astronomy': 1059,
#   'biology': 1073,
#   'cook': 1053,
#   'love': 531,
#   'math': 9,
#   'scifi': 1085},
#  'gutenberg': {'astronomy': 357,
#   'biology': 356,
#   'cook': 362,
#   'love': 179,
#   'math': 0,
#   'scifi': 363},
#  'ebook': {'astronomy': 134,
#   'biology': 125,
#   'cook': 143,
#   'love': 66,
#   'math': 0,
#   'scifi': 138},
#  'of': {'astronomy': 50859,
#   'biology': 62968,
#   'cook': 21479,
#   'love': 17480,
#   'math': 28987,
#   'scifi': 36033},
#  'time': {'astronomy': 1842,
#   'biology': 1288,
#   'cook': 476,
#   'love': 973,
#   'math': 262,
#   'scifi': 1810},
#  'machine': {'astronomy': 70,
#   'biology': 23,
#   'cook': 103,
#   'love': 10,
#   'math': 3,
#   'scifi': 200},
#  'by': {'astronomy': 8061,
#   'biology': 9696,
#   'cook': 2387,
#   'love': 2854,
#   'math': 6638,
#   'scifi': 4744},
#  'h': {'astronomy': 242,
#   'biology': 137,
#   'cook': 212,
#   'love': 1,
#   'math': 1532,
#   'scifi': 23},
#  'g': {'astronomy': 220,
#   'biology': 188,
#   'cook': 63,
#   'love': 1,
#   'math': 719,
#   'scifi': 44},
#  'wells': {'astronomy': 5,
#   'biology': 11,
#   'cook': 2,
#   'love': 9,
#   'math': 0,
#   'scifi': 18},
#  'this': {'astronomy': 6243,
#   'biology': 7013,
#   'cook': 2820,
#   'love': 2304,
#   'math': 2979,
#   'scifi': 4932},
#  'is': {'astronomy': 11876,
#   'biology': 14344,
#   'cook': 6112,
#   'love': 4009,
#   'math': 10589,
#   'scifi': 5942},
#  'for': {'astronomy': 5793,
#   'biology': 7278,
#   'cook': 3854,
#   'love': 5227,
#   'math': 3738,
#   'scifi': 6203},
#  'use': {'astronomy': 609,
#   'biology': 614,
#   'cook': 710,
#   'love': 191,
#   'math': 281,
#   'scifi': 311},
#  'anyone': {'astronomy': 73,
#   'biology': 65,
#   'cook': 75,
#   'love': 63,
#   'math': 0,
#   'scifi': 85},
#  'anywhere': {'astronomy': 38,
#   'biology': 42,
#   'cook': 26,
#   'love': 42,
#   'math': 8,
#   'scifi': 42},
#  'at': {'astronomy': 5244,
#   'biology': 5431,
#   'cook': 2678,
#   'love': 3856,
#   'math': 1741,
#   'scifi': 5511},
#  'no': {'astronomy': 1801,
#   'biology': 2741,
#   'cook': 1365,
#   'love': 2361,
#   'math': 453,
#   'scifi': 2453},
#  'cost': {'astronomy': 112,
#   'biology': 58,
#   'cook': 49,
#   'love': 32,
#   'math': 129,
#   'scifi': 66},
#  'and': {'astronomy': 27092,
#   'biology': 35479,
#   'cook': 22721,
#   'love': 17822,
#   'math': 12965,
#   'scifi': 26878},
#  'with': {'astronomy': 6575,
#   'biology': 10718,
#   'cook': 8835,
#   'love': 4995,
#   'math': 1996,
#   'scifi': 7438},
#  'almost': {'astronomy': 441,
#   'biology': 869,
#   'cook': 275,
#   'love': 351,
#   'math': 5,
#   'scifi': 398},
#  'restrictions': {'astronomy': 27,
#   'biology': 25,
#   'cook': 24,
#   'love': 16,
#   'math': 1,
#   'scifi': 30},
#  'whatsoever': {'astronomy': 26,
#   'biology': 25,
#   'cook': 25,
#   'love': 12,
#   'math': 0,
#   'scifi': 30},
#  'you': {'astronomy': 1285,
#   'biology': 1230,
#   'cook': 1435,
#   'love': 6653,
#   'math': 91,
#   'scifi': 4584},
#  'may': {'astronomy': 2177,
#   'biology': 2890,
#   'cook': 1110,
#   'love': 858,
#   'math': 2147,
#   'scifi': 1122},
#  'copy': {'astronomy': 275,
#   'biology': 152,
#   'cook': 146,
#   'love': 80,
#   'math': 4,
#   'scifi': 150},
#  'it': {'astronomy': 9860,
#   'biology': 9465,
#   'cook': 6262,
#   'love': 7702,
#   'math': 3096,
#   'scifi': 8891},
#  'give': {'astronomy': 287,
#   'biology': 441,
#   'cook': 167,
#   'love': 555,
#   'math': 381,
#   'scifi': 399},
#  'away': {'astronomy': 354,
#   'biology': 445,
#   'cook': 173,
#   'love': 531,
#   'math': 40,
#   'scifi': 539},
#  'or': {'astronomy': 4946,
#   'biology': 9781,
#   'cook': 8805,
#   'love': 2136,
#   'math': 2818,
#   'scifi': 3503},
#  'reuse': {'astronomy': 24,
#   'biology': 24,
#   'cook': 24,
#   'love': 12,
#   'math': 0,
#   'scifi': 24},
#  'under': {'astronomy': 542,
#   'biology': 1163,
#   'cook': 401,
#   'love': 289,
#   'math': 236,
#   'scifi': 714},
#  'terms': {'astronomy': 294,
#   'biology': 375,
#   'cook': 263,
#   'love': 196,
#   'math': 1167,
#   'scifi': 336},
#  'license': {'astronomy': 180,
#   'biology': 183,
#   'cook': 180,
#   'love': 94,
#   'math': 0,
#   'scifi': 184},
#  'included': {'astronomy': 104,
#   'biology': 117,
#   'cook': 57,
#   'love': 35,
#   'math': 34,
#   'scifi': 44},
#  'online': {'astronomy': 68,
#   'biology': 62,
#   'cook': 68,
#   'love': 24,
#   'math': 0,
#   'scifi': 54},
#  'wwwgutenbergnet': {'astronomy': 3,
#   'biology': 0,
#   'cook': 9,
#   'love': 6,
#   'math': 0,
#   'scifi': 13},
#  'title': {'astronomy': 141,
#   'biology': 35,
#   'cook': 15,
#   'love': 12,
#   'math': 2,
#   'scifi': 41},
#  'author': {'astronomy': 232,
#   'biology': 107,
#   'cook': 57,
#   'love': 10,
#   'math': 45,
#   'scifi': 34},
#  'release': {'astronomy': 15,
#   'biology': 18,
#   'cook': 14,
#   'love': 14,
#   'math': 0,
#   'scifi': 31},
#  'date': {'astronomy': 341,
#   'biology': 168,
#   'cook': 74,
#   'love': 31,
#   'math': 9,
#   'scifi': 58},
#  'october': {'astronomy': 65,
#   'biology': 32,
#   'cook': 205,
#   'love': 7,
#   'math': 1,
#   'scifi': 33},
#  '': {'astronomy': 23454,
#   'biology': 19595,
#   'cook': 21593,
#   'love': 621,
#   'math': 117295,
#   'scifi': 2315},
#  'last': {'astronomy': 385,
#   'biology': 500,
#   'cook': 176,
#   'love': 537,
#   'math': 545,
#   'scifi': 793},
#  'updated': {'astronomy': 13,
#   'biology': 15,
#   'cook': 13,
#   'love': 12,
#   'math': 0,
#   'scifi': 23},
#  'january': {'astronomy': 78,
#   'biology': 25,
#   'cook': 15,
#   'love': 17,
#   'math': 1,
#   'scifi': 10},
#  'language': {'astronomy': 106,
#   'biology': 303,
#   'cook': 13,
#   'love': 39,
#   'math': 25,
#   'scifi': 99},
#  'english': {'astronomy': 147,
#   'biology': 286,
#   'cook': 119,
#   'love': 25,
#   'math': 40,
#   'scifi': 100},
#  'character': {'astronomy': 238,
#   'biology': 630,
#   'cook': 102,
#   'love': 208,
#   'math': 44,
#   'scifi': 139},
#  'set': {'astronomy': 418,
#   'biology': 281,
#   'cook': 519,
#   'love': 238,
#   'math': 126,
#   'scifi': 420},
#  'encoding': {'astronomy': 11,
#   'biology': 2,
#   'cook': 5,
#   'love': 6,
#   'math': 0,
#   'scifi': 12},
#  'utf': {'astronomy': 11,
#   'biology': 2,
#   'cook': 5,
#   'love': 3,
#   'math': 0,
#   'scifi': 5},
#  'start': {'astronomy': 48,
#   'biology': 58,
#   'cook': 47,
#   'love': 41,
#   'math': 20,
#   'scifi': 115},
#  'an': {'astronomy': 3660,
#   'biology': 3993,
#   'cook': 1543,
#   'love': 1793,
#   'math': 1883,
#   'scifi': 2855},
#  'invention': {'astronomy': 106,
#   'biology': 14,
#   'cook': 3,
#   'love': 5,
#   'math': 5,
#   'scifi': 14},
#  'contents': {'astronomy': 25,
#   'biology': 73,
#   'cook': 86,
#   'love': 17,
#   'math': 40,
#   'scifi': 30},
#  'i': {'astronomy': 2049,
#   'biology': 4915,
#   'cook': 917,
#   'love': 9684,
#   'math': 2604,
#   'scifi': 14143},
#  'introduction': {'astronomy': 85,
#   'biology': 90,
#   'cook': 18,
#   'love': 30,
#   'math': 24,
#   'scifi': 16},
#  'ii': {'astronomy': 981,
#   'biology': 473,
#   'cook': 13,
#   'love': 11,
#   'math': 241,
#   'scifi': 41},
#  'iii': {'astronomy': 101,
#   'biology': 227,
#   'cook': 15,
#   'love': 6,
#   'math': 108,
#   'scifi': 33},
#  'traveller': {'astronomy': 9,
#   'biology': 18,
#   'cook': 4,
#   'love': 2,
#   'math': 19,
#   'scifi': 59},
#  'returns': {'astronomy': 33,
#   'biology': 72,
#   'cook': 13,
#   'love': 9,
#   'math': 0,
#   'scifi': 26},
#  'iv': {'astronomy': 60,
#   'biology': 135,
#   'cook': 13,
#   'love': 4,
#   'math': 117,
#   'scifi': 28},
#  'travelling': {'astronomy': 36,
#   'biology': 20,
#   'cook': 3,
#   'love': 18,
#   'math': 12,
#   'scifi': 38},
#  'v': {'astronomy': 187,
#   'biology': 131,
#   'cook': 28,
#   'love': 10,
#   'math': 1465,
#   'scifi': 46},
#  'in': {'astronomy': 23621,
#   'biology': 34048,
#   'cook': 15250,
#   'love': 9360,
#   'math': 8614,
#   'scifi': 14975},
#  'golden': {'astronomy': 65,
#   'biology': 80,
#   'cook': 98,
#   'love': 24,
#   'math': 0,
#   'scifi': 84},
#  'age': {'astronomy': 285,
#   'biology': 380,
#   'cook': 132,
#   'love': 87,
#   'math': 208,
#   'scifi': 86},
#  'vi': {'astronomy': 40,
#   'biology': 69,
#   'cook': 16,
#   'love': 4,
#   'math': 100,
#   'scifi': 28},
#  'sunset': {'astronomy': 49,
#   'biology': 17,
#   'cook': 2,
#   'love': 1,
#   'math': 0,
#   'scifi': 39},
#  'mankind': {'astronomy': 44,
#   'biology': 203,
#   'cook': 4,
#   'love': 4,
#   'math': 1,
#   'scifi': 37},
#  'vii': {'astronomy': 31,
#   'biology': 48,
#   'cook': 7,
#   'love': 4,
#   'math': 37,
#   'scifi': 23},
#  'a': {'astronomy': 20255,
#   'biology': 24298,
#   'cook': 15205,
#   'love': 11439,
#   'math': 20560,
#   'scifi': 18617},
#  'sudden': {'astronomy': 39,
#   'biology': 77,
#   'cook': 9,
#   'love': 71,
#   'math': 1,
#   'scifi': 159},
#  'shock': {'astronomy': 8,
#   'biology': 11,
#   'cook': 0,
#   'love': 20,
#   'math': 0,
#   'scifi': 86},
#  'viii': {'astronomy': 32,
#   'biology': 31,
#   'cook': 6,
#   'love': 4,
#   'math': 29,
#   'scifi': 25},
#  'explanation': {'astronomy': 200,
#   'biology': 153,
#   'cook': 26,
#   'love': 64,
#   'math': 20,
#   'scifi': 112},
#  'ix': {'astronomy': 25,
#   'biology': 41,
#   'cook': 6,
#   'love': 4,
#   'math': 167,
#   'scifi': 23},
#  'morlocks': {'astronomy': 0,
#   'biology': 0,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 46},
#  'x': {'astronomy': 70,
#   'biology': 61,
#   'cook': 219,
#   'love': 5,
#   'math': 12054,
#   'scifi': 66},
#  'when': {'astronomy': 1798,
#   'biology': 3071,
#   'cook': 2667,
#   'love': 1544,
#   'math': 1634,
#   'scifi': 1813},
#  'night': {'astronomy': 310,
#   'biology': 165,
#   'cook': 52,
#   'love': 240,
#   'math': 1,
#   'scifi': 589},
#  'came': {'astronomy': 245,
#   'biology': 259,
#   'cook': 15,
#   'love': 451,
#   'math': 1,
#   'scifi': 890},
#  'xi': {'astronomy': 25,
#   'biology': 29,
#   'cook': 5,
#   'love': 4,
#   'math': 121,
#   'scifi': 18},
#  'palace': {'astronomy': 30,
#   'biology': 4,
#   'cook': 1,
#   'love': 1,
#   'math': 0,
#   'scifi': 168},
#  'green': {'astronomy': 98,
#   'biology': 395,
#   'cook': 448,
#   'love': 25,
#   'math': 3,
#   'scifi': 326},
#  'porcelain': {'astronomy': 2,
#   'biology': 0,
#   'cook': 11,
#   'love': 0,
#   'math': 0,
#   'scifi': 12},
#  'xii': {'astronomy': 21,
#   'biology': 34,
#   'cook': 7,
#   'love': 4,
#   'math': 18,
#   'scifi': 18},
#  'darkness': {'astronomy': 48,
#   'biology': 35,
#   'cook': 3,
#   'love': 12,
#   'math': 0,
#   'scifi': 237},
#  'xiii': {'astronomy': 29,
#   'biology': 21,
#   'cook': 6,
#   'love': 4,
#   'math': 12,
#   'scifi': 16},
#  'trap': {'astronomy': 1,
#   'biology': 19,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 25},
#  'white': {'astronomy': 202,
#   'biology': 910,
#   'cook': 2186,
#   'love': 48,
#   'math': 20,
#   'scifi': 282},
#  'sphinx': {'astronomy': 0,
#   'biology': 17,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 24},
#  'xiv': {'astronomy': 21,
#   'biology': 26,
#   'cook': 4,
#   'love': 5,
#   'math': 11,
#   'scifi': 14},
#  'further': {'astronomy': 284,
#   'biology': 194,
#   'cook': 37,
#   'love': 51,
#   'math': 71,
#   'scifi': 252},
#  'vision': {'astronomy': 58,
#   'biology': 22,
#   'cook': 6,
#   'love': 5,
#   'math': 3,
#   'scifi': 40},
#  'xv': {'astronomy': 8,
#   'biology': 29,
#   'cook': 10,
#   'love': 5,
#   'math': 43,
#   'scifi': 14},
#  'travellers': {'astronomy': 12,
#   'biology': 25,
#   'cook': 3,
#   'love': 5,
#   'math': 11,
#   'scifi': 19},
#  'return': {'astronomy': 183,
#   'biology': 159,
#   'cook': 126,
#   'love': 202,
#   'math': 18,
#   'scifi': 361},
#  'xvi': {'astronomy': 16,
#   'biology': 23,
#   'cook': 6,
#   'love': 4,
#   'math': 10,
#   'scifi': 14},
#  'after': {'astronomy': 982,
#   'biology': 1050,
#   'cook': 522,
#   'love': 776,
#   'math': 259,
#   'scifi': 1051},
#  'story': {'astronomy': 36,
#   'biology': 43,
#   'cook': 9,
#   'love': 57,
#   'math': 4,
#   'scifi': 124},
#  'epilogue': {'astronomy': 0,
#   'biology': 0,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 4},
#  'so': {'astronomy': 2616,
#   'biology': 3582,
#   'cook': 747,
#   'love': 2909,
#   'math': 808,
#   'scifi': 2260},
#  'will': {'astronomy': 1385,
#   'biology': 1922,
#   'cook': 1081,
#   'love': 1720,
#   'math': 3767,
#   'scifi': 1959},
#  'be': {'astronomy': 6972,
#   'biology': 7286,
#   'cook': 3218,
#   'love': 6137,
#   'math': 7869,
#   'scifi': 4634},
#  'convenient': {'astronomy': 44,
#   'biology': 21,
#   'cook': 34,
#   'love': 25,
#   'math': 93,
#   'scifi': 23},
#  'to': {'astronomy': 22574,
#   'biology': 25893,
#   'cook': 10533,
#   'love': 19331,
#   'math': 10651,
#   'scifi': 23961},
#  'speak': {'astronomy': 61,
#   'biology': 100,
#   'cook': 14,
#   'love': 268,
#   'math': 34,
#   'scifi': 191},
#  'him': {'astronomy': 1187,
#   'biology': 747,
#   'cook': 79,
#   'love': 3146,
#   'math': 78,
#   'scifi': 2527},
#  'was': {'astronomy': 7100,
#   'biology': 3550,
#   'cook': 464,
#   'love': 8489,
#   'math': 454,
#   'scifi': 10096},
#  'expounding': {'astronomy': 1,
#   'biology': 0,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 2},
#  'recondite': {'astronomy': 5,
#   'biology': 1,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 2},
#  'matter': {'astronomy': 422,
#   'biology': 313,
#   'cook': 69,
#   'love': 151,
#   'math': 44,
#   'scifi': 403},
#  'us': {'astronomy': 944,
#   'biology': 921,
#   'cook': 280,
#   'love': 488,
#   'math': 536,
#   'scifi': 2161},
#  'his': {'astronomy': 5634,
#   'biology': 3309,
#   'cook': 262,
#   'love': 5046,
#   'math': 383,
#   'scifi': 6576},
#  'pale': {'astronomy': 79,
#   'biology': 140,
#   'cook': 322,
#   'love': 28,
#   'math': 0,
#   'scifi': 81},
#  'grey': {'astronomy': 11,
#   'biology': 132,
#   'cook': 0,
#   'love': 12,
#   'math': 3,
#   'scifi': 58},
#  'eyes': {'astronomy': 96,
#   'biology': 324,
#   'cook': 26,
#   'love': 307,
#   'math': 0,
#   'scifi': 831},
#  'shone': {'astronomy': 23,
#   'biology': 8,
#   'cook': 0,
#   'love': 1,
#   'math': 0,
#   'scifi': 52},
#  'twinkled': {'astronomy': 1,
#   'biology': 0,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 5},
#  'usually': {'astronomy': 133,
#   'biology': 289,
#   'cook': 270,
#   'love': 39,
#   'math': 81,
#   'scifi': 46},
#  'face': {'astronomy': 192,
#   'biology': 252,
#   'cook': 19,
#   'love': 168,
#   'math': 4,
#   'scifi': 542},
#  'flushed': {'astronomy': 6,
#   'biology': 6,
#   'cook': 0,
#   'love': 7,
#   'math': 0,
#   'scifi': 15},
#  'animated': {'astronomy': 14,
#   'biology': 34,
#   'cook': 0,
#   'love': 17,
#   'math': 0,
#   'scifi': 35},
#  'fire': {'astronomy': 125,
#   'biology': 63,
#   'cook': 416,
#   'love': 51,
#   'math': 2,
#   'scifi': 253},
#  'burnt': {'astronomy': 13,
#   'biology': 30,
#   'cook': 29,
#   'love': 2,
#   'math': 0,
#   'scifi': 14},
#  'brightly': {'astronomy': 7,
#   'biology': 51,
#   'cook': 9,
#   'love': 0,
#   'math': 0,
#   'scifi': 12},
#  'soft': {'astronomy': 38,
#   'biology': 116,
#   'cook': 452,
#   'love': 25,
#   'math': 0,
#   'scifi': 94},
#  'radiance': {'astronomy': 6,
#   'biology': 0,
#   'cook': 1,
#   'love': 4,
#   'math': 0,
#   'scifi': 17},
#  'incandescent': {'astronomy': 44,
#   'biology': 1,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 17},
#  'lights': {'astronomy': 53,
#   'biology': 9,
#   'cook': 0,
#   'love': 22,
#   'math': 19,
#   'scifi': 46},
#  'lilies': {'astronomy': 3,
#   'biology': 0,
#   'cook': 1,
#   'love': 0,
#   'math': 0,
#   'scifi': 4},
#  'silver': {'astronomy': 92,
#   'biology': 37,
#   'cook': 38,
#   'love': 6,
#   'math': 22,
#   'scifi': 46},
#  'caught': {'astronomy': 15,
#   'biology': 104,
#   'cook': 3,
#   'love': 72,
#   'math': 2,
#   'scifi': 126},
#  'bubbles': {'astronomy': 0,
#   'biology': 12,
#   'cook': 10,
#   'love': 0,
#   'math': 0,
#   'scifi': 2},
#  'that': {'astronomy': 11171,
#   'biology': 13684,
#   'cook': 1910,
#   'love': 6985,
#   'math': 5498,
#   'scifi': 11142},
#  'flashed': {'astronomy': 6,
#   'biology': 1,
#   'cook': 0,
#   'love': 6,
#   'math': 0,
#   'scifi': 57},
#  'passed': {'astronomy': 197,
#   'biology': 119,
#   'cook': 8,
#   'love': 232,
#   'math': 48,
#   'scifi': 442},
#  'our': {'astronomy': 1276,
#   'biology': 1514,
#   'cook': 320,
#   'love': 404,
#   'math': 258,
#   'scifi': 3099},
#  'glasses': {'astronomy': 16,
#   'biology': 1,
#   'cook': 41,
#   'love': 7,
#   'math': 0,
#   'scifi': 39},
#  'chairs': {'astronomy': 0,
#   'biology': 2,
#   'cook': 0,
#   'love': 6,
#   'math': 4,
#   'scifi': 12},
#  'being': {'astronomy': 1101,
#   'biology': 1493,
#   'cook': 380,
#   'love': 1017,
#   'math': 539,
#   'scifi': 556},
#  'patents': {'astronomy': 1,
#   'biology': 0,
#   'cook': 2,
#   'love': 1,
#   'math': 0,
#   'scifi': 2},
#  'embraced': {'astronomy': 21,
#   'biology': 11,
#   'cook': 0,
#   'love': 3,
#   'math': 2,
#   'scifi': 12},
#  'caressed': {'astronomy': 0,
#   'biology': 4,
#   'cook': 0,
#   'love': 2,
#   'math': 0,
#   'scifi': 6},
#  'rather': {'astronomy': 300,
#   'biology': 321,
#   'cook': 377,
#   'love': 418,
#   'math': 30,
#   'scifi': 289},
#  'than': {'astronomy': 1952,
#   'biology': 2952,
#   'cook': 637,
#   'love': 1461,
#   'math': 979,
#   'scifi': 1411},
#  'submitted': {'astronomy': 9,
#   'biology': 3,
#   'cook': 3,
#   'love': 19,
#   'math': 1,
#   'scifi': 22},
#  'sat': {'astronomy': 15,
#   'biology': 22,
#   'cook': 2,
#   'love': 162,
#   'math': 1,
#   'scifi': 188},
#  'upon': {'astronomy': 1359,
#   'biology': 703,
#   'cook': 426,
#   'love': 452,
#   'math': 276,
#   'scifi': 2560},
#  'there': {'astronomy': 2287,
#   'biology': 2825,
#   'cook': 484,
#   'love': 1631,
#   'math': 869,
#   'scifi': 2330},
#  'luxurious': {'astronomy': 1,
#   'biology': 5,
#   'cook': 0,
#   'love': 6,
#   'math': 0,
#   'scifi': 17},
#  'afterdinner': {'astronomy': 0,
#   'biology': 0,
#   'cook': 2,
#   'love': 0,
#   'math': 0,
#   'scifi': 1},
#  'atmosphere': {'astronomy': 210,
#   'biology': 82,
#   'cook': 16,
#   'love': 15,
#   'math': 8,
#   'scifi': 212},
#  'thought': {'astronomy': 399,
#   'biology': 252,
#   'cook': 35,
#   'love': 626,
#   'math': 14,
#   'scifi': 630},
#  'runs': {'astronomy': 35,
#   'biology': 74,
#   'cook': 4,
#   'love': 5,
#   'math': 1,
#   'scifi': 27},
#  'gracefully': {'astronomy': 2,
#   'biology': 3,
#   'cook': 1,
#   'love': 2,
#   'math': 0,
#   'scifi': 13},
#  'free': {'astronomy': 158,
#   'biology': 246,
#   'cook': 364,
#   'love': 63,
#   'math': 16,
#   'scifi': 186},
#  'trammels': {'astronomy': 2,
#   'biology': 0,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 1},
#  'precision': {'astronomy': 45,
#   'biology': 21,
#   'cook': 1,
#   'love': 5,
#   'math': 1,
#   'scifi': 15},
#  'he': {'astronomy': 5265,
#   'biology': 3383,
#   'cook': 337,
#   'love': 6729,
#   'math': 803,
#   'scifi': 6990},
#  'put': {'astronomy': 119,
#   'biology': 146,
#   'cook': 1684,
#   'love': 197,
#   'math': 179,
#   'scifi': 258},
#  'waymarking': {'astronomy': 0,
#   'biology': 0,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 1},
#  'points': {'astronomy': 232,
#   'biology': 278,
#   'cook': 25,
#   'love': 27,
#   'math': 1400,
#   'scifi': 176},
#  'lean': {'astronomy': 1,
#   'biology': 8,
#   'cook': 14,
#   'love': 2,
#   'math': 0,
#   'scifi': 7},
#  'forefingeras': {'astronomy': 0,
#   'biology': 0,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 1},
#  'we': {'astronomy': 3062,
#   'biology': 4112,
#   'cook': 483,
#   'love': 1231,
#   'math': 6264,
#   'scifi': 6211},
#  'lazily': {'astronomy': 2,
#   'biology': 2,
#   'cook': 0,
#   'love': 8,
#   'math': 0,
#   'scifi': 8},
#  'admired': {'astronomy': 14,
#   'biology': 41,
#   'cook': 1,
#   'love': 44,
#   'math': 0,
#   'scifi': 13},
#  'earnestness': {'astronomy': 5,
#   'biology': 1,
#   'cook': 0,
#   'love': 20,
#   'math': 0,
#   'scifi': 8},
#  'over': {'astronomy': 619,
#   'biology': 943,
#   'cook': 1369,
#   'love': 574,
#   'math': 109,
#   'scifi': 1011},
#  'new': {'astronomy': 1196,
#   'biology': 832,
#   'cook': 711,
#   'love': 218,
#   'math': 379,
#   'scifi': 532},
#  'paradox': {'astronomy': 2,
#   'biology': 1,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 10},
#  'as': {'astronomy': 8559,
#   'biology': 11980,
#   'cook': 3410,
#   'love': 5406,
#   'math': 3846,
#   'scifi': 7045},
#  'fecundity': {'astronomy': 2,
#   'biology': 4,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 2},
#  'must': {'astronomy': 1235,
#   'biology': 1279,
#   'cook': 458,
#   'love': 1575,
#   'math': 1149,
#   'scifi': 1358},
#  'follow': {'astronomy': 138,
#   'biology': 172,
#   'cook': 51,
#   'love': 53,
#   'math': 60,
#   'scifi': 167},
#  'me': {'astronomy': 198,
#   'biology': 1165,
#   'cook': 131,
#   'love': 2049,
#   'math': 19,
#   'scifi': 3795},
#  'carefully': {'astronomy': 84,
#   'biology': 178,
#   'cook': 245,
#   'love': 21,
#   'math': 14,
#   'scifi': 84},
#  'shall': {'astronomy': 301,
#   'biology': 459,
#   'cook': 83,
#   'love': 643,
#   'math': 604,
#   'scifi': 765},
#  'have': {'astronomy': 4116,
#   'biology': 7810,
#   'cook': 1442,
#   'love': 4130,
#   'math': 2593,
#   'scifi': 3745},
#  'controvert': {'astronomy': 4,
#   'biology': 1,
#   'cook': 1,
#   'love': 0,
#   'math': 0,
#   'scifi': 3},
#  'one': {'astronomy': 3217,
#   'biology': 4201,
#   'cook': 3457,
#   'love': 1613,
#   'math': 2268,
#   'scifi': 2856},
#  'two': {'astronomy': 1458,
#   'biology': 2233,
#   'cook': 1861,
#   'love': 700,
#   'math': 3296,
#   'scifi': 1201},
#  'ideas': {'astronomy': 122,
#   'biology': 114,
#   'cook': 9,
#   'love': 63,
#   'math': 3,
#   'scifi': 125},
#  'are': {'astronomy': 5344,
#   'biology': 9677,
#   'cook': 2864,
#   'love': 1529,
#   'math': 3790,
#   'scifi': 2722},
#  'universally': {'astronomy': 26,
#   'biology': 35,
#   'cook': 1,
#   'love': 12,
#   'math': 2,
#   'scifi': 8},
#  'accepted': {'astronomy': 131,
#   'biology': 68,
#   'cook': 30,
#   'love': 57,
#   'math': 0,
#   'scifi': 61},
#  'geometry': {'astronomy': 32,
#   'biology': 1,
#   'cook': 0,
#   'love': 2,
#   'math': 50,
#   'scifi': 172},
#  'instance': {'astronomy': 176,
#   'biology': 485,
#   'cook': 16,
#   'love': 33,
#   'math': 74,
#   'scifi': 68},
#  'they': {'astronomy': 2826,
#   'biology': 5271,
#   'cook': 1053,
#   'love': 2489,
#   'math': 413,
#   'scifi': 3383},
#  'taught': {'astronomy': 56,
#   'biology': 44,
#   'cook': 7,
#   'love': 25,
#   'math': 6,
#   'scifi': 47},
#  'school': {'astronomy': 109,
#   'biology': 33,
#   'cook': 15,
#   'love': 78,
#   'math': 48,
#   'scifi': 25},
#  'founded': {'astronomy': 70,
#   'biology': 51,
#   'cook': 1,
#   'love': 12,
#   'math': 9,
#   'scifi': 20},
#  'on': {'astronomy': 4712,
#   'biology': 9228,
#   'cook': 3523,
#   'love': 3175,
#   'math': 2062,
#   'scifi': 4577},
#  'misconception': {'astronomy': 5,
#   'biology': 2,
#   'cook': 1,
#   'love': 2,
#   'math': 0,
#   'scifi': 2},
#  'not': {'astronomy': 4342,
#   'biology': 5885,
#   'cook': 2681,
#   'love': 6389,
#   'math': 1207,
#   'scifi': 5402},
#  'large': {'astronomy': 591,
#   'biology': 1001,
#   'cook': 842,
#   'love': 118,
#   'math': 73,
#   'scifi': 241},
#  'thing': {'astronomy': 162,
#   'biology': 122,
#   'cook': 40,
#   'love': 716,
#   'math': 54,
#   'scifi': 389},
#  'expect': {'astronomy': 52,
#   'biology': 64,
#   'cook': 8,
#   'love': 103,
#   'math': 11,
#   'scifi': 70},
#  'begin': {'astronomy': 51,
#   'biology': 107,
#   'cook': 51,
#   'love': 66,
#   'math': 30,
#   'scifi': 56},
#  'said': {'astronomy': 379,
#   'biology': 461,
#   'cook': 248,
#   'love': 1657,
#   'math': 162,
#   'scifi': 1689},
#  'filby': {'astronomy': 0,
#   'biology': 0,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 15},
#  'argumentative': {'astronomy': 0,
#   'biology': 0,
#   'cook': 0,
#   'love': 1,
#   'math': 0,
#   'scifi': 1},
#  'person': {'astronomy': 97,
#   'biology': 122,
#   'cook': 90,
#   'love': 260,
#   'math': 21,
#   'scifi': 147},
#  'red': {'astronomy': 171,
#   'biology': 459,
#   'cook': 501,
#   'love': 24,
#   'math': 2,
#   'scifi': 288},
#  'hair': {'astronomy': 14,
#   'biology': 403,
#   'cook': 46,
#   'love': 80,
#   'math': 0,
#   'scifi': 100},
#  'do': {'astronomy': 714,
#   'biology': 1304,
#   'cook': 691,
#   'love': 1817,
#   'math': 245,
#   'scifi': 1379},
#  'mean': {'astronomy': 158,
#   'biology': 64,
#   'cook': 13,
#   'love': 180,
#   'math': 96,
#   'scifi': 185},
#  'ask': {'astronomy': 26,
#   'biology': 37,
#   'cook': 15,
#   'love': 141,
#   'math': 3,
#   'scifi': 106},
#  'accept': {'astronomy': 61,
#   'biology': 44,
#   'cook': 18,
#   'love': 57,
#   'math': 0,
#   'scifi': 59},
#  'anything': {'astronomy': 131,
#   'biology': 101,
#   'cook': 56,
#   'love': 213,
#   'math': 13,
#   'scifi': 183},
#  'without': {'astronomy': 562,
#   'biology': 907,
#   'cook': 448,
#   'love': 781,
#   'math': 174,
#   'scifi': 857},
#  'reasonable': {'astronomy': 41,
#   'biology': 28,
#   'cook': 18,
#   'love': 62,
#   'math': 2,
#   'scifi': 35},
#  'ground': {'astronomy': 137,
#   'biology': 369,
#   'cook': 613,
#   'love': 45,
#   'math': 7,
#   'scifi': 355},
#  'soon': {'astronomy': 201,
#   'biology': 291,
#   'cook': 220,
#   'love': 792,
#   'math': 12,
#   'scifi': 420},
#  'admit': {'astronomy': 40,
#   'biology': 140,
#   'cook': 6,
#   'love': 44,
#   'math': 11,
#   'scifi': 67},
#  'much': {'astronomy': 1126,
#   'biology': 1740,
#   'cook': 473,
#   'love': 1451,
#   'math': 200,
#   'scifi': 581},
#  'need': {'astronomy': 106,
#   'biology': 137,
#   'cook': 64,
#   'love': 125,
#   'math': 48,
#   'scifi': 154},
#  'from': {'astronomy': 5181,
#   'biology': 7742,
#   'cook': 2461,
#   'love': 2366,
#   'math': 2591,
#   'scifi': 4925},
#  'know': {'astronomy': 349,
#   'biology': 470,
#   'cook': 93,
#   'love': 1133,
#   'math': 125,
#   'scifi': 706},
#  'course': {'astronomy': 469,
#   'biology': 379,
#   'cook': 61,
#   'love': 262,
#   'math': 179,
#   'scifi': 351},
#  'mathematical': {'astronomy': 193,
#   'biology': 19,
#   'cook': 1,
#   'love': 0,
#   'math': 52,
#   'scifi': 62},
#  'line': {'astronomy': 670,
#   'biology': 322,
#   'cook': 183,
#   'love': 67,
#   'math': 1400,
#   'scifi': 319},
#  'thickness': {'astronomy': 34,
#   'biology': 110,
#   'cook': 80,
#   'love': 0,
#   'math': 2,
#   'scifi': 35},
#  'nil': {'astronomy': 1,
#   'biology': 0,
#   'cook': 0,
#   'love': 0,
#   'math': 1,
#   'scifi': 5},
#  'has': {'astronomy': 2841,
#   'biology': 4206,
#   'cook': 1007,
#   'love': 960,
#   'math': 1118,
#   'scifi': 1083},
#  'real': {'astronomy': 194,
#   'biology': 86,
#   'cook': 20,
#   'love': 166,
#   'math': 653,
#   'scifi': 176},
#  'existence': {'astronomy': 229,
#   'biology': 266,
#   'cook': 8,
#   'love': 20,
#   'math': 30,
#   'scifi': 165},
#  'neither': {'astronomy': 116,
#   'biology': 102,
#   'cook': 48,
#   'love': 162,
#   'math': 43,
#   'scifi': 198},
#  'plane': {'astronomy': 240,
#   'biology': 43,
#   'cook': 317,
#   'love': 1,
#   'math': 181,
#   'scifi': 87},
#  'these': {'astronomy': 2312,
#   'biology': 3303,
#   'cook': 566,
#   'love': 325,
#   'math': 1220,
#   'scifi': 1540},
#  'things': {'astronomy': 318,
#   'biology': 202,
#   'cook': 69,
#   'love': 236,
#   'math': 23,
#   'scifi': 336},
#  'mere': {'astronomy': 116,
#   'biology': 206,
#   'cook': 52,
#   'love': 43,
#   'math': 23,
#   'scifi': 125},
#  'abstractions': {'astronomy': 1,
#   'biology': 0,
#   'cook': 0,
#   'love': 2,
#   'math': 0,
#   'scifi': 3},
#  'all': {'astronomy': 2810,
#   'biology': 3753,
#   'cook': 1579,
#   'love': 3178,
#   'math': 1257,
#   'scifi': 3285},
#  'right': {'astronomy': 358,
#   'biology': 280,
#   'cook': 106,
#   'love': 270,
#   'math': 773,
#   'scifi': 446},
#  'psychologist': {'astronomy': 0,
#   'biology': 0,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 25},
#  'nor': {'astronomy': 313,
#   'biology': 400,
#   'cook': 74,
#   'love': 281,
#   'math': 33,
#   'scifi': 507},
#  'having': {'astronomy': 657,
#   'biology': 928,
#   'cook': 274,
#   'love': 441,
#   'math': 276,
#   'scifi': 272},
#  'only': {'astronomy': 1414,
#   'biology': 1810,
#   'cook': 452,
#   'love': 1230,
#   'math': 765,
#   'scifi': 1349},
#  'length': {'astronomy': 318,
#   'biology': 658,
#   'cook': 291,
#   'love': 62,
#   'math': 278,
#   'scifi': 303},
#  'breadth': {'astronomy': 24,
#   'biology': 74,
#   'cook': 31,
#   'love': 0,
#   'math': 9,
#   'scifi': 17},
#  'can': {'astronomy': 1271,
#   'biology': 1880,
#   'cook': 849,
#   'love': 1020,
#   'math': 1077,
#   'scifi': 1031},
#  'cube': {'astronomy': 22,
#   'biology': 0,
#   'cook': 4,
#   'love': 0,
#   'math': 313,
#   'scifi': 5},
#  'object': {'astronomy': 275,
#   'biology': 151,
#   'cook': 20,
#   'love': 157,
#   'math': 13,
#   'scifi': 160},
#  'solid': {'astronomy': 166,
#   'biology': 55,
#   'cook': 369,
#   'love': 11,
#   'math': 17,
#   'scifi': 72},
#  'body': {'astronomy': 564,
#   'biology': 839,
#   'cook': 123,
#   'love': 229,
#   'math': 78,
#   'scifi': 407},
#  'exist': {'astronomy': 111,
#   'biology': 159,
#   'cook': 7,
#   'love': 12,
#   'math': 41,
#   'scifi': 73},
#  'most': {'astronomy': 1478,
#   'biology': 1876,
#   'cook': 381,
#   'love': 830,
#   'math': 165,
#   'scifi': 690},
#  'people': {'astronomy': 180,
#   'biology': 198,
#   'cook': 140,
#   'love': 370,
#   'math': 8,
#   'scifi': 506},
#  'think': {'astronomy': 125,
#   'biology': 163,
#   'cook': 51,
#   'love': 1092,
#   'math': 59,
#   'scifi': 430},
#  'but': {'astronomy': 4414,
#   'biology': 5695,
#   'cook': 1935,
#   'love': 4272,
#   'math': 1352,
#   'scifi': 4867},
#  'wait': {'astronomy': 17,
#   'biology': 35,
#   'cook': 9,
#   'love': 86,
#   'math': 1,
#   'scifi': 106},
#  'moment': {'astronomy': 97,
#   'biology': 159,
#   'cook': 31,
#   'love': 353,
#   'math': 14,
#   'scifi': 672},
#  'instantaneous': {'astronomy': 10,
#   'biology': 8,
#   'cook': 4,
#   'love': 4,
#   'math': 0,
#   'scifi': 8},
#  'dont': {'astronomy': 4,
#   'biology': 12,
#   'cook': 13,
#   'love': 238,
#   'math': 2,
#   'scifi': 127},
#  'does': {'astronomy': 422,
#   'biology': 709,
#   'cook': 191,
#   'love': 354,
#   'math': 211,
#   'scifi': 309},
#  'any': {'astronomy': 1818,
#   'biology': 2373,
#   'cook': 1036,
#   'love': 1892,
#   'math': 1800,
#   'scifi': 1536},
#  'became': {'astronomy': 288,
#   'biology': 162,
#   'cook': 6,
#   'love': 111,
#   'math': 6,
#   'scifi': 319},
#  'pensive': {'astronomy': 1,
#   'biology': 1,
#   'cook': 0,
#   'love': 5,
#   'math': 0,
#   'scifi': 2},
#  'clearly': {'astronomy': 148,
#   'biology': 144,
#   'cook': 30,
#   'love': 16,
#   'math': 40,
#   'scifi': 84},
#  'proceeded': {'astronomy': 40,
#   'biology': 32,
#   'cook': 1,
#   'love': 37,
#   'math': 4,
#   'scifi': 51},
#  'extension': {'astronomy': 34,
#   'biology': 41,
#   'cook': 1,
#   'love': 2,
#   'math': 55,
#   'scifi': 9},
#  'four': {'astronomy': 378,
#   'biology': 490,
#   'cook': 496,
#   'love': 141,
#   'math': 782,
#   'scifi': 283},
#  'directions': {'astronomy': 95,
#   'biology': 64,
#   'cook': 66,
#   'love': 15,
#   'math': 29,
#   'scifi': 69},
#  'andduration': {'astronomy': 0,
#   'biology': 0,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 1},
#  'through': {'astronomy': 941,
#   'biology': 1215,
#   'cook': 553,
#   'love': 320,
#   'math': 828,
#   'scifi': 1340},
#  'natural': {'astronomy': 201,
#   'biology': 903,
#   'cook': 114,
#   'love': 137,
#   'math': 48,
#   'scifi': 161},
#  'infirmity': {'astronomy': 0,
#   'biology': 4,
#   'cook': 0,
#   'love': 3,
#   'math': 0,
#   'scifi': 6},
#  'flesh': {'astronomy': 6,
#   'biology': 67,
#   'cook': 769,
#   'love': 2,
#   'math': 0,
#   'scifi': 71},
#  'which': {'astronomy': 8422,
#   'biology': 9152,
#   'cook': 1929,
#   'love': 2343,
#   'math': 3000,
#   'scifi': 4688},
#  'explain': {'astronomy': 111,
#   'biology': 91,
#   'cook': 3,
#   'love': 23,
#   'math': 30,
#   'scifi': 91},
#  'incline': {'astronomy': 2,
#   'biology': 9,
#   'cook': 4,
#   'love': 2,
#   'math': 0,
#   'scifi': 13},
#  'overlook': {'astronomy': 3,
#   'biology': 14,
#   'cook': 1,
#   'love': 10,
#   'math': 0,
#   'scifi': 6},
#  'fact': {'astronomy': 601,
#   'biology': 663,
#   'cook': 58,
#   'love': 102,
#   'math': 169,
#   'scifi': 376},
#  'really': {'astronomy': 172,
#   'biology': 117,
#   'cook': 19,
#   'love': 436,
#   'math': 31,
#   'scifi': 159},
#  'dimensions': {'astronomy': 112,
#   'biology': 48,
#   'cook': 7,
#   'love': 5,
#   'math': 32,
#   'scifi': 114},
#  'three': {'astronomy': 546,
#   'biology': 816,
#   'cook': 823,
#   'love': 269,
#   'math': 1329,
#   'scifi': 612},
#  'call': {'astronomy': 123,
#   'biology': 161,
#   'cook': 20,
#   'love': 148,
#   'math': 73,
#   'scifi': 165},
#  'planes': {'astronomy': 16,
#   'biology': 12,
#   'cook': 0,
#   'love': 0,
#   'math': 12,
#   'scifi': 27},
#  'space': {'astronomy': 413,
#   'biology': 198,
#   'cook': 29,
#   'love': 18,
#   'math': 40,
#   'scifi': 727},
#  'fourth': {'astronomy': 74,
#   'biology': 82,
#   'cook': 8,
#   'love': 9,
#   'math': 314,
#   'scifi': 61},
#  'however': {'astronomy': 812,
#   'biology': 726,
#   'cook': 110,
#   'love': 556,
#   'math': 177,
#   'scifi': 477},
#  'tendency': {'astronomy': 79,
#   'biology': 214,
#   'cook': 20,
#   'love': 19,
#   'math': 1,
#   'scifi': 16},
#  'draw': {'astronomy': 61,
#   'biology': 49,
#   'cook': 47,
#   'love': 34,
#   'math': 125,
#   'scifi': 72},
#  'unreal': {'astronomy': 0,
#   'biology': 1,
#   'cook': 0,
#   'love': 2,
#   'math': 0,
#   'scifi': 11},
#  'distinction': {'astronomy': 83,
#   'biology': 62,
#   'cook': 16,
#   'love': 22,
#   'math': 18,
#   'scifi': 34},
#  'between': {'astronomy': 798,
#   'biology': 1693,
#   'cook': 202,
#   'love': 303,
#   'math': 878,
#   'scifi': 603},
#  'former': {'astronomy': 105,
#   'biology': 283,
#   'cook': 22,
#   'love': 117,
#   'math': 43,
#   'scifi': 112},
#  'latter': {'astronomy': 204,
#   'biology': 535,
#   'cook': 65,
#   'love': 63,
#   'math': 106,
#   'scifi': 113},
#  'because': {'astronomy': 449,
#   'biology': 301,
#   'cook': 129,
#   'love': 259,
#   'math': 186,
#   'scifi': 294},
#  'happens': {'astronomy': 59,
#   'biology': 56,
#   'cook': 3,
#   'love': 13,
#   'math': 25,
#   'scifi': 16},
#  'consciousness': {'astronomy': 22,
#   'biology': 17,
#   'cook': 2,
#   'love': 60,
#   'math': 0,
#   'scifi': 28},
#  'moves': {'astronomy': 74,
#   'biology': 24,
#   'cook': 0,
#   'love': 3,
#   'math': 32,
#   'scifi': 32},
#  'intermittently': {'astronomy': 0,
#   'biology': 0,
#   'cook': 0,
#   'love': 1,
#   'math': 0,
#   'scifi': 5},
#  'direction': {'astronomy': 361,
#   'biology': 198,
#   'cook': 28,
#   'love': 40,
#   'math': 135,
#   'scifi': 330},
#  'along': {'astronomy': 251,
#   'biology': 316,
#   'cook': 55,
#   'love': 91,
#   'math': 50,
#   'scifi': 326},
#  'beginning': {'astronomy': 210,
#   'biology': 103,
#   'cook': 35,
#   'love': 110,
#   'math': 27,
#   'scifi': 85},
#  'end': {'astronomy': 354,
#   'biology': 469,
#   'cook': 170,
#   'love': 206,
#   'math': 92,
#   'scifi': 442},
#  'lives': {'astronomy': 48,
#   'biology': 113,
#   'cook': 11,
#   'love': 28,
#   'math': 4,
#   'scifi': 66},
#  'very': {'astronomy': 1399,
#   'biology': 1522,
#   'cook': 1667,
#   'love': 2800,
#   'math': 147,
#   'scifi': 1137},
#  'young': {'astronomy': 150,
#   'biology': 1105,
#   'cook': 368,
#   'love': 576,
#   'math': 14,
#   'scifi': 265},
#  'man': {'astronomy': 519,
#   'biology': 2621,
#   'cook': 133,
#   'love': 810,
#   'math': 149,
#   'scifi': 1278},
#  'making': {'astronomy': 263,
#   'biology': 142,
#   'cook': 136,
#   'love': 151,
#   'math': 224,
#   'scifi': 153},
#  'spasmodic': {'astronomy': 3,
#   'biology': 1,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 5},
#  'efforts': {'astronomy': 94,
#   'biology': 73,
#   'cook': 44,
#   'love': 30,
#   'math': 7,
#   'scifi': 92},
#  'relight': {'astronomy': 0,
#   'biology': 0,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 1},
#  'cigar': {'astronomy': 0,
#   'biology': 4,
#   'cook': 2,
#   'love': 2,
#   'math': 0,
#   'scifi': 13},
#  'lamp': {'astronomy': 52,
#   'biology': 9,
#   'cook': 1,
#   'love': 3,
#   'math': 0,
#   'scifi': 40},
#  'clear': {'astronomy': 133,
#   'biology': 167,
#   'cook': 168,
#   'love': 55,
#   'math': 51,
#   'scifi': 181},
#  'indeed': {'astronomy': 389,
#   'biology': 168,
#   'cook': 36,
#   'love': 432,
#   'math': 14,
#   'scifi': 273},
#  'now': {'astronomy': 1330,
#   'biology': 1361,
#   'cook': 200,
#   'love': 1066,
#   'math': 691,
#   'scifi': 1758},
#  'remarkable': {'astronomy': 287,
#   'biology': 450,
#   'cook': 50,
#   'love': 23,
#   'math': 21,
#   'scifi': 77},
#  'extensively': {'astronomy': 13,
#   'biology': 17,
#   'cook': 7,
#   'love': 0,
#   'math': 2,
#   'scifi': 2},
#  'overlooked': {'astronomy': 9,
#   'biology': 19,
#   'cook': 7,
#   'love': 7,
#   'math': 1,
#   'scifi': 23},
#  'continued': {'astronomy': 98,
#   'biology': 143,
#   'cook': 13,
#   'love': 194,
#   'math': 19,
#   'scifi': 258},
#  'slight': {'astronomy': 71,
#   'biology': 345,
#   'cook': 104,
#   'love': 55,
#   'math': 13,
#   'scifi': 100},
#  'accession': {'astronomy': 6,
#   'biology': 3,
#   'cook': 0,
#   'love': 2,
#   'math': 4,
#   'scifi': 2},
#  'cheerfulness': {'astronomy': 1,
#   'biology': 1,
#   'cook': 0,
#   'love': 35,
#   'math': 0,
#   'scifi': 10},
#  'what': {'astronomy': 919,
#   'biology': 997,
#   'cook': 175,
#   'love': 1899,
#   'math': 1888,
#   'scifi': 1849},
#  'meant': {'astronomy': 31,
#   'biology': 20,
#   'cook': 2,
#   'love': 121,
#   'math': 8,
#   'scifi': 47},
#  'dimension': {'astronomy': 2,
#   'biology': 0,
#   'cook': 0,
#   'love': 0,
#   'math': 26,
#   'scifi': 48},
#  'though': {'astronomy': 656,
#   'biology': 835,
#   'cook': 131,
#   'love': 803,
#   'math': 56,
#   'scifi': 527},
#  'some': {'astronomy': 1869,
#   'biology': 3955,
#   'cook': 893,
#   'love': 1002,
#   'math': 409,
#   'scifi': 1451},
#  'who': {'astronomy': 1218,
#   'biology': 1353,
#   'cook': 292,
#   'love': 1238,
#   'math': 46,
#   'scifi': 1457},
#  'talk': {'astronomy': 8,
#   'biology': 14,
#   'cook': 3,
#   'love': 197,
#   'math': 0,
#   'scifi': 69},
#  'about': {'astronomy': 1373,
#   'biology': 1135,
#   'cook': 1084,
#   'love': 868,
#   'math': 101,
#   'scifi': 1434},
#  'another': {'astronomy': 614,
#   'biology': 915,
#   'cook': 244,
#   'love': 373,
#   'math': 332,
#   'scifi': 704},
#  'way': {'astronomy': 702,
#   'biology': 460,
#   'cook': 334,
#   'love': 493,
#   'math': 214,
#   'scifi': 854},
#  'looking': {'astronomy': 60,
#   'biology': 96,
#   'cook': 21,
#   'love': 158,
#   'math': 6,
#   'scifi': 171},
#  'difference': {'astronomy': 150,
#   'biology': 640,
#   'cook': 32,
#   'love': 79,
#   'math': 382,
#   'scifi': 74},
#  'except': {'astronomy': 172,
#   'biology': 255,
#   'cook': 135,
#   'love': 120,
#   'math': 81,
#   'scifi': 188},
#  'foolish': {'astronomy': 5,
#   'biology': 10,
#   'cook': 4,
#   'love': 26,
#   'math': 0,
#   'scifi': 35},
#  'got': {'astronomy': 54,
#   'biology': 64,
#   'cook': 21,
#   'love': 211,
#   'math': 29,
#   'scifi': 164},
#  'hold': {'astronomy': 111,
#   'biology': 152,
#   'cook': 67,
#   'love': 62,
#   'math': 37,
#   'scifi': 155},
#  'wrong': {'astronomy': 48,
#   'biology': 37,
#   'cook': 15,
#   'love': 104,
#   'math': 3,
#   'scifi': 66},
#  'side': {'astronomy': 326,
#   'biology': 631,
#   'cook': 220,
#   'love': 261,
#   'math': 149,
#   'scifi': 565},
#  'idea': {'astronomy': 263,
#   'biology': 174,
#   'cook': 53,
#   'love': 260,
#   'math': 20,
#   'scifi': 269},
#  'heard': {'astronomy': 53,
#   'biology': 198,
#   'cook': 12,
#   'love': 398,
#   'math': 0,
#   'scifi': 440},
#  'say': {'astronomy': 295,
#   'biology': 295,
#   'cook': 73,
#   'love': 803,
#   'math': 159,
#   'scifi': 498},
#  'provincial': {'astronomy': 8,
#   'biology': 5,
#   'cook': 0,
#   'love': 1,
#   'math': 0,
#   'scifi': 4},
#  'mayor': {'astronomy': 3,
#   'biology': 3,
#   'cook': 2,
#   'love': 0,
#   'math': 0,
#   'scifi': 7},
#  'simply': {'astronomy': 59,
#   'biology': 125,
#   'cook': 35,
#   'love': 10,
#   'math': 23,
#   'scifi': 135},
#  'mathematicians': {'astronomy': 45,
#   'biology': 4,
#   'cook': 1,
#   'love': 0,
#   'math': 10,
#   'scifi': 17},
#  'spoken': {'astronomy': 39,
#   'biology': 67,
#   'cook': 6,
#   'love': 82,
#   'math': 4,
#   'scifi': 63},
#  'always': {'astronomy': 374,
#   'biology': 591,
#   'cook': 230,
#   'love': 671,
#   'math': 252,
#   'scifi': 263},
#  'definable': {'astronomy': 0,
#   'biology': 1,
#   'cook': 0,
#   'love': 0,
#   'math': 1,
#   'scifi': 1},
#  'reference': {'astronomy': 316,
#   'biology': 64,
#   'cook': 10,
#   'love': 10,
#   'math': 63,
#   'scifi': 141},
#  'each': {'astronomy': 1074,
#   'biology': 1433,
#   'cook': 861,
#   'love': 270,
#   'math': 1519,
#   'scifi': 682},
#  'angles': {'astronomy': 109,
#   'biology': 55,
#   'cook': 9,
#   'love': 1,
#   'math': 250,
#   'scifi': 35},
#  'others': {'astronomy': 530,
#   'biology': 871,
#   'cook': 174,
#   'love': 264,
#   'math': 73,
#   'scifi': 327},
#  'philosophical': {'astronomy': 41,
#   'biology': 57,
#   'cook': 5,
#   'love': 0,
#   'math': 4,
#   'scifi': 21},
#  'been': {'astronomy': 3306,
#   'biology': 4715,
#   'cook': 787,
#   'love': 2460,
#   'math': 463,
#   'scifi': 2068},
#  'asking': {'astronomy': 3,
#   'biology': 10,
#   'cook': 3,
#   'love': 39,
#   'math': 2,
#   'scifi': 32},
#  'why': {'astronomy': 148,
#   'biology': 248,
#   'cook': 38,
#   'love': 248,
#   'math': 51,
#   'scifi': 364},
#  'particularlywhy': {'astronomy': 0,
#   'biology': 0,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 1},
#  'other': {'astronomy': 2154,
#   'biology': 4072,
#   'cook': 795,
#   'love': 923,
#   'math': 1142,
#   'scifi': 1424},
#  'threeand': {'astronomy': 0,
#   'biology': 0,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 1},
#  'even': {'astronomy': 852,
#   'biology': 1378,
#   'cook': 609,
#   'love': 505,
#   'math': 245,
#   'scifi': 1016},
#  'tried': {'astronomy': 56,
#   'biology': 58,
#   'cook': 29,
#   'love': 100,
#   'math': 2,
#   'scifi': 150},
#  'construct': {'astronomy': 64,
#   'biology': 8,
#   'cook': 0,
#   'love': 0,
#   'math': 36,
#   'scifi': 11},
#  'fourdimensional': {'astronomy': 0,
#   'biology': 0,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 48},
#  'professor': {'astronomy': 297,
#   'biology': 276,
#   'cook': 157,
#   'love': 8,
#   'math': 26,
#   'scifi': 261},
#  'simon': {'astronomy': 6,
#   'biology': 1,
#   'cook': 0,
#   'love': 0,
#   'math': 1,
#   'scifi': 1},
#  'newcomb': {'astronomy': 11,
#   'biology': 0,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 2},
#  'york': {'astronomy': 276,
#   'biology': 52,
#   'cook': 197,
#   'love': 32,
#   'math': 35,
#   'scifi': 33},
#  'society': {'astronomy': 287,
#   'biology': 254,
#   'cook': 13,
#   'love': 125,
#   'math': 5,
#   'scifi': 81},
#  'month': {'astronomy': 118,
#   'biology': 63,
#   'cook': 18,
#   'love': 44,
#   'math': 8,
#   'scifi': 53},
#  'ago': {'astronomy': 184,
#   'biology': 167,
#   'cook': 20,
#   'love': 103,
#   'math': 11,
#   'scifi': 98},
#  'how': {'astronomy': 569,
#   'biology': 905,
#   'cook': 189,
#   'love': 1058,
#   'math': 785,
#   'scifi': 710},
#  'flat': {'astronomy': 53,
#   'biology': 77,
#   'cook': 102,
#   'love': 6,
#   'math': 15,
#   'scifi': 59},
#  'surface': {'astronomy': 629,
#   'biology': 695,
#   'cook': 275,
#   'love': 5,
#   'math': 16,
#   'scifi': 308},
#  'represent': {'astronomy': 154,
#   'biology': 52,
#   'cook': 9,
#   'love': 12,
#   'math': 387,
#   'scifi': 33},
#  'figure': {'astronomy': 191,
#   'biology': 395,
#   'cook': 10,
#   'love': 35,
#   'math': 332,
#   'scifi': 152},
#  'threedimensional': {'astronomy': 0,
#   'biology': 0,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 31},
#  'similarly': {'astronomy': 52,
#   'biology': 49,
#   'cook': 8,
#   'love': 0,
#   'math': 105,
#   'scifi': 22},
#  'models': {'astronomy': 1,
#   'biology': 3,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 4},
#  'could': {'astronomy': 996,
#   'biology': 853,
#   'cook': 93,
#   'love': 2575,
#   'math': 74,
#   'scifi': 2075},
#  'fourif': {'astronomy': 0,
#   'biology': 0,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 1},
#  'master': {'astronomy': 66,
#   'biology': 80,
#   'cook': 4,
#   'love': 45,
#   'math': 4,
#   'scifi': 46},
#  'perspective': {'astronomy': 28,
#   'biology': 0,
#   'cook': 0,
#   'love': 1,
#   'math': 0,
#   'scifi': 4},
#  'see': {'astronomy': 876,
#   'biology': 2100,
#   'cook': 185,
#   'love': 811,
#   'math': 729,
#   'scifi': 896},
#  'murmured': {'astronomy': 1,
#   'biology': 0,
#   'cook': 1,
#   'love': 4,
#   'math': 0,
#   'scifi': 31},
#  'knitting': {'astronomy': 0,
#   'biology': 0,
#   'cook': 0,
#   'love': 3,
#   'math': 0,
#   'scifi': 3},
#  'brows': {'astronomy': 0,
#   'biology': 4,
#   'cook': 0,
#   'love': 1,
#   'math': 0,
#   'scifi': 11},
#  'lapsed': {'astronomy': 3,
#   'biology': 3,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 2},
#  'into': {'astronomy': 1444,
#   'biology': 1638,
#   'cook': 2289,
#   'love': 751,
#   'math': 671,
#   'scifi': 1836},
#  'introspective': {'astronomy': 1,
#   'biology': 0,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 1},
#  'state': {'astronomy': 326,
#   'biology': 680,
#   'cook': 429,
#   'love': 183,
#   'math': 64,
#   'scifi': 322},
#  'lips': {'astronomy': 8,
#   'biology': 29,
#   'cook': 4,
#   'love': 47,
#   'math': 0,
#   'scifi': 165},
#  'moving': {'astronomy': 195,
#   'biology': 57,
#   'cook': 4,
#   'love': 25,
#   'math': 17,
#   'scifi': 244},
#  'repeats': {'astronomy': 2,
#   'biology': 7,
#   'cook': 0,
#   'love': 2,
#   'math': 0,
#   'scifi': 1},
#  'mystic': {'astronomy': 8,
#   'biology': 1,
#   'cook': 0,
#   'love': 3,
#   'math': 1,
#   'scifi': 3},
#  'words': {'astronomy': 172,
#   'biology': 193,
#   'cook': 23,
#   'love': 154,
#   'math': 90,
#   'scifi': 369},
#  'yes': {'astronomy': 14,
#   'biology': 14,
#   'cook': 4,
#   'love': 311,
#   'math': 0,
#   'scifi': 256},
#  'brightening': {'astronomy': 0,
#   'biology': 0,
#   'cook': 0,
#   'love': 2,
#   'math': 0,
#   'scifi': 2},
#  'quite': {'astronomy': 312,
#   'biology': 431,
#   'cook': 308,
#   'love': 669,
#   'math': 24,
#   'scifi': 382},
#  'transitory': {'astronomy': 4,
#   'biology': 3,
#   'cook': 1,
#   'love': 0,
#   'math': 0,
#   'scifi': 4},
#  'manner': {'astronomy': 227,
#   'biology': 710,
#   'cook': 85,
#   'love': 288,
#   'math': 270,
#   'scifi': 171},
#  'well': {'astronomy': 629,
#   'biology': 1048,
#   'cook': 1167,
#   'love': 1092,
#   'math': 60,
#   'scifi': 798},
#  'mind': {'astronomy': 163,
#   'biology': 392,
#   'cook': 34,
#   'love': 423,
#   'math': 16,
#   'scifi': 451},
#  'telling': {'astronomy': 12,
#   'biology': 7,
#   'cook': 3,
#   'love': 53,
#   'math': 1,
#   'scifi': 30},
#  'work': {'astronomy': 1596,
#   'biology': 1046,
#   'cook': 777,
#   'love': 364,
#   'math': 106,
#   'scifi': 813},
#  'my': {'astronomy': 286,
#   'biology': 1015,
#   'cook': 156,
#   'love': 2792,
#   'math': 89,
#   'scifi': 6728},
#  'results': {'astronomy': 206,
#   'biology': 143,
#   'cook': 20,
#   'love': 5,
#   'math': 218,
#   'scifi': 95},
#  'curious': {'astronomy': 79,
#   'biology': 245,
#   'cook': 9,
#   'love': 27,
#   'math': 1,
#   'scifi': 71},
#  'here': {'astronomy': 516,
#   'biology': 713,
#   'cook': 120,
#   'love': 442,
#   'math': 129,
#   'scifi': 677},
#  'portrait': {'astronomy': 60,
#   'biology': 17,
#   'cook': 3,
#   'love': 5,
#   'math': 12,
#   'scifi': 8},
#  'eight': {'astronomy': 114,
#   'biology': 142,
#   'cook': 97,
#   'love': 49,
#   'math': 78,
#   'scifi': 79},
#  'years': {'astronomy': 1258,
#   'biology': 636,
#   'cook': 79,
#   'love': 300,
#   'math': 159,
#   'scifi': 419},
#  'old': {'astronomy': 440,
#   'biology': 708,
#   'cook': 247,
#   'love': 305,
#   'math': 104,
#   'scifi': 522},
#  'fifteen': {'astronomy': 63,
#   'biology': 57,
#   'cook': 200,
#   'love': 21,
#   'math': 39,
#   'scifi': 64},
#  'seventeen': {'astronomy': 21,
#   'biology': 23,
#   'cook': 1,
#   'love': 13,
#   'math': 16,
#   'scifi': 20},
#  'twentythree': {'astronomy': 13,
#   'biology': 8,
#   'cook': 1,
#   'love': 2,
#   'math': 11,
#   'scifi': 2},
#  'evidently': {'astronomy': 64,
#   'biology': 115,
#   'cook': 19,
#   'love': 40,
#   'math': 121,
#   'scifi': 193},
#  'sections': {'astronomy': 48,
#   'biology': 56,
#   'cook': 30,
#   'love': 12,
#   'math': 66,
#   'scifi': 21},
#  'were': {'astronomy': 2758,
#   'biology': 2768,
#   'cook': 304,
#   'love': 2374,
#   'math': 295,
#   'scifi': 4103},
#  'representations': {'astronomy': 46,
#   'biology': 19,
#   'cook': 12,
#   'love': 10,
#   'math': 0,
#   'scifi': 16},
#  'fourdimensioned': {'astronomy': 0,
#   'biology': 0,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 2},
#  'fixed': {'astronomy': 275,
#   'biology': 116,
#   'cook': 16,
#   'love': 87,
#   'math': 509,
#   'scifi': 130},
#  'unalterable': {'astronomy': 0,
#   'biology': 2,
#   'cook': 0,
#   'love': 2,
#   'math': 0,
#   'scifi': 8},
#  'scientific': {'astronomy': 367,
#   'biology': 67,
#   'cook': 15,
#   'love': 2,
#   'math': 9,
#   'scifi': 119},
#  'pause': {'astronomy': 4,
#   'biology': 15,
#   'cook': 1,
#   'love': 65,
#   'math': 0,
#   'scifi': 32},
#  'required': {'astronomy': 178,
#   'biology': 100,
#   'cook': 192,
#   'love': 61,
#   'math': 758,
#   'scifi': 82},
#  'proper': {'astronomy': 196,
#   'biology': 234,
#   'cook': 55,
#   'love': 109,
#   'math': 82,
#   'scifi': 59},
#  'assimilation': {'astronomy': 2,
#   'biology': 2,
#   'cook': 1,
#   'love': 0,
#   'math': 0,
#   'scifi': 2},
#  'kind': {'astronomy': 261,
#   'biology': 542,
#   'cook': 101,
#   'love': 278,
#   'math': 106,
#   'scifi': 261},
#  'popular': {'astronomy': 89,
#   'biology': 54,
#   'cook': 18,
#   'love': 20,
#   'math': 7,
#   'scifi': 32},
#  'diagram': {'astronomy': 63,
#   'biology': 27,
#   'cook': 0,
#   'love': 0,
#   'math': 11,
#   'scifi': 8},
#  'weather': {'astronomy': 44,
#   'biology': 80,
#   'cook': 99,
#   'love': 76,
#   'math': 0,
#   'scifi': 41},
#  'record': {'astronomy': 115,
#   'biology': 87,
#   'cook': 12,
#   'love': 2,
#   'math': 2,
#   'scifi': 34},
#  'trace': {'astronomy': 76,
#   'biology': 130,
#   'cook': 19,
#   'love': 9,
#   'math': 10,
#   'scifi': 49},
#  'finger': {'astronomy': 7,
#   'biology': 17,
#   'cook': 40,
#   'love': 6,
#   'math': 0,
#   'scifi': 49},
#  'shows': {'astronomy': 211,
#   'biology': 91,
#   'cook': 25,
#   'love': 8,
#   'math': 109,
#   'scifi': 37},
#  'movement': {'astronomy': 230,
#   'biology': 109,
#   'cook': 9,
#   'love': 2,
#   'math': 2,
#   'scifi': 70},
#  'barometer': {'astronomy': 3,
#   'biology': 1,
#   'cook': 1,
#   'love': 0,
#   'math': 3,
#   'scifi': 9},
#  'yesterday': {'astronomy': 3,
#   'biology': 13,
#   'cook': 8,
#   'love': 71,
#   'math': 0,
#   'scifi': 16},
#  'high': {'astronomy': 297,
#   'biology': 382,
#   'cook': 246,
#   'love': 100,
#   'math': 26,
#   'scifi': 300},
#  'fell': {'astronomy': 72,
#   'biology': 30,
#   'cook': 10,
#   'love': 56,
#   'math': 1,
#   'scifi': 287},
#  'then': {'astronomy': 1064,
#   'biology': 975,
#   'cook': 2681,
#   'love': 741,
#   'math': 2039,
#   'scifi': 1849},
#  'morning': {'astronomy': 95,
#   'biology': 136,
#   'cook': 63,
#   'love': 354,
#   'math': 2,
#   'scifi': 260},
#  'rose': {'astronomy': 42,
#   'biology': 68,
#   'cook': 51,
#   'love': 47,
#   'math': 2,
#   'scifi': 264},
#  'again': {'astronomy': 422,
#   'biology': 566,
#   'cook': 179,
#   'love': 762,
#   'math': 236,
#   'scifi': 875},
#  'gently': {'astronomy': 7,
#   'biology': 26,
#   'cook': 150,
#   'love': 11,
#   'math': 0,
#   'scifi': 66},
#  'upward': {'astronomy': 14,
#   'biology': 35,
#   'cook': 184,
#   'love': 2,
#   'math': 14,
#   'scifi': 61},
#  'surely': {'astronomy': 35,
#   'biology': 59,
#   'cook': 11,
#   'love': 27,
#   'math': 2,
#   'scifi': 61},
#  'mercury': {'astronomy': 138,
#   'biology': 13,
#   'cook': 3,
#   'love': 0,
#   'math': 5,
#   'scifi': 52},
#  'did': {'astronomy': 472,
#   'biology': 299,
#   'cook': 39,
#   'love': 1109,
#   'math': 154,
#   'scifi': 1103},
#  'generally': {'astronomy': 202,
#   'biology': 638,
#   'cook': 223,
#   'love': 74,
# ...
#   'biology': 212,
#   'cook': 46,
#   'love': 153,
#   'math': 35,
#   'scifi': 560},
#  'impartiality': {'astronomy': 0,
#   'biology': 1,
#   'cook': 0,
#   'love': 1,
#   'math': 0,
#   'scifi': 1},
#  'bit': {'astronomy': 16,
#   'biology': 18,
#   'cook': 64,
#   'love': 37,
#   'math': 2,
#   'scifi': 72},
#  'presentation': {'astronomy': 10,
#   'biology': 0,
#   'cook': 3,
#   'love': 8,
#   'math': 7,
#   'scifi': 4},
#  'below': {'astronomy': 256,
#   'biology': 271,
#   'cook': 177,
#   'love': 44,
#   'math': 41,
#   'scifi': 293},
#  'threshold': {'astronomy': 2,
#   'biology': 11,
#   'cook': 0,
#   'love': 1,
#   'math': 0,
#   'scifi': 24},
#  'diluted': {'astronomy': 0,
#   'biology': 2,
#   'cook': 12,
#   'love': 1,
#   'math': 0,
#   'scifi': 1},
#  'reassured': {'astronomy': 0,
#   'biology': 1,
#   'cook': 0,
#   'love': 1,
#   'math': 0,
#   'scifi': 13},
#  'thats': {'astronomy': 0,
#   'biology': 6,
#   'cook': 5,
#   'love': 97,
#   'math': 0,
#   'scifi': 45},
#  'simple': {'astronomy': 179,
#   'biology': 187,
#   'cook': 102,
#   'love': 42,
#   'math': 173,
#   'scifi': 158},
#  'point': {'astronomy': 507,
#   'biology': 482,
#   'cook': 155,
#   'love': 198,
#   'math': 1729,
#   'scifi': 530},
#  'psychology': {'astronomy': 5,
#   'biology': 11,
#   'cook': 0,
#   'love': 1,
#   'math': 2,
#   'scifi': 3},
#  'plain': {'astronomy': 89,
#   'biology': 137,
#   'cook': 168,
#   'love': 55,
#   'math': 132,
#   'scifi': 144},
#  'helps': {'astronomy': 7,
#   'biology': 4,
#   'cook': 2,
#   'love': 0,
#   'math': 2,
#   'scifi': 1},
#  'delightfully': {'astronomy': 0,
#   'biology': 1,
#   'cook': 0,
#   'love': 11,
#   'math': 0,
#   'scifi': 1},
#  'appreciate': {'astronomy': 25,
#   'biology': 38,
#   'cook': 1,
#   'love': 5,
#   'math': 2,
#   'scifi': 21},
#  'spoke': {'astronomy': 14,
#   'biology': 20,
#   'cook': 0,
#   'love': 165,
#   'math': 1,
#   'scifi': 207},
#  'wheel': {'astronomy': 33,
#   'biology': 29,
#   'cook': 5,
#   'love': 2,
#   'math': 7,
#   'scifi': 42},
#  'spinning': {'astronomy': 21,
#   'biology': 10,
#   'cook': 3,
#   'love': 2,
#   'math': 0,
#   'scifi': 10},
#  'bullet': {'astronomy': 18,
#   'biology': 1,
#   'cook': 0,
#   'love': 1,
#   'math': 0,
#   'scifi': 41},
#  'flying': {'astronomy': 33,
#   'biology': 79,
#   'cook': 1,
#   'love': 6,
#   'math': 0,
#   'scifi': 54},
#  'times': {'astronomy': 577,
#   'biology': 425,
#   'cook': 130,
#   'love': 105,
#   'math': 623,
#   'scifi': 309},
#  'hundred': {'astronomy': 307,
#   'biology': 198,
#   'cook': 28,
#   'love': 77,
#   'math': 31,
#   'scifi': 401},
#  'faster': {'astronomy': 27,
#   'biology': 8,
#   'cook': 0,
#   'love': 9,
#   'math': 6,
#   'scifi': 36},
#  'gets': {'astronomy': 25,
#   'biology': 13,
#   'cook': 31,
#   'love': 17,
#   'math': 2,
#   'scifi': 14},
#  'while': {'astronomy': 769,
#   'biology': 540,
#   'cook': 273,
#   'love': 470,
#   'math': 112,
#   'scifi': 872},
#  'impression': {'astronomy': 55,
#   'biology': 50,
#   'cook': 4,
#   'love': 36,
#   'math': 0,
#   'scifi': 37},
#  'creates': {'astronomy': 5,
#   'biology': 4,
#   'cook': 1,
#   'love': 0,
#   'math': 0,
#   'scifi': 3},
#  'onefiftieth': {'astronomy': 1,
#   'biology': 1,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 1},
#  'onehundredth': {'astronomy': 1,
#   'biology': 0,
#   'cook': 1,
#   'love': 0,
#   'math': 0,
#   'scifi': 2},
#  'laughing': {'astronomy': 2,
#   'biology': 6,
#   'cook': 3,
#   'love': 53,
#   'math': 0,
#   'scifi': 50},
#  'vacant': {'astronomy': 20,
#   'biology': 15,
#   'cook': 2,
#   'love': 12,
#   'math': 0,
#   'scifi': 36},
#  'asked': {'astronomy': 39,
#   'biology': 62,
#   'cook': 10,
#   'love': 170,
#   'math': 17,
#   'scifi': 409},
#  'sounds': {'astronomy': 13,
#   'biology': 195,
#   'cook': 2,
#   'love': 25,
#   'math': 1,
#   'scifi': 76},
#  'plausible': {'astronomy': 12,
#   'biology': 5,
#   'cook': 0,
#   'love': 5,
#   'math': 3,
#   'scifi': 14},
#  'tonight': {'astronomy': 2,
#   'biology': 0,
#   'cook': 0,
#   'love': 32,
#   'math': 0,
#   'scifi': 40},
#  'tomorrow': {'astronomy': 4,
#   'biology': 13,
#   'cook': 3,
#   'love': 90,
#   'math': 0,
#   'scifi': 79},
#  'common': {'astronomy': 247,
#   'biology': 920,
#   'cook': 348,
#   'love': 115,
#   'math': 833,
#   'scifi': 197},
#  'sense': {'astronomy': 105,
#   'biology': 288,
#   'cook': 23,
#   'love': 190,
#   'math': 53,
#   'scifi': 168},
#  'like': {'astronomy': 826,
#   'biology': 1339,
#   'cook': 567,
#   'love': 652,
#   'math': 280,
#   'scifi': 1058},
#  'itself': {'astronomy': 369,
#   'biology': 343,
#   'cook': 67,
#   'love': 71,
#   'math': 231,
#   'scifi': 269},
#  'therewith': {'astronomy': 4,
#   'biology': 0,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 3},
#  'taking': {'astronomy': 89,
#   'biology': 94,
#   'cook': 68,
#   'love': 115,
#   'math': 108,
#   'scifi': 136},
#  'led': {'astronomy': 210,
#   'biology': 171,
#   'cook': 10,
#   'love': 82,
#   'math': 31,
#   'scifi': 187},
#  'draughty': {'astronomy': 0,
#   'biology': 1,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 1},
#  'corridor': {'astronomy': 0,
#   'biology': 0,
#   'cook': 0,
#   'love': 1,
#   'math': 0,
#   'scifi': 90},
#  'remember': {'astronomy': 73,
#   'biology': 54,
#   'cook': 9,
#   'love': 125,
#   'math': 17,
#   'scifi': 105},
#  'flickering': {'astronomy': 3,
#   'biology': 2,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 19},
#  'queer': {'astronomy': 1,
#   'biology': 4,
#   'cook': 3,
#   'love': 6,
#   'math': 0,
#   'scifi': 23},
#  'broad': {'astronomy': 67,
#   'biology': 164,
#   'cook': 908,
#   'love': 18,
#   'math': 1,
#   'scifi': 90},
#  'head': {'astronomy': 193,
#   'biology': 805,
#   'cook': 135,
#   'love': 190,
#   'math': 22,
#   'scifi': 465},
#  'silhouette': {'astronomy': 0,
#   'biology': 0,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 3},
#  'dance': {'astronomy': 9,
#   'biology': 10,
#   'cook': 0,
#   'love': 83,
#   'math': 0,
#   'scifi': 23},
#  'shadows': {'astronomy': 36,
#   'biology': 24,
#   'cook': 1,
#   'love': 11,
#   'math': 0,
#   'scifi': 85},
#  'followed': {'astronomy': 187,
#   'biology': 150,
#   'cook': 28,
#   'love': 111,
#   'math': 12,
#   'scifi': 285},
#  'puzzled': {'astronomy': 5,
#   'biology': 5,
#   'cook': 5,
#   'love': 21,
#   'math': 0,
#   'scifi': 34},
#  'incredulous': {'astronomy': 6,
#   'biology': 1,
#   'cook': 0,
#   'love': 5,
#   'math': 0,
#   'scifi': 12},
#  'beheld': {'astronomy': 23,
#   'biology': 13,
#   'cook': 1,
#   'love': 6,
#   'math': 0,
#   'scifi': 50},
#  'edition': {'astronomy': 112,
#   'biology': 125,
#   'cook': 30,
#   'love': 18,
#   'math': 160,
#   'scifi': 19},
#  'parts': {'astronomy': 461,
#   'biology': 696,
#   'cook': 133,
#   'love': 19,
#   'math': 225,
#   'scifi': 90},
#  'nickel': {'astronomy': 3,
#   'biology': 0,
#   'cook': 0,
#   'love': 0,
#   'math': 1,
#   'scifi': 2},
#  'filed': {'astronomy': 1,
#   'biology': 3,
#   'cook': 2,
#   'love': 0,
#   'math': 3,
#   'scifi': 12},
#  'sawn': {'astronomy': 1,
#   'biology': 4,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 1},
#  'rock': {'astronomy': 57,
#   'biology': 123,
#   'cook': 17,
#   'love': 2,
#   'math': 0,
#   'scifi': 128},
#  'crystal': {'astronomy': 20,
#   'biology': 14,
#   'cook': 19,
#   'love': 0,
#   'math': 0,
#   'scifi': 10},
#  'complete': {'astronomy': 190,
#   'biology': 167,
#   'cook': 38,
#   'love': 53,
#   'math': 136,
#   'scifi': 96},
#  'twisted': {'astronomy': 5,
#   'biology': 24,
#   'cook': 27,
#   'love': 11,
#   'math': 0,
#   'scifi': 19},
#  'bars': {'astronomy': 10,
#   'biology': 34,
#   'cook': 60,
#   'love': 1,
#   'math': 0,
#   'scifi': 37},
#  'lay': {'astronomy': 61,
#   'biology': 96,
#   'cook': 292,
#   'love': 57,
#   'math': 18,
#   'scifi': 384},
#  'unfinished': {'astronomy': 5,
#   'biology': 2,
#   'cook': 1,
#   'love': 1,
#   'math': 0,
#   'scifi': 3},
#  'bench': {'astronomy': 1,
#   'biology': 2,
#   'cook': 2,
#   'love': 4,
#   'math': 0,
#   'scifi': 20},
#  'beside': {'astronomy': 11,
#   'biology': 41,
#   'cook': 7,
#   'love': 24,
#   'math': 1,
#   'scifi': 193},
#  'sheets': {'astronomy': 17,
#   'biology': 7,
#   'cook': 27,
#   'love': 4,
#   'math': 2,
#   'scifi': 11},
#  'drawings': {'astronomy': 32,
#   'biology': 36,
#   'cook': 2,
#   'love': 9,
#   'math': 3,
#   'scifi': 6},
#  'quartz': {'astronomy': 4,
#   'biology': 12,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 9},
#  'perfectly': {'astronomy': 66,
#   'biology': 187,
#   'cook': 64,
#   'love': 215,
#   'math': 6,
#   'scifi': 86},
#  'tricklike': {'astronomy': 0,
#   'biology': 0,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 1},
#  'showed': {'astronomy': 138,
#   'biology': 29,
#   'cook': 3,
#   'love': 22,
#   'math': 14,
#   'scifi': 105},
#  'christmas': {'astronomy': 12,
#   'biology': 4,
#   'cook': 17,
#   'love': 35,
#   'math': 0,
#   'scifi': 2},
#  'holding': {'astronomy': 22,
#   'biology': 38,
#   'cook': 21,
#   'love': 8,
#   'math': 1,
#   'scifi': 48},
#  'aloft': {'astronomy': 1,
#   'biology': 1,
#   'cook': 1,
#   'love': 1,
#   'math': 0,
#   'scifi': 24},
#  'intend': {'astronomy': 3,
#   'biology': 5,
#   'cook': 4,
#   'love': 7,
#   'math': 2,
#   'scifi': 19},
#  'explore': {'astronomy': 4,
#   'biology': 8,
#   'cook': 1,
#   'love': 5,
#   'math': 0,
#   'scifi': 16},
#  'life': {'astronomy': 663,
#   'biology': 992,
#   'cook': 105,
#   'love': 359,
#   'math': 55,
#   'scifi': 747},
#  'none': {'astronomy': 129,
#   'biology': 146,
#   'cook': 87,
#   'love': 96,
#   'math': 23,
#   'scifi': 199},
#  'knew': {'astronomy': 86,
#   'biology': 59,
#   'cook': 9,
#   'love': 341,
#   'math': 9,
#   'scifi': 363},
#  'take': {'astronomy': 235,
#   'biology': 337,
#   'cook': 729,
#   'love': 348,
#   'math': 360,
#   'scifi': 526},
#  'eye': {'astronomy': 300,
#   'biology': 178,
#   'cook': 35,
#   'love': 88,
#   'math': 3,
#   'scifi': 163},
#  'winked': {'astronomy': 0,
#   'biology': 0,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 4},
#  'solemnly': {'astronomy': 6,
#   'biology': 3,
#   'cook': 0,
#   'love': 4,
#   'math': 0,
#   'scifi': 6},
#  'believed': {'astronomy': 155,
#   'biology': 123,
#   'cook': 11,
#   'love': 143,
#   'math': 2,
#   'scifi': 76},
#  'those': {'astronomy': 1314,
#   'biology': 1648,
#   'cook': 264,
#   'love': 342,
#   'math': 363,
#   'scifi': 685},
#  'clever': {'astronomy': 6,
#   'biology': 15,
#   'cook': 2,
#   'love': 65,
#   'math': 0,
#   'scifi': 18},
#  'felt': {'astronomy': 90,
#   'biology': 87,
#   'cook': 13,
#   'love': 456,
#   'math': 2,
#   'scifi': 417},
#  'suspected': {'astronomy': 26,
#   'biology': 29,
#   'cook': 9,
#   'love': 44,
#   'math': 0,
#   'scifi': 25},
#  'subtle': {'astronomy': 11,
#   'biology': 14,
#   'cook': 10,
#   'love': 4,
#   'math': 1,
#   'scifi': 8},
#  'reserve': {'astronomy': 15,
#   'biology': 14,
#   'cook': 28,
#   'love': 29,
#   'math': 2,
#   'scifi': 23},
#  'ingenuity': {'astronomy': 22,
#   'biology': 14,
#   'cook': 1,
#   'love': 6,
#   'math': 2,
#   'scifi': 9},
#  'ambush': {'astronomy': 0,
#   'biology': 3,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 5},
#  'lucid': {'astronomy': 19,
#   'biology': 1,
#   'cook': 1,
#   'love': 1,
#   'math': 0,
#   'scifi': 2},
#  'frankness': {'astronomy': 1,
#   'biology': 0,
#   'cook': 0,
#   'love': 8,
#   'math': 0,
#   'scifi': 9},
#  'shown': {'astronomy': 372,
#   'biology': 189,
#   'cook': 28,
#   'love': 9,
#   'math': 128,
#   'scifi': 51},
#  'explained': {'astronomy': 115,
#   'biology': 112,
#   'cook': 4,
#   'love': 30,
#   'math': 55,
#   'scifi': 97},
#  'less': {'astronomy': 574,
#   'biology': 997,
#   'cook': 366,
#   'love': 300,
#   'math': 524,
#   'scifi': 318},
#  'scepticism': {'astronomy': 13,
#   'biology': 1,
#   'cook': 0,
#   'love': 1,
#   'math': 0,
#   'scifi': 2},
#  'perceived': {'astronomy': 90,
#   'biology': 31,
#   'cook': 0,
#   'love': 41,
#   'math': 3,
#   'scifi': 70},
#  'motives': {'astronomy': 10,
#   'biology': 28,
#   'cook': 0,
#   'love': 25,
#   'math': 0,
#   'scifi': 20},
#  'porkbutcher': {'astronomy': 0,
#   'biology': 0,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 1},
#  'touch': {'astronomy': 29,
#   'biology': 75,
#   'cook': 29,
#   'love': 30,
#   'math': 167,
#   'scifi': 70},
#  'whim': {'astronomy': 0,
#   'biology': 1,
#   'cook': 0,
#   'love': 1,
#   'math': 0,
#   'scifi': 4},
#  'among': {'astronomy': 563,
#   'biology': 520,
#   'cook': 213,
#   'love': 157,
#   'math': 57,
#   'scifi': 487},
#  'elements': {'astronomy': 146,
#   'biology': 71,
#   'cook': 12,
#   'love': 1,
#   'math': 174,
#   'scifi': 104},
#  'distrusted': {'astronomy': 0,
#   'biology': 0,
#   'cook': 0,
#   'love': 4,
#   'math': 0,
#   'scifi': 1},
#  'fame': {'astronomy': 97,
#   'biology': 7,
#   'cook': 2,
#   'love': 5,
#   'math': 0,
#   'scifi': 17},
#  'tricks': {'astronomy': 1,
#   'biology': 6,
#   'cook': 0,
#   'love': 5,
#   'math': 0,
#   'scifi': 2},
#  'mistake': {'astronomy': 22,
#   'biology': 45,
#   'cook': 11,
#   'love': 47,
#   'math': 2,
#   'scifi': 45},
#  'easily': {'astronomy': 154,
#   'biology': 196,
#   'cook': 241,
#   'love': 95,
#   'math': 123,
#   'scifi': 135},
#  'deportment': {'astronomy': 0,
#   'biology': 0,
#   'cook': 0,
#   'love': 2,
#   'math': 0,
#   'scifi': 1},
#  'somehow': {'astronomy': 6,
#   'biology': 12,
#   'cook': 4,
#   'love': 36,
#   'math': 1,
#   'scifi': 15},
#  'aware': {'astronomy': 17,
#   'biology': 56,
#   'cook': 3,
#   'love': 83,
#   'math': 4,
#   'scifi': 63},
#  'trusting': {'astronomy': 1,
#   'biology': 10,
#   'cook': 0,
#   'love': 8,
#   'math': 0,
#   'scifi': 6},
#  'their': {'astronomy': 2714,
#   'biology': 5772,
#   'cook': 522,
#   'love': 1712,
#   'math': 790,
#   'scifi': 2791},
#  'reputations': {'astronomy': 1,
#   'biology': 1,
#   'cook': 1,
#   'love': 0,
#   'math': 0,
#   'scifi': 3},
#  'judgment': {'astronomy': 19,
#   'biology': 59,
#   'cook': 8,
#   'love': 70,
#   'math': 0,
#   'scifi': 29},
#  'furnishing': {'astronomy': 10,
#   'biology': 3,
#   'cook': 3,
#   'love': 2,
#   'math': 2,
#   'scifi': 6},
#  'nursery': {'astronomy': 2,
#   'biology': 26,
#   'cook': 0,
#   'love': 6,
#   'math': 0,
#   'scifi': 3},
#  'eggshell': {'astronomy': 0,
#   'biology': 3,
#   'cook': 2,
#   'love': 0,
#   'math': 0,
#   'scifi': 3},
#  'china': {'astronomy': 20,
#   'biology': 65,
#   'cook': 9,
#   'love': 6,
#   'math': 1,
#   'scifi': 6},
#  'next': {'astronomy': 229,
#   'biology': 229,
#   'cook': 101,
#   'love': 285,
#   'math': 152,
#   'scifi': 179},
#  'potentialities': {'astronomy': 0,
#   'biology': 2,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 1},
#  'ran': {'astronomy': 16,
#   'biology': 37,
#   'cook': 1,
#   'love': 47,
#   'math': 2,
#   'scifi': 154},
#  'doubt': {'astronomy': 241,
#   'biology': 481,
#   'cook': 34,
#   'love': 224,
#   'math': 6,
#   'scifi': 207},
#  'minds': {'astronomy': 63,
#   'biology': 44,
#   'cook': 4,
#   'love': 19,
#   'math': 3,
#   'scifi': 72},
#  'plausibility': {'astronomy': 1,
#   'biology': 5,
#   'cook': 0,
#   'love': 0,
#   'math': 1,
#   'scifi': 2},
#  'practical': {'astronomy': 136,
#   'biology': 33,
#   'cook': 28,
#   'love': 3,
#   'math': 36,
#   'scifi': 41},
#  'incredibleness': {'astronomy': 0,
#   'biology': 0,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 1},
#  'possibilities': {'astronomy': 14,
#   'biology': 2,
#   'cook': 3,
#   'love': 6,
#   'math': 6,
#   'scifi': 27},
#  'anachronism': {'astronomy': 0,
#   'biology': 1,
#   'cook': 1,
#   'love': 0,
#   'math': 0,
#   'scifi': 1},
#  'utter': {'astronomy': 9,
#   'biology': 40,
#   'cook': 3,
#   'love': 17,
#   'math': 0,
#   'scifi': 70},
#  'confusion': {'astronomy': 28,
#   'biology': 29,
#   'cook': 3,
#   'love': 50,
#   'math': 3,
#   'scifi': 44},
#  'particularly': {'astronomy': 108,
#   'biology': 89,
#   'cook': 30,
#   'love': 159,
#   'math': 6,
#   'scifi': 53},
#  'preoccupied': {'astronomy': 2,
#   'biology': 3,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 4},
#  'discussing': {'astronomy': 10,
#   'biology': 9,
#   'cook': 3,
#   'love': 3,
#   'math': 5,
#   'scifi': 10},
#  'whom': {'astronomy': 189,
#   'biology': 132,
#   'cook': 30,
#   'love': 312,
#   'math': 4,
#   'scifi': 241},
#  'met': {'astronomy': 67,
#   'biology': 139,
#   'cook': 23,
#   'love': 174,
#   'math': 24,
#   'scifi': 178},
#  'friday': {'astronomy': 3,
#   'biology': 1,
#   'cook': 4,
#   'love': 7,
#   'math': 0,
#   'scifi': 14},
#  'linnæan': {'astronomy': 0,
#   'biology': 0,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 1},
#  'similar': {'astronomy': 313,
#   'biology': 461,
#   'cook': 62,
#   'love': 20,
#   'math': 175,
#   'scifi': 87},
#  'tübingen': {'astronomy': 8,
#   'biology': 0,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 1},
#  'laid': {'astronomy': 99,
#   'biology': 120,
#   'cook': 15,
#   'love': 37,
#   'math': 10,
#   'scifi': 105},
#  'considerable': {'astronomy': 216,
#   'biology': 231,
#   'cook': 54,
#   'love': 62,
#   'math': 4,
#   'scifi': 114},
#  'stress': {'astronomy': 11,
#   'biology': 25,
#   'cook': 0,
#   'love': 2,
#   'math': 0,
#   'scifi': 13},
#  'blowingout': {'astronomy': 0,
#   'biology': 0,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 1},
#  'candle': {'astronomy': 12,
#   'biology': 5,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 7},
#  'richmondi': {'astronomy': 0,
#   'biology': 0,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 1},
#  ...}

# %%
print(clase_pred)
# Out:
# ('math', [-inf, -inf, -53.81765144361964, -inf, -inf, -inf])

# %% [markdown]
# ## Predicción con el conjunto de prueba

# %%
predicciones = []
for clase in clases:
    for i in libros_test[clase]:
        archivo_txt = todos_los_libros[clase][i-2]
        libro_prueba = open(archivo_txt).read().split()
        clase_pred,lv = clasifica(libro_prueba, frecuencias, frecuencias_clases, clases)
        predicciones.append((clase, clase_pred))
        print("Libro:", archivo_txt, "--", clase, clase_pred, max(lv))
# Out:
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:10: RuntimeWarning: divide by zero encountered in log
#   # Remove the CWD from sys.path while we load stuff.
# scifi scifi -438777.90662840114 Libro: books/scifi10.txt
# scifi scifi -478645.2742125031 Libro: books/scifi2.txt
# scifi scifi -1255240.1768416797 Libro: books/scifi12.txt
# love love -793403.4410954133 Libro: books/love3.txt
# love love -562697.6876509512 Libro: books/love6.txt
# math scifi 0.0 Libro: books/math10.txt
# math math -32582.447892758686 Libro: books/math9.txt
# biology biology -488911.5426589277 Libro: books/biology15.txt
# biology biology -2108090.854640536 Libro: books/biology1.txt
# biology scifi -inf Libro: books/biology2.txt
# biology biology -501085.6143372392 Libro: books/biology8.txt
# astronomy astronomy -759666.7043536137 Libro: books/astronomy14.txt
# astronomy astronomy -581966.3088570021 Libro: books/astronomy16.txt

# %%
porcentaje_clasificación = sum( [ p[0] == p[1] for p in predicciones] ) / len(predicciones)
print("porcentaje_clasificación =", porcentaje_clasificación)
# Out:
# porcentaje_clasificación = 0.7368421052631579

# %% [markdown]
# ## Matriz de Confusión

# %%
matriz_confusion = [[ 0 for c in clases] for c in clases]

for cc in predicciones:
    real, prediccion = cc
    j = clases.index(prediccion)
    i = clases.index(real)
    matriz_confusion[i][j] += 1
    
print("Matriz de confusion")
print(clases)
for i in range(len(matriz_confusion)):
    clase = clases[i]
    print(clase[:4], matriz_confusion[i])
print("porcentaje_clasificación =", porcentaje_clasificación)
# Out:
# Matriz de confusion
# ['scifi', 'love', 'math', 'biology', 'astronomy', 'cook']
# scif [3, 0, 0, 0, 0, 0]
# love [0, 2, 0, 0, 0, 0]
# math [1, 0, 1, 0, 0, 0]
# biol [1, 0, 0, 3, 0, 0]
# astr [1, 0, 0, 0, 3, 0]
# cook [2, 0, 0, 0, 0, 2]
# porcentaje_clasificación = 0.7368421052631579

# %% [markdown]
# ## Predicción de un solo libro

# %%
predicciones = []
clase = 'cook'
archivo_txt = todos_los_libros[clase][i]
libro_prueba = open(archivo_txt).read().split()
clase_pred,lv = clasifica(libro_prueba, frecuencias, frecuencas_clases, clases)
predicciones.append((clase, clase_pred))
# Out:
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:10: RuntimeWarning: divide by zero encountered in log
#   # Remove the CWD from sys.path while we load stuff.

# %%
archivo_txt
# Out:
# 'books/cook14.txt'

# %%
print(clase, clase_pred, max(lv))
# Out:
# cook scifi -inf

# %%
porcentaje_clasificación_libro= sum( [ p[0] == p[1] for p in predicciones] ) / len(predicciones)
print("porcentaje_clasificación =", porcentaje_clasificación_libro)
# Out:
# porcentaje_clasificación = 0.0
