# %% [markdown]
# # <center> Clasificación de libros haciendo uso del algoritmo de clasificación Naïve Bayes<center>

# %% [markdown]
# <div align=justify> Los modelos de clasificación son usados extensamente en la actualidad para resolver problemas donde se requiere separar clases de elementos en un conjunto. El ejemplo clásico suele ser cuando se recibe un correo electrónico y mediante un algoritmo, se decide si el correo recibido pertenece a la categoría de <b>spam</b> o <b>no spam</b>. Cuando el conjunto que se requiere separar consta de palabras (como el ejemplo anterior), se le conoce como clasificación de textos. Dentro de las técnicas de clasificación en el aprendizaje supervisado que se aplican en la clasificación de textos, se encuentra el Clasificador Bayesiano Ingenuo o *Naïve Bayes*, esta técnica se fundamenta en teoría de probabilidad, especialmente en el Teorema de Bayes.
# </div>

# %% [markdown]
# <div align=justify> El objetivo de este trabajo es obtener una base de datos conformada por libros en formato  <b>.txt</b> de distintas categorías. Una vez obtenida la base de datos, aplicar el algoritmo del Clasificador Bayesiano Ingenuo para entrenar un modelo que sea capaz de clasificar un libro a partir de la frecuencia de las palabras que se encuentran en el libro. Para finalizar, ver los resultados obtenidos al introducir un libro en el modelo, lo que va a devolver una clase que identifique a qué categoría pertenece el libro. Cabe remarcar que toda la implementación del algoritmo, se desarrolla en el lenguaje de programación Python.
# </div>

# %% [markdown]
# ## Base teórica
# ### Teorema de Bayes
#
# Supongamos que $E_1, E_2, \dots, E_n$ son eventos mutuamente excluyentes en el espacio muestral $\Omega$ tales que $\cup_{i=1}^n E_i = \Omega$. Entonces
# \begin{equation}\label{principal}
# Pr(E_j | B) = \frac{Pr(E_j \cap B)}{Pr(B)} = \frac{Pr(B | E_j)Pr(E_j)}{\sum_{i=1}^n Pr(B | E_i) Pr(E_i)} \ \ \ \ \ \ \ \ \ (1)
# \end{equation}
#
# **Demostración:**
#
#     Tomemos
# \begin{equation}
# Pr(E_j | B) = \frac{Pr(E_j \cap B)}{Pr(B)},
# \end{equation}
# con esto, vemos que por la regla de multiplicación
# \begin{equation}\label{arg1}
# Pr(E_j \cap B) = Pr(B | E_j){Pr(B)}, \ \ \ \ \ \ \ \ \ (2)
# \end{equation}
# y por la Regla de Probabilidad Total, se obtiene
# \begin{equation}\label{arg2}
# Pr(B) = Pr(B|E_1)Pr(E_1) + \cdots + Pr(B|E_n)Pr(E_n) = \displaystyle\sum_{i=1}^n Pr(B|E_i)Pr(E_i). \ \ \ \ \ \ \ \ \ (3)
# \end{equation}
#
#
# Por las Ecuaciones $(2)$ y $(3)$, podemos obtener $(1)$
#
# $$\blacksquare$$

# %% [markdown]
# ### Algoritmo de Clasificación Bayesiano Ingenuo
#
# Este algoritmo sirve para entrenar un modelo que sea capaz de clasificar textos. Se tomó del libro *Probability and Computing: Randomization and Probabilistic Techniques in Algorithms and Data Analysis*, escrito por Michael Mitzenmacher y Eli Upfal en su segunda edición.
#
# **Entrada:** Conjunto $C$ de las clasificaciones posibles, conjunto de características $F_1,\dots,F_m$ con sus respectivos valores y un conjunto de entrenamiento que contiene libros y su respectiva clasificación.
#
# **Fase de entrenamiento:**
#
# 1. Para cada categoría $c \in  C$, característica $k = 1,\dots, m$ y valor de la característica $x_k \in F_k$, calcule
#
# \begin{equation*}
# \hat{Pr}(x_k^* = x_k 1 c(D^*) = c) = \frac{|\{ i: x_k^i = x_k, c(D_i) = c \}|}{\{ i | c(D_i) = c \}}.
# \end{equation*}
#
# 2. Para cada categoría $c \in C$, calcular
# \begin{equation*}
# \hat{Pr}(c(D^*)=c)=\frac{\{ i | c(D_i) = c \}}{|D|}.
# \end{equation*}
#
# **Clasificación de un nuevo item $D^*$.**
#
# 1. Para alcular la mayor probabilidad de clasificación para $x^* = x = (x_1,\dots,x_m)$.
# \begin{equation}\label{perro}
# c(D^*) = arg\ \max_{c_j \in C} \left( \prod_{k=1}^m \hat{Pr} (x_k^* = x_k | c(D^*) = c_j) \right) \hat{Pr}(c(D^*)=c_j). \ \ \ \ \ \ \ \ \ (4)
# \end{equation}
#
# 2. Para calcular una distribución de clasificación
# \begin{equation*}
# \hat{Pr}(c(D^*)=c_j) = \frac{\left( \prod_{k=1}^m \hat{Pr} (x_k^* = x_k | c(D^*) = c_j) \right)\hat{Pr}(c(D^*)=c_j)}{\hat{Pr}(x^* = x)}
# \end{equation*}

# %% [markdown]
# ### Log probabilidades para Naïve Bayes
# <div align=justify>Para el caso de la clasificación de textos nos encontramos con una limitación computacional cuando implementamos el algoritmo anterior. Esto sucede cuando la cantidad de características (en el caso de clasificación de textos las características son palabras) es muy grande, lo que lleva a obtener números extremadamente pequeños al calcular las probabilidades que no son representables en Python. Esto se puede resolver aplicando el logaritmo al cálculo de las probabilidades. Esto es posible por dos propiedades de los logaritmos que se muestran a continuación. </div>
#
#
# - Dados dos números $a$ y $b$, tales que $a<b$, aplicando los logaritmos obtenemos que ln $a<$ln $b$.
# - El logaritmo de un producto es la suma de los logaritmos. ln $ab$ = ln $a$ $+$ ln $b$.
#
#
# Aplicando estas propiedades de los logaritmos a la Ecuación $(4)$, vemos que queda de la siguiente forma.
# \begin{equation}
# c(D^*) = arg\ \max_{c_j \in C} \left( \sum_{k=1}^m ln\ \hat{Pr} (x_k^* = x_k | c(D^*) = c_j) \right) + ln\ \hat{Pr}(c(D^*)=c_j).
# \end{equation}

# %% [markdown]
# ## Metodología
#
# <div align=justify>Para aplicar el Algoritmo de Clasificación Bayesiano Ingenuo primero requerimos de crear nuestra base de datos, para esto se descargaron libros en formato de texto simple (o <b>txt</b>) de la página https://www.gutenberg.org/ que pertenece a un proyecto de biblioteca virtual llamado Proyecto Gutenberg, aquí se encuentran libros electrónicos en distintos formatos y de carácter gratuito.</div>
#
# La base de datos conformada por los libros que recolectamos contaba con las siguientes categorías:
# - Astronomy: 16 libros.
# - Biology: 16 libros.
# - Cook: 16 libros.
# - Love: 8 libros.
# - Math: 10 libros.
# - Scifi: 15 libros.

# %% [markdown]
# <div align=justify>
# La primer parte se encarga de definir funciones. La primer función elimina símbolos, tales como los signos de puntuación. La segunda función se encarga de abrir los archivos de texto simple como una cadena de caracteres para después separar la cadena en un arreglo que contiene todas las palabras detectadas en la cadena. Luego de obtener el arreglo, cuenta la ocurrencia de cada palabra.</div>

# %%
from math import log
from numpy import argmax, log
import os
from random import shuffle

# %%
def elimina_simbolos(palabra):
    palabra = "".join(k for k in palabra if k.isalpha())
    return palabra.lower()

def obtener_frequencias(archivo, clase, clases, frecuencias= dict(), frecuencias_clases= dict()):
    print("abriendo archivos ", archivo)
    f=open(archivo)
    print("cargando texto")
    libro=f.read()
    print("generando lista palabras")
    palabras = libro.split() # este paso puede ser caro en archivos grandes

    print("contando palabras")
    for i in palabras:
        i = "".join(k for k in i if k.isalpha())
        i = i.lower()
        try:
            frecuencias[i][clase] += 1 
        except:
            frecuencias[i] = dict((c, 0) for c in clases)
            frecuencias[i][clase] += 1 
            
        try:
            frecuencias_clases[clase] += 1
        except:
            frecuencias_clases[clase] = 1

    return frecuencias, frecuencias_clases

# %% [markdown]
# A continuación escribimos las clases a las que puede pertenecer el libro e introducimos todos los nombres de los libros que pertenecen a cada categoría para poder hacer una división de cada clase en un 80% de los libros para entrenar el modelo y el 20% para probarlo.

# %%
clases = ["scifi", "love", "math", "biology", "astronomy", "cook"]


todos_los_libros = dict( (c, []) for c in clases )
libros_train = dict( (c, []) for c in clases )
libros_test = dict( (c, []) for c in clases )

for clase in clases:
    i = 1
    while True:
        archivo_txt = "books/"+clase+str(i)+".txt"
        #
        
        if not os.path.exists(archivo_txt):
            break
        
        todos_los_libros[clase].append( archivo_txt)
        i += 1
    
    idx = list(range(1, 1+len(todos_los_libros[clase])))
    shuffle(idx)
    n = int(len(idx)*0.8)
    libros_train[clase] = idx[:n]
    libros_test[clase] = idx[n:]

# %%
libros_train,libros_test
# Out:
# ({'astronomy': [11, 3, 5, 1, 12, 16, 4, 10, 2, 13, 15, 7],
#   'biology': [1, 3, 16, 2, 13, 10, 5, 11, 15, 8, 6, 12],
#   'cook': [2, 8, 9, 14, 16, 7, 13, 11, 10, 6, 3, 12],
#   'love': [5, 2, 8, 1, 4, 7],
#   'math': [1, 6, 5, 9, 8, 2, 10, 3],
#   'scifi': [7, 12, 1, 15, 3, 10, 2, 13, 6, 4, 8, 11]},
#  {'astronomy': [8, 9, 14, 6],
#   'biology': [14, 9, 7, 4],
#   'cook': [15, 5, 1, 4],
#   'love': [3, 6],
#   'math': [7, 4],
#   'scifi': [5, 14, 9]})

# %% [markdown]
# Lo siguiente es leer los libros del conjunto de entrenamiento y ver las frecuencias de las palabras aplicando la función definida anteriormente.

# %%
frecuencias = dict()
frecuencas_clases = dict()

for clase in clases:
    for i in libros_train[clase]:
        archivo_txt = todos_los_libros[clase][i-1]
        print(archivo_txt)
        frecuencias, frecuencas_clases = obtener_frequencias(archivo_txt, clase,clases, frecuencias, frecuencas_clases)
# Out:
# books/scifi7.txt
# abriendo archivos  books/scifi7.txt
# cargando texto
# generando lista palabras
# contando palabras
# books/scifi12.txt
# abriendo archivos  books/scifi12.txt
# cargando texto
# generando lista palabras
# contando palabras
# books/scifi1.txt
# abriendo archivos  books/scifi1.txt
# cargando texto
# generando lista palabras
# contando palabras
# books/scifi15.txt
# abriendo archivos  books/scifi15.txt
# cargando texto
# generando lista palabras
# contando palabras
# books/scifi3.txt
# abriendo archivos  books/scifi3.txt
# cargando texto
# generando lista palabras
# contando palabras
# books/scifi10.txt
# abriendo archivos  books/scifi10.txt
# cargando texto
# generando lista palabras
# contando palabras
# books/scifi2.txt
# abriendo archivos  books/scifi2.txt
# cargando texto
# generando lista palabras
# contando palabras
# books/scifi13.txt
# abriendo archivos  books/scifi13.txt
# cargando texto
# generando lista palabras
# contando palabras
# books/scifi6.txt
# abriendo archivos  books/scifi6.txt
# cargando texto
# generando lista palabras
# contando palabras
# books/scifi4.txt
# abriendo archivos  books/scifi4.txt
# cargando texto
# generando lista palabras
# contando palabras
# books/scifi8.txt
# abriendo archivos  books/scifi8.txt
# cargando texto
# generando lista palabras
# contando palabras
# books/scifi11.txt
# abriendo archivos  books/scifi11.txt
# cargando texto
# generando lista palabras
# contando palabras
# books/love5.txt
# abriendo archivos  books/love5.txt
# cargando texto
# generando lista palabras
# contando palabras
# books/love2.txt
# abriendo archivos  books/love2.txt
# cargando texto
# generando lista palabras
# contando palabras
# books/love8.txt
# abriendo archivos  books/love8.txt
# cargando texto
# generando lista palabras
# contando palabras
# books/love1.txt
# abriendo archivos  books/love1.txt
# cargando texto
# generando lista palabras
# contando palabras
# books/love4.txt
# abriendo archivos  books/love4.txt
# cargando texto
# generando lista palabras
# contando palabras
# books/love7.txt
# abriendo archivos  books/love7.txt
# cargando texto
# generando lista palabras
# contando palabras
# books/math1.txt
# abriendo archivos  books/math1.txt
# cargando texto
# generando lista palabras
# contando palabras
# books/math6.txt
# abriendo archivos  books/math6.txt
# cargando texto
# generando lista palabras
# contando palabras
# books/math5.txt
# abriendo archivos  books/math5.txt
# cargando texto
# generando lista palabras
# contando palabras
# books/math9.txt
# abriendo archivos  books/math9.txt
# cargando texto
# generando lista palabras
# contando palabras
# books/math8.txt
# abriendo archivos  books/math8.txt
# cargando texto
# generando lista palabras
# contando palabras
# books/math2.txt
# abriendo archivos  books/math2.txt
# cargando texto
# generando lista palabras
# contando palabras
# books/math10.txt
# abriendo archivos  books/math10.txt
# cargando texto
# generando lista palabras
# contando palabras
# books/math3.txt
# abriendo archivos  books/math3.txt
# cargando texto
# generando lista palabras
# contando palabras
# books/biology1.txt
# abriendo archivos  books/biology1.txt
# cargando texto
# generando lista palabras
# contando palabras
# books/biology3.txt
# abriendo archivos  books/biology3.txt
# cargando texto
# generando lista palabras
# contando palabras
# books/biology16.txt
# abriendo archivos  books/biology16.txt
# cargando texto
# generando lista palabras
# contando palabras
# books/biology2.txt
# abriendo archivos  books/biology2.txt
# cargando texto
# generando lista palabras
# contando palabras
# books/biology13.txt
# abriendo archivos  books/biology13.txt
# cargando texto
# generando lista palabras
# contando palabras
# books/biology10.txt
# abriendo archivos  books/biology10.txt
# cargando texto
# generando lista palabras
# contando palabras
# books/biology5.txt
# abriendo archivos  books/biology5.txt
# cargando texto
# generando lista palabras
# contando palabras
# books/biology11.txt
# abriendo archivos  books/biology11.txt
# cargando texto
# generando lista palabras
# contando palabras
# books/biology15.txt
# abriendo archivos  books/biology15.txt
# cargando texto
# generando lista palabras
# contando palabras
# books/biology8.txt
# abriendo archivos  books/biology8.txt
# cargando texto
# generando lista palabras
# contando palabras
# books/biology6.txt
# abriendo archivos  books/biology6.txt
# cargando texto
# generando lista palabras
# contando palabras
# books/biology12.txt
# abriendo archivos  books/biology12.txt
# cargando texto
# generando lista palabras
# contando palabras
# books/astronomy11.txt
# abriendo archivos  books/astronomy11.txt
# cargando texto
# generando lista palabras
# contando palabras
# books/astronomy3.txt
# abriendo archivos  books/astronomy3.txt
# cargando texto
# generando lista palabras
# contando palabras
# books/astronomy5.txt
# abriendo archivos  books/astronomy5.txt
# cargando texto
# generando lista palabras
# contando palabras
# books/astronomy1.txt
# abriendo archivos  books/astronomy1.txt
# cargando texto
# generando lista palabras
# contando palabras
# books/astronomy12.txt
# abriendo archivos  books/astronomy12.txt
# cargando texto
# generando lista palabras
# contando palabras
# books/astronomy16.txt
# abriendo archivos  books/astronomy16.txt
# cargando texto
# generando lista palabras
# contando palabras
# books/astronomy4.txt
# abriendo archivos  books/astronomy4.txt
# cargando texto
# generando lista palabras
# contando palabras
# books/astronomy10.txt
# abriendo archivos  books/astronomy10.txt
# cargando texto
# generando lista palabras
# contando palabras
# books/astronomy2.txt
# abriendo archivos  books/astronomy2.txt
# cargando texto
# generando lista palabras
# contando palabras
# books/astronomy13.txt
# abriendo archivos  books/astronomy13.txt
# cargando texto
# generando lista palabras
# contando palabras
# books/astronomy15.txt
# abriendo archivos  books/astronomy15.txt
# cargando texto
# generando lista palabras
# contando palabras
# books/astronomy7.txt
# abriendo archivos  books/astronomy7.txt
# cargando texto
# generando lista palabras
# contando palabras
# books/cook2.txt
# abriendo archivos  books/cook2.txt
# cargando texto
# generando lista palabras
# contando palabras
# books/cook8.txt
# abriendo archivos  books/cook8.txt
# cargando texto
# generando lista palabras
# contando palabras
# books/cook9.txt
# abriendo archivos  books/cook9.txt
# cargando texto
# generando lista palabras
# contando palabras
# books/cook14.txt
# abriendo archivos  books/cook14.txt
# cargando texto
# generando lista palabras
# contando palabras
# books/cook16.txt
# abriendo archivos  books/cook16.txt
# cargando texto
# generando lista palabras
# contando palabras
# books/cook7.txt
# abriendo archivos  books/cook7.txt
# cargando texto
# generando lista palabras
# contando palabras
# books/cook13.txt
# abriendo archivos  books/cook13.txt
# cargando texto
# generando lista palabras
# contando palabras
# books/cook11.txt
# abriendo archivos  books/cook11.txt
# cargando texto
# generando lista palabras
# contando palabras
# books/cook10.txt
# abriendo archivos  books/cook10.txt
# cargando texto
# generando lista palabras
# contando palabras
# books/cook6.txt
# abriendo archivos  books/cook6.txt
# cargando texto
# generando lista palabras
# contando palabras
# books/cook3.txt
# abriendo archivos  books/cook3.txt
# cargando texto
# generando lista palabras
# contando palabras
# books/cook12.txt
# abriendo archivos  books/cook12.txt
# cargando texto
# generando lista palabras
# contando palabras

# %%
frecuencas_clases
# Out:
# {'astronomy': 1091746,
#  'biology': 1414385,
#  'cook': 664775,
#  'love': 662069,
#  'math': 445983,
#  'scifi': 918461}

# %%
frecuencias
# Out:
# {'the': {'astronomy': 94904,
#   'biology': 111815,
#   'cook': 33429,
#   'love': 26835,
#   'math': 31435,
#   'scifi': 63892},
#  'project': {'astronomy': 1060,
#   'biology': 1070,
#   'cook': 1050,
#   'love': 535,
#   'math': 9,
#   'scifi': 1084},
#  'gutenberg': {'astronomy': 413,
#   'biology': 358,
#   'cook': 360,
#   'love': 179,
#   'math': 0,
#   'scifi': 359},
#  'ebook': {'astronomy': 137,
#   'biology': 128,
#   'cook': 141,
#   'love': 65,
#   'math': 0,
#   'scifi': 131},
#  'of': {'astronomy': 58857,
#   'biology': 73111,
#   'cook': 22348,
#   'love': 18868,
#   'math': 19996,
#   'scifi': 35403},
#  'a': {'astronomy': 19855,
#   'biology': 26811,
#   'cook': 16435,
#   'love': 13025,
#   'math': 12643,
#   'scifi': 18676},
#  'trip': {'astronomy': 2,
#   'biology': 9,
#   'cook': 1,
#   'love': 7,
#   'math': 0,
#   'scifi': 42},
#  'to': {'astronomy': 24243,
#   'biology': 29596,
#   'cook': 10965,
#   'love': 20872,
#   'math': 7105,
#   'scifi': 24380},
#  'venus': {'astronomy': 296,
#   'biology': 18,
#   'cook': 0,
#   'love': 1,
#   'math': 4,
#   'scifi': 94},
#  'by': {'astronomy': 8849,
#   'biology': 11880,
#   'cook': 2551,
#   'love': 2712,
#   'math': 3870,
#   'scifi': 4935},
#  'john': {'astronomy': 190,
#   'biology': 101,
#   'cook': 108,
#   'love': 94,
#   'math': 78,
#   'scifi': 218},
#  'munro': {'astronomy': 1,
#   'biology': 1,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 4},
#  'this': {'astronomy': 6460,
#   'biology': 7894,
#   'cook': 3079,
#   'love': 2432,
#   'math': 2176,
#   'scifi': 4930},
#  'is': {'astronomy': 12797,
#   'biology': 17224,
#   'cook': 6963,
#   'love': 4081,
#   'math': 7435,
#   'scifi': 5535},
#  'for': {'astronomy': 6095,
#   'biology': 8485,
#   'cook': 4009,
#   'love': 5481,
#   'math': 2631,
#   'scifi': 6366},
#  'use': {'astronomy': 525,
#   'biology': 676,
#   'cook': 613,
#   'love': 205,
#   'math': 243,
#   'scifi': 314},
#  'anyone': {'astronomy': 72,
#   'biology': 79,
#   'cook': 75,
#   'love': 62,
#   'math': 0,
#   'scifi': 88},
#  'anywhere': {'astronomy': 40,
#   'biology': 58,
#   'cook': 28,
#   'love': 43,
#   'math': 8,
#   'scifi': 41},
#  'at': {'astronomy': 5834,
#   'biology': 5785,
#   'cook': 3062,
#   'love': 4308,
#   'math': 1383,
#   'scifi': 5196},
#  'no': {'astronomy': 2211,
#   'biology': 3016,
#   'cook': 1516,
#   'love': 2415,
#   'math': 257,
#   'scifi': 2395},
#  'cost': {'astronomy': 104,
#   'biology': 111,
#   'cook': 60,
#   'love': 38,
#   'math': 116,
#   'scifi': 65},
#  'and': {'astronomy': 30905,
#   'biology': 39719,
#   'cook': 22168,
#   'love': 20290,
#   'math': 8114,
#   'scifi': 29109},
#  'with': {'astronomy': 7293,
#   'biology': 10226,
#   'cook': 8248,
#   'love': 5633,
#   'math': 1433,
#   'scifi': 7851},
#  'almost': {'astronomy': 597,
#   'biology': 794,
#   'cook': 299,
#   'love': 380,
#   'math': 5,
#   'scifi': 405},
#  'restrictions': {'astronomy': 28,
#   'biology': 31,
#   'cook': 24,
#   'love': 13,
#   'math': 1,
#   'scifi': 32},
#  'whatsoever': {'astronomy': 28,
#   'biology': 25,
#   'cook': 25,
#   'love': 13,
#   'math': 0,
#   'scifi': 30},
#  'you': {'astronomy': 1279,
#   'biology': 1275,
#   'cook': 1605,
#   'love': 7270,
#   'math': 82,
#   'scifi': 4670},
#  'may': {'astronomy': 2135,
#   'biology': 3532,
#   'cook': 1175,
#   'love': 1014,
#   'math': 1492,
#   'scifi': 1089},
#  'copy': {'astronomy': 172,
#   'biology': 160,
#   'cook': 147,
#   'love': 81,
#   'math': 4,
#   'scifi': 154},
#  'it': {'astronomy': 10660,
#   'biology': 11528,
#   'cook': 6541,
#   'love': 8271,
#   'math': 1990,
#   'scifi': 8470},
#  'give': {'astronomy': 358,
#   'biology': 496,
#   'cook': 181,
#   'love': 525,
#   'math': 141,
#   'scifi': 372},
#  'away': {'astronomy': 334,
#   'biology': 441,
#   'cook': 178,
#   'love': 621,
#   'math': 33,
#   'scifi': 581},
#  'or': {'astronomy': 5788,
#   'biology': 10426,
#   'cook': 8462,
#   'love': 2293,
#   'math': 1716,
#   'scifi': 3584},
#  'reuse': {'astronomy': 24,
#   'biology': 24,
#   'cook': 24,
#   'love': 12,
#   'math': 0,
#   'scifi': 24},
#  'under': {'astronomy': 662,
#   'biology': 1252,
#   'cook': 404,
#   'love': 361,
#   'math': 123,
#   'scifi': 623},
#  'terms': {'astronomy': 318,
#   'biology': 410,
#   'cook': 264,
#   'love': 178,
#   'math': 551,
#   'scifi': 331},
#  'license': {'astronomy': 179,
#   'biology': 231,
#   'cook': 180,
#   'love': 93,
#   'math': 0,
#   'scifi': 187},
#  'included': {'astronomy': 104,
#   'biology': 122,
#   'cook': 60,
#   'love': 36,
#   'math': 30,
#   'scifi': 47},
#  'online': {'astronomy': 65,
#   'biology': 62,
#   'cook': 68,
#   'love': 24,
#   'math': 0,
#   'scifi': 56},
#  'wwwgutenbergnet': {'astronomy': 12,
#   'biology': 3,
#   'cook': 12,
#   'love': 3,
#   'math': 0,
#   'scifi': 15},
#  'title': {'astronomy': 63,
#   'biology': 65,
#   'cook': 15,
#   'love': 13,
#   'math': 2,
#   'scifi': 41},
#  'author': {'astronomy': 105,
#   'biology': 99,
#   'cook': 68,
#   'love': 11,
#   'math': 38,
#   'scifi': 44},
#  'release': {'astronomy': 19,
#   'biology': 11,
#   'cook': 14,
#   'love': 12,
#   'math': 0,
#   'scifi': 25},
#  'date': {'astronomy': 204,
#   'biology': 201,
#   'cook': 69,
#   'love': 39,
#   'math': 6,
#   'scifi': 57},
#  'october': {'astronomy': 62,
#   'biology': 44,
#   'cook': 207,
#   'love': 11,
#   'math': 3,
#   'scifi': 36},
#  '': {'astronomy': 24685,
#   'biology': 18769,
#   'cook': 18264,
#   'love': 618,
#   'math': 67593,
#   'scifi': 1934},
#  'language': {'astronomy': 107,
#   'biology': 240,
#   'cook': 22,
#   'love': 47,
#   'math': 23,
#   'scifi': 121},
#  'english': {'astronomy': 127,
#   'biology': 224,
#   'cook': 172,
#   'love': 48,
#   'math': 40,
#   'scifi': 194},
#  'character': {'astronomy': 268,
#   'biology': 516,
#   'cook': 104,
#   'love': 194,
#   'math': 15,
#   'scifi': 136},
#  'set': {'astronomy': 467,
#   'biology': 450,
#   'cook': 447,
#   'love': 254,
#   'math': 34,
#   'scifi': 422},
#  'encoding': {'astronomy': 5,
#   'biology': 2,
#   'cook': 4,
#   'love': 6,
#   'math': 0,
#   'scifi': 12},
#  'utf': {'astronomy': 5,
#   'biology': 2,
#   'cook': 4,
#   'love': 4,
#   'math': 0,
#   'scifi': 3},
#  'start': {'astronomy': 49,
#   'biology': 64,
#   'cook': 47,
#   'love': 51,
#   'math': 9,
#   'scifi': 116},
#  'produced': {'astronomy': 302,
#   'biology': 633,
#   'cook': 91,
#   'love': 69,
#   'math': 23,
#   'scifi': 101},
#  'steven': {'astronomy': 0,
#   'biology': 0,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 2},
#  'desjardins': {'astronomy': 0,
#   'biology': 0,
#   'cook': 2,
#   'love': 0,
#   'math': 0,
#   'scifi': 2},
#  'distributed': {'astronomy': 117,
#   'biology': 105,
#   'cook': 78,
#   'love': 26,
#   'math': 4,
#   'scifi': 65},
#  'proofreaders': {'astronomy': 0,
#   'biology': 0,
#   'cook': 4,
#   'love': 0,
#   'math': 0,
#   'scifi': 2},
#  'novel': {'astronomy': 21,
#   'biology': 12,
#   'cook': 5,
#   'love': 7,
#   'math': 0,
#   'scifi': 17},
#  'wire': {'astronomy': 44,
#   'biology': 28,
#   'cook': 34,
#   'love': 4,
#   'math': 1,
#   'scifi': 29},
#  'wave': {'astronomy': 40,
#   'biology': 23,
#   'cook': 8,
#   'love': 9,
#   'math': 1,
#   'scifi': 64},
#  'story': {'astronomy': 94,
#   'biology': 70,
#   'cook': 28,
#   'love': 59,
#   'math': 4,
#   'scifi': 146},
#  'electricity': {'astronomy': 117,
#   'biology': 37,
#   'cook': 1,
#   'love': 1,
#   'math': 3,
#   'scifi': 29},
#  'etc': {'astronomy': 175,
#   'biology': 265,
#   'cook': 364,
#   'love': 24,
#   'math': 111,
#   'scifi': 13},
#  'published': {'astronomy': 171,
#   'biology': 199,
#   'cook': 43,
#   'love': 3,
#   'math': 52,
#   'scifi': 13},
#  'in': {'astronomy': 25616,
#   'biology': 36962,
#   'cook': 15343,
#   'love': 10207,
#   'math': 5785,
#   'scifi': 15154},
#  'jarrold': {'astronomy': 0,
#   'biology': 3,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 1},
#  'sons': {'astronomy': 51,
#   'biology': 53,
#   'cook': 1,
#   'love': 29,
#   'math': 13,
#   'scifi': 15},
#  'london': {'astronomy': 105,
#   'biology': 282,
#   'cook': 44,
#   'love': 202,
#   'math': 11,
#   'scifi': 262},
#  'contents': {'astronomy': 43,
#   'biology': 82,
#   'cook': 75,
#   'love': 14,
#   'math': 28,
#   'scifi': 35},
#  'chapter': {'astronomy': 313,
#   'biology': 520,
#   'cook': 80,
#   'love': 247,
#   'math': 147,
#   'scifi': 314},
#  'i': {'astronomy': 2226,
#   'biology': 4354,
#   'cook': 1244,
#   'love': 9852,
#   'math': 1964,
#   'scifi': 15504},
#  'message': {'astronomy': 14,
#   'biology': 4,
#   'cook': 1,
#   'love': 31,
#   'math': 0,
#   'scifi': 38},
#  'from': {'astronomy': 5972,
#   'biology': 7910,
#   'cook': 2516,
#   'love': 2513,
#   'math': 1757,
#   'scifi': 5047},
#  'mars': {'astronomy': 322,
#   'biology': 9,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 220},
#  'ii': {'astronomy': 312,
#   'biology': 367,
#   'cook': 18,
#   'love': 17,
#   'math': 190,
#   'scifi': 38},
#  'how': {'astronomy': 605,
#   'biology': 944,
#   'cook': 219,
#   'love': 1119,
#   'math': 608,
#   'scifi': 755},
#  'can': {'astronomy': 1455,
#   'biology': 2254,
#   'cook': 784,
#   'love': 1020,
#   'math': 568,
#   'scifi': 1057},
#  'we': {'astronomy': 4284,
#   'biology': 5450,
#   'cook': 643,
#   'love': 1341,
#   'math': 3953,
#   'scifi': 5926},
#  'get': {'astronomy': 119,
#   'biology': 166,
#   'cook': 226,
#   'love': 377,
#   'math': 141,
#   'scifi': 285},
#  'other': {'astronomy': 2227,
#   'biology': 4366,
#   'cook': 872,
#   'love': 975,
#   'math': 814,
#   'scifi': 1401},
#  'planets': {'astronomy': 775,
#   'biology': 36,
#   'cook': 0,
#   'love': 1,
#   'math': 5,
#   'scifi': 77},
#  'iii': {'astronomy': 192,
#   'biology': 173,
#   'cook': 21,
#   'love': 9,
#   'math': 64,
#   'scifi': 31},
#  'new': {'astronomy': 1059,
#   'biology': 1467,
#   'cook': 720,
#   'love': 450,
#   'math': 268,
#   'scifi': 543},
#  'force': {'astronomy': 517,
#   'biology': 337,
#   'cook': 17,
#   'love': 36,
#   'math': 84,
#   'scifi': 296},
#  'iv': {'astronomy': 96,
#   'biology': 100,
#   'cook': 17,
#   'love': 6,
#   'math': 90,
#   'scifi': 26},
#  'electric': {'astronomy': 249,
#   'biology': 51,
#   'cook': 5,
#   'love': 13,
#   'math': 0,
#   'scifi': 53},
#  'orrery': {'astronomy': 1,
#   'biology': 0,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 5},
#  'v': {'astronomy': 132,
#   'biology': 103,
#   'cook': 38,
#   'love': 13,
#   'math': 778,
#   'scifi': 39},
#  'leaving': {'astronomy': 60,
#   'biology': 109,
#   'cook': 62,
#   'love': 92,
#   'math': 4,
#   'scifi': 125},
#  'earth': {'astronomy': 2379,
#   'biology': 306,
#   'cook': 52,
#   'love': 32,
#   'math': 6,
#   'scifi': 756},
#  'vi': {'astronomy': 73,
#   'biology': 49,
#   'cook': 20,
#   'love': 6,
#   'math': 55,
#   'scifi': 24},
#  'space': {'astronomy': 617,
#   'biology': 241,
#   'cook': 25,
#   'love': 19,
#   'math': 39,
#   'scifi': 609},
#  'vii': {'astronomy': 69,
#   'biology': 41,
#   'cook': 11,
#   'love': 6,
#   'math': 25,
#   'scifi': 20},
#  'arriving': {'astronomy': 14,
#   'biology': 17,
#   'cook': 2,
#   'love': 11,
#   'math': 1,
#   'scifi': 10},
#  'viii': {'astronomy': 69,
#   'biology': 21,
#   'cook': 11,
#   'love': 6,
#   'math': 21,
#   'scifi': 22},
#  'crater': {'astronomy': 121,
#   'biology': 6,
#   'cook': 6,
#   'love': 0,
#   'math': 0,
#   'scifi': 56},
#  'land': {'astronomy': 323,
#   'biology': 423,
#   'cook': 36,
#   'love': 21,
#   'math': 9,
#   'scifi': 189},
#  'ix': {'astronomy': 62,
#   'biology': 25,
#   'cook': 10,
#   'love': 6,
#   'math': 107,
#   'scifi': 20},
#  'flower': {'astronomy': 78,
#   'biology': 96,
#   'cook': 18,
#   'love': 10,
#   'math': 0,
#   'scifi': 44},
#  'soul': {'astronomy': 49,
#   'biology': 33,
#   'cook': 8,
#   'love': 38,
#   'math': 0,
#   'scifi': 209},
#  'x': {'astronomy': 89,
#   'biology': 50,
#   'cook': 211,
#   'love': 7,
#   'math': 6143,
#   'scifi': 60},
#  'alumion': {'astronomy': 0,
#   'biology': 0,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 32},
#  'xi': {'astronomy': 53,
#   'biology': 26,
#   'cook': 5,
#   'love': 6,
#   'math': 76,
#   'scifi': 15},
#  'flying': {'astronomy': 47,
#   'biology': 67,
#   'cook': 3,
#   'love': 6,
#   'math': 0,
#   'scifi': 59},
#  'ape': {'astronomy': 2,
#   'biology': 55,
#   'cook': 2,
#   'love': 0,
#   'math': 1,
#   'scifi': 108},
#  'xii': {'astronomy': 44,
#   'biology': 27,
#   'cook': 11,
#   'love': 6,
#   'math': 14,
#   'scifi': 15},
#  'sunward': {'astronomy': 8,
#   'biology': 0,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 5},
#  'ho': {'astronomy': 4,
#   'biology': 3,
#   'cook': 1,
#   'love': 0,
#   'math': 21,
#   'scifi': 4},
#  'xiii': {'astronomy': 28,
#   'biology': 21,
#   'cook': 8,
#   'love': 6,
#   'math': 9,
#   'scifi': 14},
#  'home': {'astronomy': 124,
#   'biology': 118,
#   'cook': 53,
#   'love': 420,
#   'math': 7,
#   'scifi': 194},
#  'again': {'astronomy': 558,
#   'biology': 637,
#   'cook': 201,
#   'love': 825,
#   'math': 163,
#   'scifi': 925},
#  'heaven': {'astronomy': 384,
#   'biology': 22,
#   'cook': 3,
#   'love': 41,
#   'math': 0,
#   'scifi': 107},
#  'that': {'astronomy': 12834,
#   'biology': 17055,
#   'cook': 2345,
#   'love': 7791,
#   'math': 3728,
#   'scifi': 10761},
#  'rolls': {'astronomy': 8,
#   'biology': 7,
#   'cook': 94,
#   'love': 3,
#   'math': 2,
#   'scifi': 3},
#  'around': {'astronomy': 214,
#   'biology': 188,
#   'cook': 166,
#   'love': 108,
#   'math': 9,
#   'scifi': 266},
#  'cries': {'astronomy': 9,
#   'biology': 49,
#   'cook': 1,
#   'love': 2,
#   'math': 0,
#   'scifi': 55},
#  'aloud': {'astronomy': 6,
#   'biology': 3,
#   'cook': 0,
#   'love': 43,
#   'math': 0,
#   'scifi': 51},
#  'while': {'astronomy': 821,
#   'biology': 855,
#   'cook': 274,
#   'love': 471,
#   'math': 85,
#   'scifi': 959},
#  'displays': {'astronomy': 17,
#   'biology': 23,
#   'cook': 0,
#   'love': 2,
#   'math': 0,
#   'scifi': 9},
#  'its': {'astronomy': 3829,
#   'biology': 3444,
#   'cook': 1257,
#   'love': 833,
#   'math': 838,
#   'scifi': 2011},
#  'eternal': {'astronomy': 65,
#   'biology': 15,
#   'cook': 5,
#   'love': 15,
#   'math': 0,
#   'scifi': 80},
#  'harmony': {'astronomy': 41,
#   'biology': 83,
#   'cook': 9,
#   'love': 17,
#   'math': 1,
#   'scifi': 29},
#  'yet': {'astronomy': 803,
#   'biology': 980,
#   'cook': 101,
#   'love': 431,
#   'math': 23,
#   'scifi': 769},
#  'your': {'astronomy': 252,
#   'biology': 261,
#   'cook': 389,
#   'love': 1706,
#   'math': 45,
#   'scifi': 1174},
#  'eyes': {'astronomy': 169,
#   'biology': 272,
#   'cook': 33,
#   'love': 445,
#   'math': 0,
#   'scifi': 841},
#  'are': {'astronomy': 5823,
#   'biology': 11389,
#   'cook': 3011,
#   'love': 1620,
#   'math': 2631,
#   'scifi': 2665},
#  'fixed': {'astronomy': 271,
#   'biology': 135,
#   'cook': 20,
#   'love': 93,
#   'math': 504,
#   'scifi': 140},
#  'upon': {'astronomy': 1408,
#   'biology': 774,
#   'cook': 457,
#   'love': 447,
#   'math': 135,
#   'scifi': 2369},
#  'alone': {'astronomy': 185,
#   'biology': 490,
#   'cook': 76,
#   'love': 184,
#   'math': 14,
#   'scifi': 392},
#  'dante': {'astronomy': 9,
#   'biology': 1,
#   'cook': 0,
#   'love': 1,
#   'math': 0,
#   'scifi': 2},
#  'truth': {'astronomy': 286,
#   'biology': 173,
#   'cook': 14,
#   'love': 122,
#   'math': 22,
#   'scifi': 158},
#  'within': {'astronomy': 420,
#   'biology': 530,
#   'cook': 235,
#   'love': 178,
#   'math': 20,
#   'scifi': 498},
#  'thy': {'astronomy': 199,
#   'biology': 15,
#   'cook': 9,
#   'love': 5,
#   'math': 0,
#   'scifi': 89},
#  'mind': {'astronomy': 250,
#   'biology': 406,
#   'cook': 50,
#   'love': 463,
#   'math': 14,
#   'scifi': 490},
#  'rehearse': {'astronomy': 0,
#   'biology': 0,
#   'cook': 0,
#   'love': 10,
#   'math': 0,
#   'scifi': 2},
#  'boúndless': {'astronomy': 0,
#   'biology': 0,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 1},
#  'universe': {'astronomy': 412,
#   'biology': 15,
#   'cook': 3,
#   'love': 2,
#   'math': 2,
#   'scifi': 140},
#  'boundless': {'astronomy': 23,
#   'biology': 7,
#   'cook': 1,
#   'love': 2,
#   'math': 0,
#   'scifi': 12},
#  'better': {'astronomy': 192,
#   'biology': 277,
#   'cook': 215,
#   'love': 504,
#   'math': 10,
#   'scifi': 256},
#  'worse': {'astronomy': 12,
#   'biology': 23,
#   'cook': 13,
#   'love': 101,
#   'math': 0,
#   'scifi': 67},
#  'think': {'astronomy': 139,
#   'biology': 317,
#   'cook': 68,
#   'love': 1186,
#   'math': 60,
#   'scifi': 409},
#  'mould': {'astronomy': 7,
#   'biology': 12,
#   'cook': 70,
#   'love': 2,
#   'math': 0,
#   'scifi': 11},
#  'hopes': {'astronomy': 19,
#   'biology': 10,
#   'cook': 5,
#   'love': 87,
#   'math': 3,
#   'scifi': 106},
#  'fears': {'astronomy': 16,
#   'biology': 2,
#   'cook': 0,
#   'love': 54,
#   'math': 1,
#   'scifi': 83},
#  'could': {'astronomy': 1075,
#   'biology': 833,
#   'cook': 132,
#   'love': 2570,
#   'math': 33,
#   'scifi': 2121},
#  'find': {'astronomy': 504,
#   'biology': 629,
#   'cook': 103,
#   'love': 310,
#   'math': 1007,
#   'scifi': 449},
#  'statelier': {'astronomy': 0,
#   'biology': 0,
#   'cook': 0,
#   'love': 1,
#   'math': 0,
#   'scifi': 1},
#  'than': {'astronomy': 2059,
#   'biology': 2993,
#   'cook': 746,
#   'love': 1416,
#   'math': 479,
#   'scifi': 1372},
#  'his': {'astronomy': 5565,
#   'biology': 2955,
#   'cook': 513,
#   'love': 5929,
#   'math': 295,
#   'scifi': 7210},
#  'peers': {'astronomy': 4,
#   'biology': 2,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 5},
#  'yonder': {'astronomy': 5,
#   'biology': 25,
#   'cook': 4,
#   'love': 0,
#   'math': 0,
#   'scifi': 20},
#  'hundred': {'astronomy': 318,
#   'biology': 270,
#   'cook': 32,
#   'love': 68,
#   'math': 26,
#   'scifi': 411},
#  'million': {'astronomy': 129,
#   'biology': 64,
#   'cook': 4,
#   'love': 8,
#   'math': 0,
#   'scifi': 47},
#  'spheres': {'astronomy': 65,
#   'biology': 19,
#   'cook': 0,
#   'love': 1,
#   'math': 8,
#   'scifi': 35},
#  'tennyson': {'astronomy': 17,
#   'biology': 5,
#   'cook': 0,
#   'love': 2,
#   'math': 0,
#   'scifi': 2},
#  'was': {'astronomy': 7824,
#   'biology': 3572,
#   'cook': 923,
#   'love': 9349,
#   'math': 288,
#   'scifi': 10646},
#  'glancing': {'astronomy': 1,
#   'biology': 7,
#   'cook': 0,
#   'love': 18,
#   'math': 0,
#   'scifi': 11},
#  'times': {'astronomy': 762,
#   'biology': 492,
#   'cook': 142,
#   'love': 108,
#   'math': 431,
#   'scifi': 274},
#  'newspaper': {'astronomy': 0,
#   'biology': 12,
#   'cook': 1,
#   'love': 26,
#   'math': 0,
#   'scifi': 11},
#  'morning': {'astronomy': 179,
#   'biology': 108,
#   'cook': 91,
#   'love': 319,
#   'math': 2,
#   'scifi': 279},
#  'train': {'astronomy': 57,
#   'biology': 54,
#   'cook': 4,
#   'love': 42,
#   'math': 14,
#   'scifi': 213},
#  'my': {'astronomy': 556,
#   'biology': 747,
#   'cook': 255,
#   'love': 2747,
#   'math': 83,
#   'scifi': 7971},
#  'fell': {'astronomy': 121,
#   'biology': 32,
#   'cook': 13,
#   'love': 60,
#   'math': 0,
#   'scifi': 291},
#  'on': {'astronomy': 5730,
#   'biology': 9820,
#   'cook': 3569,
#   'love': 3599,
#   'math': 1822,
#   'scifi': 4963},
#  'following': {'astronomy': 275,
#   'biology': 375,
#   'cook': 214,
#   'love': 92,
#   'math': 433,
#   'scifi': 189},
#  'item': {'astronomy': 2,
#   'biology': 6,
#   'cook': 6,
#   'love': 3,
#   'math': 2,
#   'scifi': 8},
#  'strange': {'astronomy': 114,
#   'biology': 165,
#   'cook': 13,
#   'love': 70,
#   'math': 2,
#   'scifi': 423},
#  'light': {'astronomy': 1438,
#   'biology': 349,
#   'cook': 357,
#   'love': 150,
#   'math': 32,
#   'scifi': 696},
#  'marson': {'astronomy': 0,
#   'biology': 0,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 1},
#  'monday': {'astronomy': 6,
#   'biology': 0,
#   'cook': 1,
#   'love': 20,
#   'math': 0,
#   'scifi': 17},
#  'afternoon': {'astronomy': 22,
#   'biology': 12,
#   'cook': 23,
#   'love': 71,
#   'math': 0,
#   'scifi': 45},
#  'dr': {'astronomy': 227,
#   'biology': 812,
#   'cook': 179,
#   'love': 98,
#   'math': 28,
#   'scifi': 54},
#  'krueger': {'astronomy': 0,
#   'biology': 0,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 1},
#  'who': {'astronomy': 1421,
#   'biology': 1617,
#   'cook': 478,
#   'love': 1388,
#   'math': 38,
#   'scifi': 1596},
#  'charge': {'astronomy': 105,
#   'biology': 119,
#   'cook': 84,
#   'love': 82,
#   'math': 3,
#   'scifi': 158},
#  'central': {'astronomy': 231,
#   'biology': 200,
#   'cook': 80,
#   'love': 7,
#   'math': 35,
#   'scifi': 55},
#  'bureau': {'astronomy': 8,
#   'biology': 15,
#   'cook': 3,
#   'love': 5,
#   'math': 1,
#   'scifi': 2},
#  'kiel': {'astronomy': 3,
#   'biology': 0,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 3},
#  'telegraphed': {'astronomy': 2,
#   'biology': 0,
#   'cook': 1,
#   'love': 1,
#   'math': 0,
#   'scifi': 4},
#  'correspondents': {'astronomy': 3,
#   'biology': 4,
#   'cook': 2,
#   'love': 2,
#   'math': 0,
#   'scifi': 3},
#  'projection': {'astronomy': 8,
#   'biology': 29,
#   'cook': 1,
#   'love': 2,
#   'math': 81,
#   'scifi': 11},
#  'lumineuse': {'astronomy': 0,
#   'biology': 1,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 1},
#  'dans': {'astronomy': 10,
#   'biology': 33,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 1},
#  'région': {'astronomy': 0,
#   'biology': 0,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 1},
#  'australe': {'astronomy': 0,
#   'biology': 0,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 1},
#  'du': {'astronomy': 74,
#   'biology': 32,
#   'cook': 1,
#   'love': 11,
#   'math': 3,
#   'scifi': 2},
#  'terminateur': {'astronomy': 0,
#   'biology': 0,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 1},
#  'de': {'astronomy': 622,
#   'biology': 296,
#   'cook': 88,
#   'love': 108,
#   'math': 95,
#   'scifi': 33},
#  'observée': {'astronomy': 0,
#   'biology': 0,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 1},
#  'par': {'astronomy': 12,
#   'biology': 17,
#   'cook': 5,
#   'love': 3,
#   'math': 6,
#   'scifi': 5},
#  'javelle': {'astronomy': 0,
#   'biology': 1,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 3},
#  'courant': {'astronomy': 0,
#   'biology': 0,
#   'cook': 0,
#   'love': 0,
#   'math': 1,
#   'scifi': 1},
#  'heuresperrotin': {'astronomy': 0,
#   'biology': 0,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 1},
#  'plain': {'astronomy': 107,
#   'biology': 127,
#   'cook': 149,
#   'love': 62,
#   'math': 20,
#   'scifi': 124},
#  'am': {'astronomy': 122,
#   'biology': 322,
#   'cook': 89,
#   'love': 1255,
#   'math': 42,
#   'scifi': 649},
#  'ray': {'astronomy': 32,
#   'biology': 23,
#   'cook': 4,
#   'love': 0,
#   'math': 1,
#   'scifi': 73},
#  'had': {'astronomy': 2875,
#   'biology': 2119,
#   'cook': 400,
#   'love': 6562,
#   'math': 264,
#   'scifi': 7130},
#  'been': {'astronomy': 3623,
#   'biology': 4823,
#   'cook': 849,
#   'love': 2659,
#   'math': 191,
#   'scifi': 2111},
#  'observed': {'astronomy': 556,
#   'biology': 412,
#   'cook': 52,
#   'love': 81,
#   'math': 17,
#   'scifi': 164},
#  'disc': {'astronomy': 74,
#   'biology': 24,
#   'cook': 1,
#   'love': 0,
#   'math': 4,
#   'scifi': 20},
#  'planet': {'astronomy': 923,
#   'biology': 30,
#   'cook': 1,
#   'love': 0,
#   'math': 4,
#   'scifi': 161},
#  'near': {'astronomy': 437,
#   'biology': 583,
#   'cook': 166,
#   'love': 161,
#   'math': 16,
#   'scifi': 360},
#  'terminator': {'astronomy': 0,
#   'biology': 0,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 5},
#  'say': {'astronomy': 429,
#   'biology': 506,
#   'cook': 99,
#   'love': 889,
#   'math': 145,
#   'scifi': 435},
#  'zone': {'astronomy': 108,
#   'biology': 42,
#   'cook': 18,
#   'love': 0,
#   'math': 0,
#   'scifi': 4},
#  'twilight': {'astronomy': 42,
#   'biology': 5,
#   'cook': 0,
#   'love': 14,
#   'math': 0,
#   'scifi': 31},
#  'separating': {'astronomy': 14,
#   'biology': 45,
#   'cook': 53,
#   'love': 4,
#   'math': 2,
#   'scifi': 9},
#  'day': {'astronomy': 970,
#   'biology': 501,
#   'cook': 209,
#   'love': 617,
#   'math': 26,
#   'scifi': 794},
#  'night': {'astronomy': 420,
#   'biology': 100,
#   'cook': 74,
#   'love': 265,
#   'math': 0,
#   'scifi': 600},
#  'news': {'astronomy': 25,
#   'biology': 18,
#   'cook': 3,
#   'love': 96,
#   'math': 0,
#   'scifi': 68},
#  'doubly': {'astronomy': 5,
#   'biology': 6,
#   'cook': 0,
#   'love': 9,
#   'math': 0,
#   'scifi': 19},
#  'interesting': {'astronomy': 199,
#   'biology': 209,
#   'cook': 28,
#   'love': 76,
#   'math': 9,
#   'scifi': 43},
#  'me': {'astronomy': 301,
#   'biology': 983,
#   'cook': 158,
#   'love': 2103,
#   'math': 17,
#   'scifi': 4292},
#  'because': {'astronomy': 504,
#   'biology': 407,
#   'cook': 139,
#   'love': 313,
#   'math': 72,
#   'scifi': 288},
#  'singular': {'astronomy': 68,
#   'biology': 61,
#   'cook': 8,
#   'love': 5,
#   'math': 0,
#   'scifi': 51},
#  'dream': {'astronomy': 30,
#   'biology': 12,
#   'cook': 2,
#   'love': 41,
#   'math': 0,
#   'scifi': 89},
#  'sunrise': {'astronomy': 27,
#   'biology': 3,
#   'cook': 0,
#   'love': 1,
#   'math': 0,
#   'scifi': 14},
#  'moon': {'astronomy': 1240,
#   'biology': 19,
#   'cook': 2,
#   'love': 28,
#   'math': 9,
#   'scifi': 128},
#  'quickened': {'astronomy': 3,
#   'biology': 0,
#   'cook': 0,
#   'love': 4,
#   'math': 0,
#   'scifi': 6},
#  'imagination': {'astronomy': 141,
#   'biology': 56,
#   'cook': 9,
#   'love': 61,
#   'math': 0,
#   'scifi': 124},
#  'as': {'astronomy': 9294,
#   'biology': 12822,
#   'cook': 3741,
#   'love': 5934,
#   'math': 2521,
#   'scifi': 7335},
#  'wonders': {'astronomy': 35,
#   'biology': 8,
#   'cook': 2,
#   'love': 9,
#   'math': 2,
#   'scifi': 23},
#  'beyond': {'astronomy': 232,
#   'biology': 291,
#   'cook': 26,
#   'love': 209,
#   'math': 68,
#   'scifi': 264},
#  'our': {'astronomy': 2386,
#   'biology': 1671,
#   'cook': 395,
#   'love': 389,
#   'math': 251,
#   'scifi': 2979},
#  'little': {'astronomy': 687,
#   'biology': 876,
#   'cook': 1355,
#   'love': 1194,
#   'math': 19,
#   'scifi': 1043},
#  'globe': {'astronomy': 323,
#   'biology': 89,
#   'cook': 12,
#   'love': 4,
#   'math': 1,
#   'scifi': 77},
#  'nevertobeforgotten': {'astronomy': 0,
#   'biology': 0,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 1},
#  'experience': {'astronomy': 107,
#   'biology': 146,
#   'cook': 56,
#   'love': 32,
#   'math': 12,
#   'scifi': 98},
#  'mine': {'astronomy': 27,
#   'biology': 21,
#   'cook': 9,
#   'love': 74,
#   'math': 8,
#   'scifi': 175},
#  'an': {'astronomy': 3678,
#   'biology': 4828,
#   'cook': 1631,
#   'love': 2003,
#   'math': 1159,
#   'scifi': 2804},
#  'aged': {'astronomy': 21,
#   'biology': 12,
#   'cook': 3,
#   'love': 2,
#   'math': 0,
#   'scifi': 22},
#  'astronomer': {'astronomy': 317,
#   'biology': 1,
#   'cook': 0,
#   'love': 0,
#   'math': 3,
#   'scifi': 32},
#  'several': {'astronomy': 383,
#   'biology': 902,
#   'cook': 244,
#   'love': 94,
#   'math': 46,
#   'scifi': 399},
#  'years': {'astronomy': 1436,
#   'biology': 886,
#   'cook': 109,
#   'love': 295,
#   'math': 140,
#   'scifi': 424},
#  'ago': {'astronomy': 193,
#   'biology': 221,
#   'cook': 33,
#   'love': 111,
#   'math': 7,
#   'scifi': 99},
#  'extraordinary': {'astronomy': 118,
#   'biology': 124,
#   'cook': 1,
#   'love': 53,
#   'math': 0,
#   'scifi': 72},
#  'man': {'astronomy': 729,
#   'biology': 2630,
#   'cook': 185,
#   'love': 839,
#   'math': 109,
#   'scifi': 1272},
#  'living': {'astronomy': 149,
#   'biology': 815,
#   'cook': 63,
#   'love': 97,
#   'math': 11,
#   'scifi': 157},
#  'life': {'astronomy': 816,
#   'biology': 1776,
#   'cook': 121,
#   'love': 395,
#   'math': 53,
#   'scifi': 842},
#  'recluse': {'astronomy': 5,
#   'biology': 0,
#   'cook': 1,
#   'love': 0,
#   'math': 0,
#   'scifi': 3},
#  'own': {'astronomy': 652,
#   'biology': 592,
#   'cook': 132,
#   'love': 1062,
#   'math': 13,
#   'scifi': 762},
#  'observatory': {'astronomy': 264,
#   'biology': 1,
#   'cook': 0,
#   'love': 0,
#   'math': 1,
#   'scifi': 24},
#  'which': {'astronomy': 9010,
#   'biology': 10828,
#   'cook': 2082,
#   'love': 2307,
#   'math': 2153,
#   'scifi': 5103},
#  'situated': {'astronomy': 164,
#   'biology': 108,
#   'cook': 16,
#   'love': 10,
#   'math': 19,
#   'scifi': 35},
#  'lonely': {'astronomy': 6,
#   'biology': 6,
#   'cook': 0,
#   'love': 11,
#   'math': 0,
#   'scifi': 29},
#  'part': {'astronomy': 793,
#   'biology': 1307,
#   'cook': 363,
#   'love': 354,
#   'math': 135,
#   'scifi': 482},
#  'country': {'astronomy': 242,
#   'biology': 462,
#   'cook': 118,
#   'love': 153,
#   'math': 12,
#   'scifi': 316},
#  'any': {'astronomy': 1939,
#   'biology': 2817,
#   'cook': 1099,
#   'love': 1819,
#   'math': 1378,
#   'scifi': 1550},
#  'rate': {'astronomy': 136,
#   'biology': 170,
#   'cook': 8,
#   'love': 55,
#   'math': 70,
#   'scifi': 53},
#  'believed': {'astronomy': 160,
#   'biology': 99,
#   'cook': 10,
#   'love': 133,
#   'math': 1,
#   'scifi': 75},
#  'he': {'astronomy': 5313,
#   'biology': 3110,
#   'cook': 496,
#   'love': 7990,
#   'math': 617,
#   'scifi': 7610},
#  'opened': {'astronomy': 82,
#   'biology': 43,
#   'cook': 16,
#   'love': 93,
#   'math': 2,
#   'scifi': 172},
#  'up': {'astronomy': 983,
#   'biology': 1390,
#   'cook': 1161,
#   'love': 1050,
#   'math': 72,
#   'scifi': 1383},
#  'communication': {'astronomy': 38,
#   'biology': 35,
#   'cook': 0,
#   'love': 34,
#   'math': 0,
#   'scifi': 43},
#  'inhabitants': {'astronomy': 120,
#   'biology': 131,
#   'cook': 7,
#   'love': 5,
#   'math': 0,
#   'scifi': 91},
#  'means': {'astronomy': 643,
#   'biology': 494,
#   'cook': 113,
#   'love': 209,
#   'math': 117,
#   'scifi': 354},
#  'powerful': {'astronomy': 166,
#   'biology': 117,
#   'cook': 10,
#   'love': 18,
#   'math': 0,
#   'scifi': 104},
#  'lights': {'astronomy': 79,
#   'biology': 11,
#   'cook': 1,
#   'love': 25,
#   'math': 0,
#   'scifi': 44},
#  'flashing': {'astronomy': 12,
#   'biology': 2,
#   'cook': 1,
#   'love': 1,
#   'math': 0,
#   'scifi': 21},
#  'manner': {'astronomy': 254,
#   'biology': 622,
#   'cook': 93,
#   'love': 283,
#   'math': 146,
#   'scifi': 212},
#  'signallantern': {'astronomy': 0,
#   'biology': 0,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 1},
#  'heliograph': {'astronomy': 0,
#   'biology': 0,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 4},
#  'him': {'astronomy': 1368,
#   'biology': 686,
#   'cook': 137,
#   'love': 3306,
#   'math': 59,
#   'scifi': 2706},
#  'down': {'astronomy': 546,
#   'biology': 684,
#   'cook': 283,
#   'love': 514,
#   'math': 52,
#   'scifi': 836},
#  'monomaniac': {'astronomy': 0,
#   'biology': 0,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 1},
#  'but': {'astronomy': 4846,
#   'biology': 5839,
#   'cook': 2307,
#   'love': 4736,
#   'math': 842,
#   'scifi': 5336},
#  'knows': {'astronomy': 52,
#   'biology': 78,
#   'cook': 22,
#   'love': 80,
#   'math': 4,
#   'scifi': 65},
#  'perhaps': {'astronomy': 396,
#   'biology': 420,
#   'cook': 78,
#   'love': 341,
#   'math': 7,
#   'scifi': 282},
#  'not': {'astronomy': 5218,
#   'biology': 6531,
#   'cook': 2966,
#   'love': 6545,
#   'math': 766,
#   'scifi': 5508},
#  'so': {'astronomy': 2909,
#   'biology': 3754,
#   'cook': 820,
#   'love': 3100,
#   'math': 541,
#   'scifi': 2386},
#  'crazy': {'astronomy': 0,
#   'biology': 4,
#   'cook': 0,
#   'love': 9,
#   'math': 0,
#   'scifi': 5},
#  'after': {'astronomy': 1043,
#   'biology': 1203,
#   'cook': 559,
#   'love': 888,
#   'math': 92,
#   'scifi': 1056},
#  'all': {'astronomy': 3446,
#   'biology': 4275,
#   'cook': 1730,
#   'love': 3203,
#   'math': 777,
#   'scifi': 3177},
#  'when': {'astronomy': 2228,
#   'biology': 3200,
#   'cook': 2583,
#   'love': 1688,
#   'math': 633,
#   'scifi': 2072},
#  'evening': {'astronomy': 189,
#   'biology': 65,
#   'cook': 20,
#   'love': 339,
#   'math': 0,
#   'scifi': 193},
#  'came': {'astronomy': 267,
#   'biology': 252,
#   'cook': 29,
#   'love': 484,
#   'math': 0,
#   'scifi': 817},
#  'turned': {'astronomy': 125,
#   'biology': 75,
#   'cook': 45,
#   'love': 262,
#   'math': 8,
#   'scifi': 488},
#  'books': {'astronomy': 89,
#   'biology': 41,
#   'cook': 25,
#   'love': 62,
#   'math': 109,
#   'scifi': 82},
#  'gathered': {'astronomy': 29,
#   'biology': 49,
#   'cook': 44,
#   'love': 12,
#   'math': 0,
#   'scifi': 68},
#  'great': {'astronomy': 2129,
#   'biology': 1774,
#   'cook': 228,
#   'love': 786,
#   'math': 65,
#   'scifi': 1178},
#  'deal': {'astronomy': 69,
#   'biology': 53,
#   'cook': 39,
#   'love': 227,
#   'math': 0,
#   'scifi': 63},
#  'about': {'astronomy': 1178,
#   'biology': 1300,
#   'cook': 1058,
#   'love': 1024,
#   'math': 90,
#   'scifi': 1462},
#  'fiery': {'astronomy': 50,
#   'biology': 8,
#   'cook': 2,
#   'love': 3,
#   'math': 0,
#   'scifi': 23},
#  'including': {'astronomy': 162,
#   'biology': 230,
#   'cook': 120,
#   'love': 63,
#   'math': 11,
#   'scifi': 119},
#  'fact': {'astronomy': 614,
#   'biology': 806,
#   'cook': 95,
#   'love': 160,
#   'math': 134,
#   'scifi': 328},
#  'stout': {'astronomy': 3,
#   'biology': 9,
#   'cook': 122,
#   'love': 6,
#   'math': 2,
#   'scifi': 10},
#  'daniel': {'astronomy': 33,
#   'biology': 4,
#   'cook': 3,
#   'love': 0,
#   'math': 7,
#   'scifi': 4},
#  'lambert': {'astronomy': 4,
#   'biology': 2,
#   'cook': 1,
#   'love': 0,
#   'math': 0,
#   'scifi': 1},
#  'jump': {'astronomy': 4,
#   'biology': 3,
#   'cook': 1,
#   'love': 9,
#   'math': 0,
#   'scifi': 14},
#  'height': {'astronomy': 231,
#   'biology': 185,
#   'cook': 84,
#   'love': 20,
#   'math': 11,
#   'scifi': 114},
#  'there': {'astronomy': 2487,
#   'biology': 3885,
#   'cook': 673,
#   'love': 1954,
#   'math': 458,
#   'scifi': 2051},
#  'greatest': {'astronomy': 260,
#   'biology': 192,
#   'cook': 24,
#   'love': 110,
#   'math': 47,
#   'scifi': 105},
#  'ease': {'astronomy': 13,
#   'biology': 15,
#   'cook': 15,
#   'love': 65,
#   'math': 3,
#   'scifi': 47},
#  'very': {'astronomy': 1402,
#   'biology': 1595,
#   'cook': 1767,
#   'love': 2708,
#   'math': 123,
#   'scifi': 1076},
#  'likely': {'astronomy': 88,
#   'biology': 89,
#   'cook': 24,
#   'love': 136,
#   'math': 5,
#   'scifi': 61},
#  'seeking': {'astronomy': 25,
#   'biology': 16,
#   'cook': 3,
#   'love': 16,
#   'math': 13,
#   'scifi': 32},
#  'information': {'astronomy': 165,
#   'biology': 197,
#   'cook': 117,
#   'love': 117,
#   'math': 13,
#   'scifi': 146},
#  'resolved': {'astronomy': 49,
#   'biology': 15,
#   'cook': 1,
#   'love': 93,
#   'math': 11,
#   'scifi': 101},
#  'walk': {'astronomy': 23,
#   'biology': 46,
#   'cook': 11,
#   'love': 187,
#   'math': 2,
#   'scifi': 69},
#  'over': {'astronomy': 762,
#   'biology': 976,
#   'cook': 1361,
#   'love': 674,
#   'math': 58,
#   'scifi': 996},
#  'consult': {'astronomy': 5,
#   'biology': 10,
#   'cook': 1,
#   'love': 23,
#   'math': 4,
#   'scifi': 12},
#  'old': {'astronomy': 526,
#   'biology': 628,
#   'cook': 372,
#   'love': 465,
#   'math': 76,
#   'scifi': 461},
#  'friend': {'astronomy': 108,
#   'biology': 57,
#   'cook': 31,
#   'love': 395,
#   'math': 1,
#   'scifi': 268},
#  'professor': {'astronomy': 257,
#   'biology': 438,
#   'cook': 155,
#   'love': 12,
#   'math': 17,
#   'scifi': 403},
#  'gazen': {'astronomy': 0,
#   'biology': 0,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 156},
#  'wellknown': {'astronomy': 53,
#   'biology': 50,
#   'cook': 11,
#   'love': 7,
#   'math': 3,
#   'scifi': 15},
#  'made': {'astronomy': 1333,
#   'biology': 943,
#   'cook': 597,
#   'love': 778,
#   'math': 134,
#   'scifi': 875},
#  'mark': {'astronomy': 46,
#   'biology': 107,
#   'cook': 65,
#   'love': 11,
#   'math': 11,
#   'scifi': 66},
#  'series': {'astronomy': 158,
#   'biology': 477,
#   'cook': 73,
#   'love': 12,
#   'math': 326,
#   'scifi': 57},
#  'splendid': {'astronomy': 115,
#   'biology': 102,
#   'cook': 4,
#   'love': 7,
#   'math': 0,
#   'scifi': 48},
#  'researches': {'astronomy': 124,
#   'biology': 85,
#   'cook': 1,
#   'love': 1,
#   'math': 4,
#   'scifi': 9},
#  'spectroscope': {'astronomy': 49,
#   'biology': 0,
#   'cook': 1,
#   'love': 0,
#   'math': 1,
#   'scifi': 10},
#  'into': {'astronomy': 1661,
#   'biology': 2190,
#   'cook': 2115,
#   'love': 985,
#   'math': 290,
#   'scifi': 1744},
#  'constitution': {'astronomy': 64,
#   'biology': 149,
#   'cook': 12,
#   'love': 13,
#   'math': 3,
#   'scifi': 10},
#  'sun': {'astronomy': 2219,
#   'biology': 157,
#   'cook': 40,
#   'love': 25,
#   'math': 15,
#   'scifi': 432},
#  'celestial': {'astronomy': 360,
#   'biology': 4,
#   'cook': 1,
#   'love': 0,
#   'math': 3,
#   'scifi': 35},
#  'bodies': {'astronomy': 624,
#   'biology': 282,
#   'cook': 9,
#   'love': 5,
#   'math': 14,
#   'scifi': 174},
#  'fine': {'astronomy': 116,
#   'biology': 250,
#   'cook': 523,
#   'love': 145,
#   'math': 8,
#   'scifi': 67},
#  'clear': {'astronomy': 212,
#   'biology': 223,
#   'cook': 172,
#   'love': 64,
#   'math': 33,
#   'scifi': 185},
#  'sky': {'astronomy': 356,
#   'biology': 87,
#   'cook': 0,
#   'love': 24,
#   'math': 0,
#   'scifi': 187},
#  'cloudless': {'astronomy': 10,
#   'biology': 3,
#   'cook': 0,
#   'love': 2,
#   'math': 0,
#   'scifi': 10},
#  'deep': {'astronomy': 159,
#   'biology': 163,
#   'cook': 175,
#   'love': 74,
#   'math': 3,
#   'scifi': 210},
#  'dark': {'astronomy': 223,
#   'biology': 183,
#   'cook': 171,
#   'love': 82,
#   'math': 1,
#   'scifi': 274},
#  'blue': {'astronomy': 102,
#   'biology': 237,
#   'cook': 104,
#   'love': 60,
#   'math': 0,
#   'scifi': 107},
#  'revealed': {'astronomy': 110,
#   'biology': 17,
#   'cook': 1,
#   'love': 8,
#   'math': 0,
#   'scifi': 34},
#  'highest': {'astronomy': 138,
#   'biology': 251,
#   'cook': 12,
#   'love': 31,
#   'math': 35,
#   'scifi': 63},
#  'heavens': {'astronomy': 701,
#   'biology': 12,
#   'cook': 1,
#   'love': 13,
#   'math': 2,
#   'scifi': 78},
#  'silvery': {'astronomy': 13,
#   'biology': 14,
#   'cook': 3,
#   'love': 2,
#   'math': 0,
#   'scifi': 11},
#  'lustre': {'astronomy': 27,
#   'biology': 14,
#   'cook': 0,
#   'love': 2,
#   'math': 0,
#   'scifi': 12},
#  'milky': {'astronomy': 152,
#   'biology': 8,
#   'cook': 9,
#   'love': 0,
#   'math': 0,
#   'scifi': 8},
#  'way': {'astronomy': 717,
#   'biology': 636,
#   'cook': 415,
#   'love': 596,
#   'math': 159,
#   'scifi': 765},
#  'belt': {'astronomy': 41,
#   'biology': 25,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 41},
#  'orion': {'astronomy': 147,
#   'biology': 1,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 2},
#  'shone': {'astronomy': 32,
#   'biology': 8,
#   'cook': 1,
#   'love': 10,
#   'math': 0,
#   'scifi': 38},
#  'conspicuously': {'astronomy': 6,
#   'biology': 60,
#   'cook': 5,
#   'love': 4,
#   'math': 0,
#   'scifi': 3},
#  'east': {'astronomy': 219,
#   'biology': 173,
#   'cook': 17,
#   'love': 29,
#   'math': 4,
#   'scifi': 88},
#  'sirius': {'astronomy': 111,
#   'biology': 5,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 2},
#  'blazed': {'astronomy': 6,
#   'biology': 0,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 13},
#  'gem': {'astronomy': 5,
#   'biology': 0,
#   'cook': 6,
#   'love': 0,
#   'math': 1,
#   'scifi': 6},
#  'more': {'astronomy': 2449,
#   'biology': 3921,
#   'cook': 1183,
#   'love': 1672,
#   'math': 388,
#   'scifi': 1647},
#  'south': {'astronomy': 364,
#   'biology': 468,
#   'cook': 42,
#   'love': 20,
#   'math': 4,
#   'scifi': 139},
#  'looked': {'astronomy': 77,
#   'biology': 84,
#   'cook': 21,
#   'love': 433,
#   'math': 4,
#   'scifi': 425},
#  'soon': {'astronomy': 211,
#   'biology': 307,
#   'cook': 234,
#   'love': 738,
#   'math': 9,
#   'scifi': 504},
#  'found': {'astronomy': 970,
#   'biology': 1213,
#   'cook': 558,
#   'love': 418,
#   'math': 351,
#   'scifi': 797},
#  'farther': {'astronomy': 53,
#   'biology': 102,
#   'cook': 5,
#   'love': 122,
#   'math': 9,
#   'scifi': 83},
#  'north': {'astronomy': 310,
#   'biology': 574,
#   'cook': 183,
#   'love': 18,
#   'math': 8,
#   'scifi': 139},
#  'large': {'astronomy': 514,
#   'biology': 1031,
#   'cook': 800,
#   'love': 131,
#   'math': 52,
#   'scifi': 223},
#  'red': {'astronomy': 158,
#   'biology': 357,
#   'cook': 499,
#   'love': 40,
#   'math': 2,
#   'scifi': 277},
#  'star': {'astronomy': 1098,
#   'biology': 19,
#   'cook': 4,
#   'love': 10,
#   'math': 4,
#   'scifi': 100},
#  'amongst': {'astronomy': 95,
#   'biology': 163,
#   'cook': 30,
#   'love': 25,
#   'math': 5,
#   'scifi': 30},
#  'white': {'astronomy': 175,
#   'biology': 636,
#   'cook': 2109,
#   'love': 85,
#   'math': 20,
#   'scifi': 281},
#  'encircling': {'astronomy': 7,
#   'biology': 4,
#   'cook': 8,
#   'love': 1,
#   'math': 0,
#   'scifi': 7},
#  'constellations': {'astronomy': 339,
#   'biology': 2,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 7},
#  'quite': {'astronomy': 316,
#   'biology': 477,
#   'cook': 337,
#   'love': 682,
#   'math': 19,
#   'scifi': 360},
#  'arrived': {'astronomy': 97,
#   'biology': 80,
#   'cook': 11,
#   'love': 81,
#   'math': 2,
#   'scifi': 139},
#  'busily': {'astronomy': 2,
#   'biology': 4,
#   'cook': 2,
#   'love': 3,
#   'math': 0,
#   'scifi': 9},
#  'engaged': {'astronomy': 65,
#   'biology': 39,
#   'cook': 6,
#   'love': 139,
#   'math': 1,
#   'scifi': 78},
#  'writing': {'astronomy': 103,
#   'biology': 66,
#   'cook': 49,
#   'love': 78,
#   'math': 61,
#   'scifi': 71},
#  'computing': {'astronomy': 6,
#   'biology': 0,
#   'cook': 0,
#   'love': 0,
#   'math': 19,
#   'scifi': 1},
#  'desk': {'astronomy': 10,
#   'biology': 2,
#   'cook': 1,
#   'love': 14,
#   'math': 2,
#   'scifi': 20},
#  'hope': {'astronomy': 158,
#   'biology': 124,
#   'cook': 30,
#   'love': 464,
#   'math': 3,
#   'scifi': 423},
#  'im': {'astronomy': 4,
#   'biology': 13,
#   'cook': 17,
#   'love': 259,
#   'math': 24,
#   'scifi': 67},
#  'disturbing': {'astronomy': 54,
#   'biology': 19,
#   'cook': 4,
#   'love': 6,
#   'math': 2,
#   'scifi': 9},
#  'said': {'astronomy': 436,
#   'biology': 489,
#   'cook': 310,
#   'love': 1831,
#   'math': 121,
#   'scifi': 1474},
#  'shook': {'astronomy': 4,
#   'biology': 5,
#   'cook': 3,
#   'love': 59,
#   'math': 0,
#   'scifi': 82},
#  'hands': {'astronomy': 103,
#   'biology': 153,
#   'cook': 77,
#   'love': 162,
#   'math': 5,
#   'scifi': 391},
#  'know': {'astronomy': 435,
#   'biology': 482,
#   'cook': 114,
#   'love': 1185,
#   'math': 71,
#   'scifi': 683},
#  'astronomers': {'astronomy': 344,
#   'biology': 5,
#   'cook': 0,
#   'love': 0,
#   'math': 1,
#   'scifi': 12},
#  'must': {'astronomy': 1409,
#   'biology': 1842,
#   'cook': 509,
#   'love': 1678,
#   'math': 623,
#   'scifi': 1217},
#  'work': {'astronomy': 1436,
#   'biology': 1171,
#   'cook': 802,
#   'love': 398,
#   'math': 73,
#   'scifi': 815},
#  'cometh': {'astronomy': 42,
#   'biology': 0,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 1},
#  'dont': {'astronomy': 3,
#   'biology': 41,
#   'cook': 39,
#   'love': 352,
#   'math': 2,
#   'scifi': 118},
#  'mention': {'astronomy': 71,
#   'biology': 53,
#   'cook': 24,
#   'love': 69,
#   'math': 12,
#   'scifi': 25},
#  'replied': {'astronomy': 15,
#   'biology': 19,
#   'cook': 7,
#   'love': 241,
#   'math': 8,
#   'scifi': 460},
#  'cordially': {'astronomy': 1,
#   'biology': 0,
#   'cook': 1,
#   'love': 11,
#   'math': 1,
#   'scifi': 1},
#  'observing': {'astronomy': 77,
#   'biology': 50,
#   'cook': 2,
#   'love': 42,
#   'math': 4,
#   'scifi': 26},
#  'one': {'astronomy': 3238,
#   'biology': 4733,
#   'cook': 3746,
#   'love': 1806,
#   'math': 1659,
#   'scifi': 2839},
#  'nebulas': {'astronomy': 2,
#   'biology': 0,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 1},
#  'just': {'astronomy': 360,
#   'biology': 527,
#   'cook': 325,
#   'love': 617,
#   'math': 150,
#   'scifi': 451},
#  'now': {'astronomy': 1431,
#   'biology': 1829,
#   'cook': 221,
#   'love': 1113,
#   'math': 453,
#   'scifi': 1784},
#  'wont': {'astronomy': 9,
#   'biology': 11,
#   'cook': 13,
#   'love': 76,
#   'math': 0,
#   'scifi': 47},
#  'be': {'astronomy': 7070,
#   'biology': 9407,
#   'cook': 3508,
#   'love': 6268,
#   'math': 5037,
#   'scifi': 4433},
#  'sight': {'astronomy': 183,
#   'biology': 150,
#   'cook': 16,
#   'love': 105,
#   'math': 6,
#   'scifi': 293},
#  'long': {'astronomy': 792,
#   'biology': 1195,
#   'cook': 1108,
#   'love': 643,
#   'math': 70,
#   'scifi': 815},
#  'time': {'astronomy': 1818,
#   'biology': 1517,
#   'cook': 542,
#   'love': 1001,
#   'math': 168,
#   'scifi': 1661},
#  'what': {'astronomy': 1034,
#   'biology': 1140,
#   'cook': 263,
#   'love': 2132,
#   'math': 1523,
#   'scifi': 1759},
#  'mysterious': {'astronomy': 90,
#   'biology': 30,
#   'cook': 2,
#   'love': 17,
#   'math': 0,
#   'scifi': 78},
#  'have': {'astronomy': 4934,
#   'biology': 8040,
#   'cook': 1690,
#   'love': 4305,
#   'math': 1490,
#   'scifi': 3631},
#  'seen': {'astronomy': 775,
#   'biology': 912,
#   'cook': 164,
#   'love': 318,
#   'math': 98,
#   'scifi': 502},
#  'anything': {'astronomy': 133,
#   'biology': 129,
#   'cook': 82,
#   'love': 334,
#   'math': 3,
#   'scifi': 180},
#  'laughed': {'astronomy': 2,
#   'biology': 7,
#   'cook': 3,
#   'love': 90,
#   'math': 0,
#   'scifi': 55},
#  'though': {'astronomy': 677,
#   'biology': 986,
#   'cook': 160,
#   'love': 754,
#   'math': 23,
#   'scifi': 540},
#  'did': {'astronomy': 543,
#   'biology': 301,
#   'cook': 72,
#   'love': 1137,
#   'math': 130,
#   'scifi': 1266},
#  'look': {'astronomy': 176,
#   'biology': 196,
#   'cook': 91,
#   'love': 456,
#   'math': 12,
#   'scifi': 337},
#  'believe': {'astronomy': 148,
#   'biology': 286,
#   'cook': 41,
#   'love': 339,
#   'math': 5,
#   'scifi': 264},
#  'something': {'astronomy': 130,
#   'biology': 220,
#   'cook': 55,
#   'love': 447,
#   'math': 7,
#   'scifi': 289},
#  'kind': {'astronomy': 237,
#   'biology': 598,
#   'cook': 122,
#   'love': 307,
#   'math': 70,
#   'scifi': 287},
#  'has': {'astronomy': 3121,
#   'biology': 4465,
#   'cook': 1095,
#   'love': 935,
#   'math': 703,
#   'scifi': 998},
#  'oh': {'astronomy': 17,
#   'biology': 27,
#   'cook': 10,
#   'love': 563,
#   'math': 5,
#   'scifi': 104},
#  'certainly': {'astronomy': 183,
#   'biology': 206,
#   'cook': 43,
#   'love': 286,
#   'math': 8,
#   'scifi': 158},
#  'nice': {'astronomy': 8,
#   'biology': 17,
#   'cook': 107,
#   'love': 47,
#   'math': 0,
#   'scifi': 9},
#  'monsieur': {'astronomy': 0,
#   'biology': 0,
#   'cook': 3,
#   'love': 15,
#   'math': 0,
#   'scifi': 51},
#  'perrotin': {'astronomy': 0,
#   'biology': 0,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 2},
#  'director': {'astronomy': 31,
#   'biology': 25,
#   'cook': 12,
#   'love': 6,
#   'math': 8,
#   'scifi': 19},
#  'finest': {'astronomy': 32,
#   'biology': 42,
#   'cook': 29,
#   'love': 16,
#   'math': 0,
#   'scifi': 9},
#  'telescopes': {'astronomy': 116,
#   'biology': 1,
#   'cook': 0,
#   'love': 0,
#   'math': 2,
#   'scifi': 7},
#  'existence': {'astronomy': 328,
#   'biology': 325,
#   'cook': 13,
#   'love': 23,
#   'math': 24,
#   'scifi': 171},
#  'careful': {'astronomy': 69,
#   'biology': 72,
#   'cook': 88,
#   'love': 15,
#   'math': 10,
#   'scifi': 41},
#  'do': {'astronomy': 788,
#   'biology': 1563,
#   'cook': 767,
#   'love': 1989,
#   'math': 149,
#   'scifi': 1345},
#  'account': {'astronomy': 321,
#   'biology': 359,
#   'cook': 52,
#   'love': 170,
#   'math': 73,
#   'scifi': 145},
#  'outside': {'astronomy': 122,
#   'biology': 156,
#   'cook': 94,
#   'love': 50,
#   'math': 9,
#   'scifi': 130},
#  'responded': {'astronomy': 2,
#   'biology': 6,
#   'cook': 1,
#   'love': 2,
#   'math': 0,
#   'scifi': 45},
#  'else': {'astronomy': 110,
#   'biology': 77,
#   'cook': 41,
#   'love': 257,
#   'math': 49,
#   'scifi': 125},
#  'should': {'astronomy': 800,
#   'biology': 1164,
#   'cook': 757,
#   'love': 1230,
#   'math': 285,
#   'scifi': 1081},
#  'ascribe': {'astronomy': 20,
#   'biology': 13,
#   'cook': 0,
#   'love': 1,
#   'math': 0,
#   'scifi': 9},
#  'small': {'astronomy': 610,
#   'biology': 1109,
#   'cook': 1152,
#   'love': 170,
#   'math': 74,
#   'scifi': 359},
#  'comet': {'astronomy': 468,
#   'biology': 0,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 3},
#  'due': {'astronomy': 334,
#   'biology': 287,
#   'cook': 56,
#   'love': 67,
#   'math': 55,
#   'scifi': 104},
#  'aurora': {'astronomy': 82,
#   'biology': 2,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 4},
#  'writer': {'astronomy': 87,
#   'biology': 44,
#   'cook': 133,
#   'love': 13,
#   'math': 1,
#   'scifi': 18},
#  'nature': {'astronomy': 844,
#   'biology': 851,
#   'cook': 69,
#   'love': 126,
#   'math': 27,
#   'scifi': 462},
#  'suggested': {'astronomy': 116,
#   'biology': 127,
#   'cook': 7,
#   'love': 50,
#   'math': 13,
#   'scifi': 54},
#  'range': {'astronomy': 65,
#   'biology': 212,
#   'cook': 27,
#   'love': 9,
#   'math': 6,
#   'scifi': 68},
#  'snowy': {'astronomy': 10,
#   'biology': 34,
#   'cook': 8,
#   'love': 5,
#   'math': 0,
#   'scifi': 27},
#  'alps': {'astronomy': 62,
#   'biology': 90,
#   'cook': 1,
#   'love': 0,
#   'math': 14,
#   'scifi': 19},
#  'even': {'astronomy': 1095,
#   'biology': 1395,
#   'cook': 643,
#   'love': 557,
#   'math': 118,
#   'scifi': 995},
#  'bright': {'astronomy': 246,
#   'biology': 276,
#   'cook': 152,
#   'love': 30,
#   'math': 0,
#   'scifi': 82},
#  'cloud': {'astronomy': 124,
#   'biology': 26,
#   'cook': 2,
#   'love': 14,
#   'math': 0,
#   'scifi': 70},
#  'reflecting': {'astronomy': 36,
#   'biology': 11,
#   'cook': 0,
#   'love': 5,
#   'math': 0,
#   'scifi': 13},
#  'possibly': {'astronomy': 91,
#   'biology': 88,
#   'cook': 32,
#   'love': 51,
#   'math': 2,
#   'scifi': 72},
#  'martians': {'astronomy': 4,
#   'biology': 0,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 271},
#  'forest': {'astronomy': 40,
#   'biology': 181,
#   'cook': 17,
#   'love': 3,
#   'math': 3,
#   'scifi': 211},
#  'fires': {'astronomy': 25,
#   'biology': 11,
#   'cook': 4,
#   'love': 4,
#   'math': 0,
#   'scifi': 29},
#  'america': {'astronomy': 143,
#   'biology': 479,
#   'cook': 50,
#   'love': 15,
#   'math': 5,
#   'scifi': 64},
#  'started': {'astronomy': 55,
#   'biology': 18,
#   'cook': 8,
#   'love': 41,
#   'math': 5,
#   'scifi': 122},
#  'rival': {'astronomy': 20,
#   'biology': 35,
#   'cook': 4,
#   'love': 4,
#   'math': 0,
#   'scifi': 7},
#  'illumination': {'astronomy': 39,
#   'biology': 3,
#   'cook': 0,
#   'love': 3,
#   'math': 0,
#   'scifi': 11},
#  'strikes': {'astronomy': 10,
#   'biology': 21,
#   'cook': 2,
#   'love': 7,
#   'math': 0,
#   'scifi': 8},
#  'likeliest': {'astronomy': 0,
#   'biology': 0,
#   'cook': 0,
#   'love': 4,
#   'math': 0,
#   'scifi': 1},
#  'these': {'astronomy': 2549,
#   'biology': 3745,
#   'cook': 592,
#   'love': 343,
#   'math': 816,
#   'scifi': 1484},
#  'notions': {'astronomy': 18,
#   'biology': 17,
#   'cook': 2,
#   'love': 21,
#   'math': 14,
#   'scifi': 21},
#  'mountain': {'astronomy': 260,
#   'biology': 218,
#   'cook': 5,
#   'love': 2,
#   'math': 1,
#   'scifi': 96},
#  'peaks': {'astronomy': 36,
#   'biology': 5,
#   'cook': 2,
#   'love': 2,
#   'math': 1,
#   'scifi': 12},
#  'catching': {'astronomy': 5,
#   'biology': 26,
#   'cook': 3,
#   'love': 11,
#   'math': 0,
#   'scifi': 13},
#  'sunshine': {'astronomy': 33,
#   'biology': 68,
#   'cook': 7,
#   'love': 12,
#   'math': 0,
#   'scifi': 24},
#  'might': {'astronomy': 696,
#   'biology': 689,
#   'cook': 113,
#   'love': 1051,
#   'math': 65,
#   'scifi': 942},
#  'glare': {'astronomy': 9,
#   'biology': 5,
#   'cook': 0,
#   'love': 5,
#   'math': 0,
#   'scifi': 29},
#  'city': {'astronomy': 152,
#   'biology': 131,
#   'cook': 49,
#   'love': 36,
#   'math': 8,
#   'scifi': 261},
#  'searchlightin': {'astronomy': 0,
#   'biology': 0,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 1},
#  'short': {'astronomy': 192,
#   'biology': 337,
#   'cook': 323,
#   'love': 196,
#   'math': 15,
#   'scifi': 216},
#  'signal': {'astronomy': 8,
#   'biology': 9,
#   'cook': 1,
#   'love': 6,
#   'math': 0,
#   'scifi': 77},
#  'dear': {'astronomy': 20,
#   'biology': 14,
#   'cook': 44,
#   'love': 720,
#   'math': 10,
#   'scifi': 292},
#  'exclaimed': {'astronomy': 6,
#   'biology': 10,
#   'cook': 4,
#   'love': 65,
#   'math': 0,
#   'scifi': 148},
#  'smiling': {'astronomy': 4,
#   'biology': 1,
#   'cook': 1,
#   'love': 74,
#   'math': 0,
#   'scifi': 47},
#  'incredulously': {'astronomy': 0,
#   'biology': 0,
#   'cook': 0,
#   'love': 2,
# ...
#   'cook': 6,
#   'love': 12,
#   'math': 0,
#   'scifi': 40},
#  'point': {'astronomy': 534,
#   'biology': 515,
#   'cook': 152,
#   'love': 196,
#   'math': 1622,
#   'scifi': 454},
#  'appeared': {'astronomy': 249,
#   'biology': 187,
#   'cook': 12,
#   'love': 153,
#   'math': 7,
#   'scifi': 365},
#  'side': {'astronomy': 297,
#   'biology': 629,
#   'cook': 203,
#   'love': 290,
#   'math': 133,
#   'scifi': 444},
#  'hallo': {'astronomy': 0,
#   'biology': 0,
#   'cook': 1,
#   'love': 3,
#   'math': 0,
#   'scifi': 5},
#  'involuntarily': {'astronomy': 9,
#   'biology': 1,
#   'cook': 0,
#   'love': 9,
#   'math': 0,
#   'scifi': 10},
#  'theres': {'astronomy': 1,
#   'biology': 3,
#   'cook': 5,
#   'love': 79,
#   'math': 0,
#   'scifi': 42},
#  'really': {'astronomy': 175,
#   'biology': 142,
#   'cook': 40,
#   'love': 439,
#   'math': 18,
#   'scifi': 169},
#  'tone': {'astronomy': 11,
#   'biology': 14,
#   'cook': 4,
#   'love': 115,
#   'math': 2,
#   'scifi': 114},
#  'surprise': {'astronomy': 41,
#   'biology': 37,
#   'cook': 9,
#   'love': 108,
#   'math': 0,
#   'scifi': 137},
#  'unmingled': {'astronomy': 0,
#   'biology': 0,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 8},
#  'doubt': {'astronomy': 301,
#   'biology': 410,
#   'cook': 38,
#   'love': 219,
#   'math': 4,
#   'scifi': 183},
#  'distinct': {'astronomy': 108,
#   'biology': 566,
#   'cook': 219,
#   'love': 17,
#   'math': 61,
#   'scifi': 41},
#  'let': {'astronomy': 245,
#   'biology': 343,
#   'cook': 771,
#   'love': 344,
#   'math': 954,
#   'scifi': 405},
#  'hastily': {'astronomy': 11,
#   'biology': 7,
#   'cook': 1,
#   'love': 28,
#   'math': 0,
#   'scifi': 36},
#  'yielded': {'astronomy': 32,
#   'biology': 40,
#   'cook': 3,
#   'love': 12,
#   'math': 0,
#   'scifi': 48},
#  'declared': {'astronomy': 31,
#   'biology': 34,
#   'cook': 4,
#   'love': 41,
#   'math': 0,
#   'scifi': 41},
#  'pause': {'astronomy': 7,
#   'biology': 25,
#   'cook': 4,
#   'love': 71,
#   'math': 0,
#   'scifi': 30},
#  'hidden': {'astronomy': 35,
#   'biology': 66,
#   'cook': 7,
#   'love': 4,
#   'math': 0,
#   'scifi': 63},
#  'till': {'astronomy': 144,
#   'biology': 177,
#   'cook': 221,
#   'love': 352,
#   'math': 8,
#   'scifi': 119},
#  'each': {'astronomy': 880,
#   'biology': 1809,
#   'cook': 743,
#   'love': 333,
#   'math': 1103,
#   'scifi': 671},
#  'silence': {'astronomy': 39,
#   'biology': 32,
#   'cook': 6,
#   'love': 127,
#   'math': 0,
#   'scifi': 189},
#  'saw': {'astronomy': 183,
#   'biology': 218,
#   'cook': 24,
#   'love': 450,
#   'math': 36,
#   'scifi': 806},
#  'ejaculated': {'astronomy': 0,
#   'biology': 0,
#   'cook': 1,
#   'love': 0,
#   'math': 0,
#   'scifi': 8},
#  'length': {'astronomy': 303,
#   'biology': 312,
#   'cook': 297,
#   'love': 86,
#   'math': 272,
#   'scifi': 316},
#  'hellas': {'astronomy': 0,
#   'biology': 0,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 1},
#  'system': {'astronomy': 821,
#   'biology': 444,
#   'cook': 51,
#   'love': 23,
#   'math': 333,
#   'scifi': 252},
#  'daresay': {'astronomy': 0,
#   'biology': 1,
#   'cook': 3,
#   'love': 2,
#   'math': 0,
#   'scifi': 6},
#  'possess': {'astronomy': 91,
#   'biology': 211,
#   'cook': 24,
#   'love': 14,
#   'math': 4,
#   'scifi': 49},
#  'put': {'astronomy': 160,
#   'biology': 220,
#   'cook': 1368,
#   'love': 252,
#   'math': 109,
#   'scifi': 249},
#  'glass': {'astronomy': 91,
#   'biology': 55,
#   'cook': 195,
#   'love': 30,
#   'math': 8,
#   'scifi': 66},
#  'awaited': {'astronomy': 6,
#   'biology': 1,
#   'cook': 1,
#   'love': 6,
#   'math': 0,
#   'scifi': 31},
#  'result': {'astronomy': 279,
#   'biology': 450,
#   'cook': 42,
#   'love': 33,
#   'math': 224,
#   'scifi': 113},
#  'observation': {'astronomy': 384,
#   'biology': 102,
#   'cook': 17,
#   'love': 44,
#   'math': 4,
#   'scifi': 71},
#  'eager': {'astronomy': 15,
#   'biology': 32,
#   'cook': 3,
#   'love': 71,
#   'math': 0,
#   'scifi': 56},
#  'interest': {'astronomy': 197,
#   'biology': 122,
#   'cook': 20,
#   'love': 159,
#   'math': 65,
#   'scifi': 147},
#  'steady': {'astronomy': 23,
#   'biology': 17,
#   'cook': 11,
#   'love': 41,
#   'math': 0,
#   'scifi': 28},
#  'possible': {'astronomy': 301,
#   'biology': 343,
#   'cook': 140,
#   'love': 237,
#   'math': 70,
#   'scifi': 276},
#  'steadiness': {'astronomy': 3,
#   'biology': 1,
#   'cook': 0,
#   'love': 9,
#   'math': 0,
#   'scifi': 2},
#  'puzzles': {'astronomy': 3,
#   'biology': 1,
#   'cook': 2,
#   'love': 1,
#   'math': 0,
#   'scifi': 2},
#  'flash': {'astronomy': 15,
#   'biology': 2,
#   'cook': 3,
#   'love': 17,
#   'math': 0,
#   'scifi': 59},
#  'necessarily': {'astronomy': 110,
#   'biology': 115,
#   'cook': 21,
#   'love': 25,
#   'math': 12,
#   'scifi': 39},
#  'mock': {'astronomy': 0,
#   'biology': 1,
#   'cook': 23,
#   'love': 4,
#   'math': 0,
#   'scifi': 12},
#  'gravity': {'astronomy': 142,
#   'biology': 30,
#   'cook': 4,
#   'love': 16,
#   'math': 38,
#   'scifi': 49},
#  'lighthouse': {'astronomy': 4,
#   'biology': 2,
#   'cook': 0,
#   'love': 1,
#   'math': 0,
#   'scifi': 5},
#  'kaiser': {'astronomy': 2,
#   'biology': 0,
#   'cook': 1,
#   'love': 0,
#   'math': 0,
#   'scifi': 1},
#  'autumn': {'astronomy': 66,
#   'biology': 90,
#   'cook': 73,
#   'love': 23,
#   'math': 1,
#   'scifi': 15},
#  'manoeuvres': {'astronomy': 0,
#   'biology': 0,
#   'cook': 0,
#   'love': 1,
#   'math': 0,
#   'scifi': 2},
#  'warlike': {'astronomy': 3,
#   'biology': 3,
#   'cook': 2,
#   'love': 0,
#   'math': 0,
#   'scifi': 15},
#  'advertisement': {'astronomy': 0,
#   'biology': 0,
#   'cook': 3,
#   'love': 1,
#   'math': 0,
#   'scifi': 4},
#  'soap': {'astronomy': 3,
#   'biology': 3,
#   'cook': 11,
#   'love': 1,
#   'math': 0,
#   'scifi': 2},
#  'seriously': {'astronomy': 22,
#   'biology': 32,
#   'cook': 3,
#   'love': 54,
#   'math': 1,
#   'scifi': 25},
#  'asked': {'astronomy': 52,
#   'biology': 70,
#   'cook': 19,
#   'love': 241,
#   'math': 15,
#   'scifi': 352},
#  'confess': {'astronomy': 18,
#   'biology': 7,
#   'cook': 1,
#   'love': 44,
#   'math': 0,
#   'scifi': 45},
#  'mystery': {'astronomy': 58,
#   'biology': 21,
#   'cook': 6,
#   'love': 17,
#   'math': 1,
#   'scifi': 57},
#  'pondering': {'astronomy': 4,
#   'biology': 0,
#   'cook': 1,
#   'love': 3,
#   'math': 0,
#   'scifi': 2},
#  'deeply': {'astronomy': 29,
#   'biology': 53,
#   'cook': 54,
#   'love': 38,
#   'math': 1,
#   'scifi': 52},
#  'struck': {'astronomy': 51,
#   'biology': 74,
#   'cook': 4,
#   'love': 96,
#   'math': 1,
#   'scifi': 169},
#  'sudden': {'astronomy': 75,
#   'biology': 61,
#   'cook': 10,
#   'love': 91,
#   'math': 1,
#   'scifi': 135},
#  'added': {'astronomy': 110,
#   'biology': 146,
#   'cook': 200,
#   'love': 204,
#   'math': 322,
#   'scifi': 156},
#  'wonder': {'astronomy': 63,
#   'biology': 63,
#   'cook': 10,
#   'love': 174,
#   'math': 1,
#   'scifi': 132},
#  'trying': {'astronomy': 30,
#   'biology': 40,
#   'cook': 18,
#   'love': 118,
#   'math': 0,
#   'scifi': 51},
#  'saying': {'astronomy': 56,
#   'biology': 49,
#   'cook': 8,
#   'love': 166,
#   'math': 30,
#   'scifi': 72},
#  'attached': {'astronomy': 66,
#   'biology': 147,
#   'cook': 101,
#   'love': 75,
#   'math': 7,
#   'scifi': 63},
#  'employed': {'astronomy': 116,
#   'biology': 79,
#   'cook': 9,
#   'love': 29,
#   'math': 15,
#   'scifi': 33},
#  'nebulæ': {'astronomy': 142,
#   'biology': 1,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 4},
#  'renewed': {'astronomy': 25,
#   'biology': 12,
#   'cook': 0,
#   'love': 21,
#   'math': 3,
#   'scifi': 44},
#  'thats': {'astronomy': 0,
#   'biology': 4,
#   'cook': 5,
#   'love': 131,
#   'math': 0,
#   'scifi': 59},
#  'most': {'astronomy': 1608,
#   'biology': 1896,
#   'cook': 484,
#   'love': 855,
#   'math': 117,
#   'scifi': 746},
#  'remarkable': {'astronomy': 347,
#   'biology': 326,
#   'cook': 51,
#   'love': 20,
#   'math': 11,
#   'scifi': 88},
#  'thing': {'astronomy': 181,
#   'biology': 179,
#   'cook': 48,
#   'love': 612,
#   'math': 39,
#   'scifi': 374},
#  'professional': {'astronomy': 14,
#   'biology': 9,
#   'cook': 1,
#   'love': 11,
#   'math': 0,
#   'scifi': 7},
#  'resigning': {'astronomy': 0,
#   'biology': 0,
#   'cook': 0,
#   'love': 3,
#   'math': 0,
#   'scifi': 1},
#  'instrument': {'astronomy': 167,
#   'biology': 30,
#   'cook': 6,
#   'love': 36,
#   'math': 5,
#   'scifi': 45},
#  'demanded': {'astronomy': 18,
#   'biology': 15,
#   'cook': 1,
#   'love': 17,
#   'math': 0,
#   'scifi': 26},
#  'looking': {'astronomy': 74,
#   'biology': 101,
#   'cook': 25,
#   'love': 239,
#   'math': 5,
#   'scifi': 155},
#  'where': {'astronomy': 870,
#   'biology': 1229,
#   'cook': 357,
#   'love': 488,
#   'math': 505,
#   'scifi': 927},
#  'distinguish': {'astronomy': 44,
#   'biology': 96,
#   'cook': 39,
#   'love': 14,
#   'math': 10,
#   'scifi': 43},
#  'faint': {'astronomy': 88,
#   'biology': 28,
#   'cook': 13,
#   'love': 57,
#   'math': 0,
#   'scifi': 93},
#  'coloured': {'astronomy': 28,
#   'biology': 364,
#   'cook': 15,
#   'love': 13,
#   'math': 10,
#   'scifi': 9},
#  'darker': {'astronomy': 19,
#   'biology': 57,
#   'cook': 132,
#   'love': 6,
#   'math': 0,
#   'scifi': 10},
#  'background': {'astronomy': 18,
#   'biology': 4,
#   'cook': 2,
#   'love': 16,
#   'math': 2,
#   'scifi': 18},
#  'tell': {'astronomy': 92,
#   'biology': 67,
#   'cook': 22,
#   'love': 381,
#   'math': 4,
#   'scifi': 232},
#  'substance': {'astronomy': 79,
#   'biology': 244,
#   'cook': 127,
#   'love': 17,
#   'math': 9,
#   'scifi': 34},
#  'burning': {'astronomy': 80,
#   'biology': 18,
#   'cook': 33,
#   'love': 15,
#   'math': 0,
#   'scifi': 98},
#  'splitting': {'astronomy': 5,
#   'biology': 5,
#   'cook': 26,
#   'love': 0,
#   'math': 0,
#   'scifi': 2},
#  'comes': {'astronomy': 141,
#   'biology': 223,
#   'cook': 62,
#   'love': 86,
#   'math': 10,
#   'scifi': 69},
#  'prism': {'astronomy': 38,
#   'biology': 10,
#   'cook': 0,
#   'love': 0,
#   'math': 5,
#   'scifi': 3},
#  'lines': {'astronomy': 353,
#   'biology': 222,
#   'cook': 553,
#   'love': 56,
#   'math': 825,
#   'scifi': 152},
#  'different': {'astronomy': 695,
#   'biology': 1105,
#   'cook': 155,
#   'love': 171,
#   'math': 182,
#   'scifi': 255},
#  'colours': {'astronomy': 43,
#   'biology': 569,
#   'cook': 3,
#   'love': 3,
#   'math': 0,
#   'scifi': 36},
#  'spectrum': {'astronomy': 148,
#   'biology': 8,
#   'cook': 0,
#   'love': 0,
#   'math': 2,
#   'scifi': 8},
#  'gas': {'astronomy': 99,
#   'biology': 61,
#   'cook': 32,
#   'love': 4,
#   'math': 14,
#   'scifi': 45},
#  'origin': {'astronomy': 222,
#   'biology': 417,
#   'cook': 18,
#   'love': 11,
#   'math': 287,
#   'scifi': 32},
#  'blaze': {'astronomy': 15,
#   'biology': 0,
#   'cook': 2,
#   'love': 2,
#   'math': 0,
#   'scifi': 12},
#  'electricalfor': {'astronomy': 0,
#   'biology': 0,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 1},
#  'instance': {'astronomy': 278,
#   'biology': 461,
#   'cook': 23,
#   'love': 36,
#   'math': 54,
#   'scifi': 53},
#  'volcanic': {'astronomy': 184,
#   'biology': 55,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 33},
#  'eruption': {'astronomy': 90,
#   'biology': 5,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 19},
#  'lake': {'astronomy': 125,
#   'biology': 192,
#   'cook': 15,
#   'love': 24,
#   'math': 1,
#   'scifi': 102},
#  'fire': {'astronomy': 207,
#   'biology': 67,
#   'cook': 398,
#   'love': 94,
#   'math': 2,
#   'scifi': 221},
#  'kilauea': {'astronomy': 2,
#   'biology': 0,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 1},
#  'identify': {'astronomy': 27,
#   'biology': 22,
#   'cook': 15,
#   'love': 8,
#   'math': 3,
#   'scifi': 17},
#  'scarcely': {'astronomy': 125,
#   'biology': 180,
#   'cook': 110,
#   'love': 135,
#   'math': 1,
#   'scifi': 183},
#  'ere': {'astronomy': 15,
#   'biology': 13,
#   'cook': 9,
#   'love': 7,
#   'math': 3,
#   'scifi': 78},
#  'cried': {'astronomy': 5,
#   'biology': 7,
#   'cook': 4,
#   'love': 308,
#   'math': 0,
#   'scifi': 498},
#  'wonderful': {'astronomy': 117,
#   'biology': 122,
#   'cook': 3,
#   'love': 61,
#   'math': 0,
#   'scifi': 95},
#  'changed': {'astronomy': 95,
#   'biology': 197,
#   'cook': 29,
#   'love': 60,
#   'math': 32,
#   'scifi': 113},
#  'eureka': {'astronomy': 0,
#   'biology': 0,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 1},
#  'thallium': {'astronomy': 0,
#   'biology': 0,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 2},
#  'green': {'astronomy': 95,
#   'biology': 352,
#   'cook': 430,
#   'love': 40,
#   'math': 3,
#   'scifi': 300},
#  'line': {'astronomy': 416,
#   'biology': 361,
#   'cook': 183,
#   'love': 89,
#   'math': 1359,
#   'scifi': 263},
#  'thousand': {'astronomy': 274,
#   'biology': 174,
#   'cook': 24,
#   'love': 89,
#   'math': 7,
#   'scifi': 359},
#  'astonished': {'astronomy': 23,
#   'biology': 19,
#   'cook': 1,
#   'love': 45,
#   'math': 0,
#   'scifi': 44},
#  'turn': {'astronomy': 140,
#   'biology': 135,
#   'cook': 266,
#   'love': 121,
#   'math': 20,
#   'scifi': 153},
#  'hurriedly': {'astronomy': 1,
#   'biology': 0,
#   'cook': 2,
#   'love': 9,
#   'math': 0,
#   'scifi': 14},
#  'note': {'astronomy': 128,
#   'biology': 183,
#   'cook': 33,
#   'love': 77,
#   'math': 26,
#   'scifi': 85},
#  'also': {'astronomy': 1148,
#   'biology': 1579,
#   'cook': 411,
#   'love': 132,
#   'math': 615,
#   'scifi': 395},
#  'book': {'astronomy': 317,
#   'biology': 108,
#   'cook': 129,
#   'love': 80,
#   'math': 67,
#   'scifi': 77},
#  'purpose': {'astronomy': 176,
#   'biology': 248,
#   'cook': 93,
#   'love': 102,
#   'math': 33,
#   'scifi': 140},
#  'lying': {'astronomy': 48,
#   'biology': 102,
#   'cook': 19,
#   'love': 5,
#   'math': 7,
#   'scifi': 80},
#  'further': {'astronomy': 300,
#   'biology': 422,
#   'cook': 42,
#   'love': 50,
#   'math': 56,
#   'scifi': 245},
#  'orders': {'astronomy': 35,
#   'biology': 176,
#   'cook': 8,
#   'love': 37,
#   'math': 8,
#   'scifi': 65},
#  'plainly': {'astronomy': 34,
#   'biology': 58,
#   'cook': 9,
#   'love': 16,
#   'math': 18,
#   'scifi': 36},
#  'hear': {'astronomy': 69,
#   'biology': 137,
#   'cook': 21,
#   'love': 329,
#   'math': 0,
#   'scifi': 186},
#  'ticking': {'astronomy': 0,
#   'biology': 7,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 2},
#  'watch': {'astronomy': 49,
#   'biology': 80,
#   'cook': 17,
#   'love': 51,
#   'math': 0,
#   'scifi': 124},
#  'laid': {'astronomy': 96,
#   'biology': 116,
#   'cook': 21,
#   'love': 52,
#   'math': 7,
#   'scifi': 108},
#  'end': {'astronomy': 364,
#   'biology': 446,
#   'cook': 179,
#   'love': 219,
#   'math': 71,
#   'scifi': 424},
#  'sodium': {'astronomy': 39,
#   'biology': 42,
#   'cook': 4,
#   'love': 0,
#   'math': 2,
#   'scifi': 3},
#  'yellow': {'astronomy': 68,
#   'biology': 257,
#   'cook': 675,
#   'love': 39,
#   'math': 2,
#   'scifi': 80},
#  'bands': {'astronomy': 56,
#   'biology': 33,
#   'cook': 6,
#   'love': 3,
#   'math': 0,
#   'scifi': 21},
#  'unmistakable': {'astronomy': 9,
#   'biology': 17,
#   'cook': 4,
#   'love': 0,
#   'math': 0,
#   'scifi': 7},
#  'stillness': {'astronomy': 4,
#   'biology': 7,
#   'cook': 0,
#   'love': 4,
#   'math': 0,
#   'scifi': 34},
#  'reigned': {'astronomy': 11,
#   'biology': 1,
#   'cook': 3,
#   'love': 1,
#   'math': 0,
#   'scifi': 23},
#  'she': {'astronomy': 416,
#   'biology': 423,
#   'cook': 169,
#   'love': 8245,
#   'math': 49,
#   'scifi': 3052},
#  'goes': {'astronomy': 74,
#   'biology': 125,
#   'cook': 28,
#   'love': 54,
#   'math': 5,
#   'scifi': 30},
#  'excited': {'astronomy': 49,
#   'biology': 68,
#   'cook': 1,
#   'love': 26,
#   'math': 0,
#   'scifi': 92},
#  'couple': {'astronomy': 15,
#   'biology': 20,
#   'cook': 18,
#   'love': 55,
#   'math': 0,
#   'scifi': 42},
#  'indium': {'astronomy': 0,
#   'biology': 0,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 1},
#  'ensued': {'astronomy': 5,
#   'biology': 3,
#   'cook': 0,
#   'love': 4,
#   'math': 0,
#   'scifi': 12},
#  'gone': {'astronomy': 75,
#   'biology': 159,
#   'cook': 14,
#   'love': 322,
#   'math': 0,
#   'scifi': 259},
#  'once': {'astronomy': 457,
#   'biology': 555,
#   'cook': 226,
#   'love': 321,
#   'math': 90,
#   'scifi': 584},
#  'taken': {'astronomy': 322,
#   'biology': 418,
#   'cook': 119,
#   'love': 210,
#   'math': 264,
#   'scifi': 274},
#  'lithium': {'astronomy': 4,
#   'biology': 0,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 2},
#  'hey': {'astronomy': 0,
#   'biology': 0,
#   'cook': 0,
#   'love': 2,
#   'math': 2,
#   'scifi': 1},
#  'prestoand': {'astronomy': 0,
#   'biology': 0,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 1},
#  'whats': {'astronomy': 0,
#   'biology': 0,
#   'cook': 3,
#   'love': 35,
#   'math': 0,
#   'scifi': 27},
#  'matter': {'astronomy': 454,
#   'biology': 657,
#   'cook': 93,
#   'love': 163,
#   'math': 41,
#   'scifi': 374},
#  'words': {'astronomy': 269,
#   'biology': 206,
#   'cook': 29,
#   'love': 197,
#   'math': 69,
#   'scifi': 392},
#  'removed': {'astronomy': 116,
#   'biology': 111,
#   'cook': 116,
#   'love': 55,
#   'math': 3,
#   'scifi': 83},
#  'gazed': {'astronomy': 1,
#   'biology': 3,
#   'cook': 2,
#   'love': 4,
#   'math': 0,
#   'scifi': 83},
#  'anxiously': {'astronomy': 6,
#   'biology': 1,
#   'cook': 1,
#   'love': 13,
#   'math': 0,
#   'scifi': 20},
#  'continued': {'astronomy': 104,
#   'biology': 156,
#   'cook': 31,
#   'love': 235,
#   'math': 7,
#   'scifi': 261},
#  ...}

# %% [markdown]
# Continuamos definiendo dos funciones, la primera calcula la probabilidad de la clase dada la palabra y la segunda calcula la log verosimilitud.
#
# |   | rojo | amarillo | suma|
# :---|------|----------|--:
# | bola | 5 | 6| 11 |
# |  estrella | 7 | 8| 15 |
# | suma | 13 | 14 | 39|
#
# $P(x = estrella | y = amarillo) = ?$

# %%
def probabilidad(palabra, clase, frecuencias, frecuencias_clases):
    try:
        a = frecuencias[palabra][clase]
    except:
        a = 1.0
    
    b = frecuencias_clases[clase] # frecuencias de la clase
    a = a if a>0 else 1
    
    return a/b

# %%
def clasifica(libro, frecuencias, frecuencias_clases, clases):

    verosimilutudes = []

    for clase in clases:
        log_verosimilitud = 0.0

        for palabra in libro:
            palabra = elimina_simbolos(palabra)
            p = probabilidad(palabra, clase, frecuencias, frecuencias_clases)
            log_verosimilitud += log(p) #* 1 / len(clases)
            
        verosimilutudes.append(log_verosimilitud)

    return clases[argmax(verosimilutudes)], (verosimilutudes)

# %% [markdown]
# ## Clasificación de una frase o palabra
#
# Al entrenar nuestro algoritmo se realiza una prueba con una palabra o frase.

# %%
clasifica_esta_frase = "positive definite matrices are stated and proved".split()
clase_pred = clasifica(clasificame_esta_frase, frecuencias, frecuencas_clases, clases)

# %%
clasifica_esta_frase
# Out:
# ['positive', 'definite', 'matrices', 'are', 'stated', 'and', 'proved']

# %%
frecuencias
# Out:
# {'the': {'astronomy': 94904,
#   'biology': 111815,
#   'cook': 33429,
#   'love': 26835,
#   'math': 31435,
#   'scifi': 63892},
#  'project': {'astronomy': 1060,
#   'biology': 1070,
#   'cook': 1050,
#   'love': 535,
#   'math': 9,
#   'scifi': 1084},
#  'gutenberg': {'astronomy': 413,
#   'biology': 358,
#   'cook': 360,
#   'love': 179,
#   'math': 0,
#   'scifi': 359},
#  'ebook': {'astronomy': 137,
#   'biology': 128,
#   'cook': 141,
#   'love': 65,
#   'math': 0,
#   'scifi': 131},
#  'of': {'astronomy': 58857,
#   'biology': 73111,
#   'cook': 22348,
#   'love': 18868,
#   'math': 19996,
#   'scifi': 35403},
#  'a': {'astronomy': 19855,
#   'biology': 26811,
#   'cook': 16435,
#   'love': 13025,
#   'math': 12643,
#   'scifi': 18676},
#  'trip': {'astronomy': 2,
#   'biology': 9,
#   'cook': 1,
#   'love': 7,
#   'math': 0,
#   'scifi': 42},
#  'to': {'astronomy': 24243,
#   'biology': 29596,
#   'cook': 10965,
#   'love': 20872,
#   'math': 7105,
#   'scifi': 24380},
#  'venus': {'astronomy': 296,
#   'biology': 18,
#   'cook': 0,
#   'love': 1,
#   'math': 4,
#   'scifi': 94},
#  'by': {'astronomy': 8849,
#   'biology': 11880,
#   'cook': 2551,
#   'love': 2712,
#   'math': 3870,
#   'scifi': 4935},
#  'john': {'astronomy': 190,
#   'biology': 101,
#   'cook': 108,
#   'love': 94,
#   'math': 78,
#   'scifi': 218},
#  'munro': {'astronomy': 1,
#   'biology': 1,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 4},
#  'this': {'astronomy': 6460,
#   'biology': 7894,
#   'cook': 3079,
#   'love': 2432,
#   'math': 2176,
#   'scifi': 4930},
#  'is': {'astronomy': 12797,
#   'biology': 17224,
#   'cook': 6963,
#   'love': 4081,
#   'math': 7435,
#   'scifi': 5535},
#  'for': {'astronomy': 6095,
#   'biology': 8485,
#   'cook': 4009,
#   'love': 5481,
#   'math': 2631,
#   'scifi': 6366},
#  'use': {'astronomy': 525,
#   'biology': 676,
#   'cook': 613,
#   'love': 205,
#   'math': 243,
#   'scifi': 314},
#  'anyone': {'astronomy': 72,
#   'biology': 79,
#   'cook': 75,
#   'love': 62,
#   'math': 0,
#   'scifi': 88},
#  'anywhere': {'astronomy': 40,
#   'biology': 58,
#   'cook': 28,
#   'love': 43,
#   'math': 8,
#   'scifi': 41},
#  'at': {'astronomy': 5834,
#   'biology': 5785,
#   'cook': 3062,
#   'love': 4308,
#   'math': 1383,
#   'scifi': 5196},
#  'no': {'astronomy': 2211,
#   'biology': 3016,
#   'cook': 1516,
#   'love': 2415,
#   'math': 257,
#   'scifi': 2395},
#  'cost': {'astronomy': 104,
#   'biology': 111,
#   'cook': 60,
#   'love': 38,
#   'math': 116,
#   'scifi': 65},
#  'and': {'astronomy': 30905,
#   'biology': 39719,
#   'cook': 22168,
#   'love': 20290,
#   'math': 8114,
#   'scifi': 29109},
#  'with': {'astronomy': 7293,
#   'biology': 10226,
#   'cook': 8248,
#   'love': 5633,
#   'math': 1433,
#   'scifi': 7851},
#  'almost': {'astronomy': 597,
#   'biology': 794,
#   'cook': 299,
#   'love': 380,
#   'math': 5,
#   'scifi': 405},
#  'restrictions': {'astronomy': 28,
#   'biology': 31,
#   'cook': 24,
#   'love': 13,
#   'math': 1,
#   'scifi': 32},
#  'whatsoever': {'astronomy': 28,
#   'biology': 25,
#   'cook': 25,
#   'love': 13,
#   'math': 0,
#   'scifi': 30},
#  'you': {'astronomy': 1279,
#   'biology': 1275,
#   'cook': 1605,
#   'love': 7270,
#   'math': 82,
#   'scifi': 4670},
#  'may': {'astronomy': 2135,
#   'biology': 3532,
#   'cook': 1175,
#   'love': 1014,
#   'math': 1492,
#   'scifi': 1089},
#  'copy': {'astronomy': 172,
#   'biology': 160,
#   'cook': 147,
#   'love': 81,
#   'math': 4,
#   'scifi': 154},
#  'it': {'astronomy': 10660,
#   'biology': 11528,
#   'cook': 6541,
#   'love': 8271,
#   'math': 1990,
#   'scifi': 8470},
#  'give': {'astronomy': 358,
#   'biology': 496,
#   'cook': 181,
#   'love': 525,
#   'math': 141,
#   'scifi': 372},
#  'away': {'astronomy': 334,
#   'biology': 441,
#   'cook': 178,
#   'love': 621,
#   'math': 33,
#   'scifi': 581},
#  'or': {'astronomy': 5788,
#   'biology': 10426,
#   'cook': 8462,
#   'love': 2293,
#   'math': 1716,
#   'scifi': 3584},
#  'reuse': {'astronomy': 24,
#   'biology': 24,
#   'cook': 24,
#   'love': 12,
#   'math': 0,
#   'scifi': 24},
#  'under': {'astronomy': 662,
#   'biology': 1252,
#   'cook': 404,
#   'love': 361,
#   'math': 123,
#   'scifi': 623},
#  'terms': {'astronomy': 318,
#   'biology': 410,
#   'cook': 264,
#   'love': 178,
#   'math': 551,
#   'scifi': 331},
#  'license': {'astronomy': 179,
#   'biology': 231,
#   'cook': 180,
#   'love': 93,
#   'math': 0,
#   'scifi': 187},
#  'included': {'astronomy': 104,
#   'biology': 122,
#   'cook': 60,
#   'love': 36,
#   'math': 30,
#   'scifi': 47},
#  'online': {'astronomy': 65,
#   'biology': 62,
#   'cook': 68,
#   'love': 24,
#   'math': 0,
#   'scifi': 56},
#  'wwwgutenbergnet': {'astronomy': 12,
#   'biology': 3,
#   'cook': 12,
#   'love': 3,
#   'math': 0,
#   'scifi': 15},
#  'title': {'astronomy': 63,
#   'biology': 65,
#   'cook': 15,
#   'love': 13,
#   'math': 2,
#   'scifi': 41},
#  'author': {'astronomy': 105,
#   'biology': 99,
#   'cook': 68,
#   'love': 11,
#   'math': 38,
#   'scifi': 44},
#  'release': {'astronomy': 19,
#   'biology': 11,
#   'cook': 14,
#   'love': 12,
#   'math': 0,
#   'scifi': 25},
#  'date': {'astronomy': 204,
#   'biology': 201,
#   'cook': 69,
#   'love': 39,
#   'math': 6,
#   'scifi': 57},
#  'october': {'astronomy': 62,
#   'biology': 44,
#   'cook': 207,
#   'love': 11,
#   'math': 3,
#   'scifi': 36},
#  '': {'astronomy': 24685,
#   'biology': 18769,
#   'cook': 18264,
#   'love': 618,
#   'math': 67593,
#   'scifi': 1934},
#  'language': {'astronomy': 107,
#   'biology': 240,
#   'cook': 22,
#   'love': 47,
#   'math': 23,
#   'scifi': 121},
#  'english': {'astronomy': 127,
#   'biology': 224,
#   'cook': 172,
#   'love': 48,
#   'math': 40,
#   'scifi': 194},
#  'character': {'astronomy': 268,
#   'biology': 516,
#   'cook': 104,
#   'love': 194,
#   'math': 15,
#   'scifi': 136},
#  'set': {'astronomy': 467,
#   'biology': 450,
#   'cook': 447,
#   'love': 254,
#   'math': 34,
#   'scifi': 422},
#  'encoding': {'astronomy': 5,
#   'biology': 2,
#   'cook': 4,
#   'love': 6,
#   'math': 0,
#   'scifi': 12},
#  'utf': {'astronomy': 5,
#   'biology': 2,
#   'cook': 4,
#   'love': 4,
#   'math': 0,
#   'scifi': 3},
#  'start': {'astronomy': 49,
#   'biology': 64,
#   'cook': 47,
#   'love': 51,
#   'math': 9,
#   'scifi': 116},
#  'produced': {'astronomy': 302,
#   'biology': 633,
#   'cook': 91,
#   'love': 69,
#   'math': 23,
#   'scifi': 101},
#  'steven': {'astronomy': 0,
#   'biology': 0,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 2},
#  'desjardins': {'astronomy': 0,
#   'biology': 0,
#   'cook': 2,
#   'love': 0,
#   'math': 0,
#   'scifi': 2},
#  'distributed': {'astronomy': 117,
#   'biology': 105,
#   'cook': 78,
#   'love': 26,
#   'math': 4,
#   'scifi': 65},
#  'proofreaders': {'astronomy': 0,
#   'biology': 0,
#   'cook': 4,
#   'love': 0,
#   'math': 0,
#   'scifi': 2},
#  'novel': {'astronomy': 21,
#   'biology': 12,
#   'cook': 5,
#   'love': 7,
#   'math': 0,
#   'scifi': 17},
#  'wire': {'astronomy': 44,
#   'biology': 28,
#   'cook': 34,
#   'love': 4,
#   'math': 1,
#   'scifi': 29},
#  'wave': {'astronomy': 40,
#   'biology': 23,
#   'cook': 8,
#   'love': 9,
#   'math': 1,
#   'scifi': 64},
#  'story': {'astronomy': 94,
#   'biology': 70,
#   'cook': 28,
#   'love': 59,
#   'math': 4,
#   'scifi': 146},
#  'electricity': {'astronomy': 117,
#   'biology': 37,
#   'cook': 1,
#   'love': 1,
#   'math': 3,
#   'scifi': 29},
#  'etc': {'astronomy': 175,
#   'biology': 265,
#   'cook': 364,
#   'love': 24,
#   'math': 111,
#   'scifi': 13},
#  'published': {'astronomy': 171,
#   'biology': 199,
#   'cook': 43,
#   'love': 3,
#   'math': 52,
#   'scifi': 13},
#  'in': {'astronomy': 25616,
#   'biology': 36962,
#   'cook': 15343,
#   'love': 10207,
#   'math': 5785,
#   'scifi': 15154},
#  'jarrold': {'astronomy': 0,
#   'biology': 3,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 1},
#  'sons': {'astronomy': 51,
#   'biology': 53,
#   'cook': 1,
#   'love': 29,
#   'math': 13,
#   'scifi': 15},
#  'london': {'astronomy': 105,
#   'biology': 282,
#   'cook': 44,
#   'love': 202,
#   'math': 11,
#   'scifi': 262},
#  'contents': {'astronomy': 43,
#   'biology': 82,
#   'cook': 75,
#   'love': 14,
#   'math': 28,
#   'scifi': 35},
#  'chapter': {'astronomy': 313,
#   'biology': 520,
#   'cook': 80,
#   'love': 247,
#   'math': 147,
#   'scifi': 314},
#  'i': {'astronomy': 2226,
#   'biology': 4354,
#   'cook': 1244,
#   'love': 9852,
#   'math': 1964,
#   'scifi': 15504},
#  'message': {'astronomy': 14,
#   'biology': 4,
#   'cook': 1,
#   'love': 31,
#   'math': 0,
#   'scifi': 38},
#  'from': {'astronomy': 5972,
#   'biology': 7910,
#   'cook': 2516,
#   'love': 2513,
#   'math': 1757,
#   'scifi': 5047},
#  'mars': {'astronomy': 322,
#   'biology': 9,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 220},
#  'ii': {'astronomy': 312,
#   'biology': 367,
#   'cook': 18,
#   'love': 17,
#   'math': 190,
#   'scifi': 38},
#  'how': {'astronomy': 605,
#   'biology': 944,
#   'cook': 219,
#   'love': 1119,
#   'math': 608,
#   'scifi': 755},
#  'can': {'astronomy': 1455,
#   'biology': 2254,
#   'cook': 784,
#   'love': 1020,
#   'math': 568,
#   'scifi': 1057},
#  'we': {'astronomy': 4284,
#   'biology': 5450,
#   'cook': 643,
#   'love': 1341,
#   'math': 3953,
#   'scifi': 5926},
#  'get': {'astronomy': 119,
#   'biology': 166,
#   'cook': 226,
#   'love': 377,
#   'math': 141,
#   'scifi': 285},
#  'other': {'astronomy': 2227,
#   'biology': 4366,
#   'cook': 872,
#   'love': 975,
#   'math': 814,
#   'scifi': 1401},
#  'planets': {'astronomy': 775,
#   'biology': 36,
#   'cook': 0,
#   'love': 1,
#   'math': 5,
#   'scifi': 77},
#  'iii': {'astronomy': 192,
#   'biology': 173,
#   'cook': 21,
#   'love': 9,
#   'math': 64,
#   'scifi': 31},
#  'new': {'astronomy': 1059,
#   'biology': 1467,
#   'cook': 720,
#   'love': 450,
#   'math': 268,
#   'scifi': 543},
#  'force': {'astronomy': 517,
#   'biology': 337,
#   'cook': 17,
#   'love': 36,
#   'math': 84,
#   'scifi': 296},
#  'iv': {'astronomy': 96,
#   'biology': 100,
#   'cook': 17,
#   'love': 6,
#   'math': 90,
#   'scifi': 26},
#  'electric': {'astronomy': 249,
#   'biology': 51,
#   'cook': 5,
#   'love': 13,
#   'math': 0,
#   'scifi': 53},
#  'orrery': {'astronomy': 1,
#   'biology': 0,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 5},
#  'v': {'astronomy': 132,
#   'biology': 103,
#   'cook': 38,
#   'love': 13,
#   'math': 778,
#   'scifi': 39},
#  'leaving': {'astronomy': 60,
#   'biology': 109,
#   'cook': 62,
#   'love': 92,
#   'math': 4,
#   'scifi': 125},
#  'earth': {'astronomy': 2379,
#   'biology': 306,
#   'cook': 52,
#   'love': 32,
#   'math': 6,
#   'scifi': 756},
#  'vi': {'astronomy': 73,
#   'biology': 49,
#   'cook': 20,
#   'love': 6,
#   'math': 55,
#   'scifi': 24},
#  'space': {'astronomy': 617,
#   'biology': 241,
#   'cook': 25,
#   'love': 19,
#   'math': 39,
#   'scifi': 609},
#  'vii': {'astronomy': 69,
#   'biology': 41,
#   'cook': 11,
#   'love': 6,
#   'math': 25,
#   'scifi': 20},
#  'arriving': {'astronomy': 14,
#   'biology': 17,
#   'cook': 2,
#   'love': 11,
#   'math': 1,
#   'scifi': 10},
#  'viii': {'astronomy': 69,
#   'biology': 21,
#   'cook': 11,
#   'love': 6,
#   'math': 21,
#   'scifi': 22},
#  'crater': {'astronomy': 121,
#   'biology': 6,
#   'cook': 6,
#   'love': 0,
#   'math': 0,
#   'scifi': 56},
#  'land': {'astronomy': 323,
#   'biology': 423,
#   'cook': 36,
#   'love': 21,
#   'math': 9,
#   'scifi': 189},
#  'ix': {'astronomy': 62,
#   'biology': 25,
#   'cook': 10,
#   'love': 6,
#   'math': 107,
#   'scifi': 20},
#  'flower': {'astronomy': 78,
#   'biology': 96,
#   'cook': 18,
#   'love': 10,
#   'math': 0,
#   'scifi': 44},
#  'soul': {'astronomy': 49,
#   'biology': 33,
#   'cook': 8,
#   'love': 38,
#   'math': 0,
#   'scifi': 209},
#  'x': {'astronomy': 89,
#   'biology': 50,
#   'cook': 211,
#   'love': 7,
#   'math': 6143,
#   'scifi': 60},
#  'alumion': {'astronomy': 0,
#   'biology': 0,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 32},
#  'xi': {'astronomy': 53,
#   'biology': 26,
#   'cook': 5,
#   'love': 6,
#   'math': 76,
#   'scifi': 15},
#  'flying': {'astronomy': 47,
#   'biology': 67,
#   'cook': 3,
#   'love': 6,
#   'math': 0,
#   'scifi': 59},
#  'ape': {'astronomy': 2,
#   'biology': 55,
#   'cook': 2,
#   'love': 0,
#   'math': 1,
#   'scifi': 108},
#  'xii': {'astronomy': 44,
#   'biology': 27,
#   'cook': 11,
#   'love': 6,
#   'math': 14,
#   'scifi': 15},
#  'sunward': {'astronomy': 8,
#   'biology': 0,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 5},
#  'ho': {'astronomy': 4,
#   'biology': 3,
#   'cook': 1,
#   'love': 0,
#   'math': 21,
#   'scifi': 4},
#  'xiii': {'astronomy': 28,
#   'biology': 21,
#   'cook': 8,
#   'love': 6,
#   'math': 9,
#   'scifi': 14},
#  'home': {'astronomy': 124,
#   'biology': 118,
#   'cook': 53,
#   'love': 420,
#   'math': 7,
#   'scifi': 194},
#  'again': {'astronomy': 558,
#   'biology': 637,
#   'cook': 201,
#   'love': 825,
#   'math': 163,
#   'scifi': 925},
#  'heaven': {'astronomy': 384,
#   'biology': 22,
#   'cook': 3,
#   'love': 41,
#   'math': 0,
#   'scifi': 107},
#  'that': {'astronomy': 12834,
#   'biology': 17055,
#   'cook': 2345,
#   'love': 7791,
#   'math': 3728,
#   'scifi': 10761},
#  'rolls': {'astronomy': 8,
#   'biology': 7,
#   'cook': 94,
#   'love': 3,
#   'math': 2,
#   'scifi': 3},
#  'around': {'astronomy': 214,
#   'biology': 188,
#   'cook': 166,
#   'love': 108,
#   'math': 9,
#   'scifi': 266},
#  'cries': {'astronomy': 9,
#   'biology': 49,
#   'cook': 1,
#   'love': 2,
#   'math': 0,
#   'scifi': 55},
#  'aloud': {'astronomy': 6,
#   'biology': 3,
#   'cook': 0,
#   'love': 43,
#   'math': 0,
#   'scifi': 51},
#  'while': {'astronomy': 821,
#   'biology': 855,
#   'cook': 274,
#   'love': 471,
#   'math': 85,
#   'scifi': 959},
#  'displays': {'astronomy': 17,
#   'biology': 23,
#   'cook': 0,
#   'love': 2,
#   'math': 0,
#   'scifi': 9},
#  'its': {'astronomy': 3829,
#   'biology': 3444,
#   'cook': 1257,
#   'love': 833,
#   'math': 838,
#   'scifi': 2011},
#  'eternal': {'astronomy': 65,
#   'biology': 15,
#   'cook': 5,
#   'love': 15,
#   'math': 0,
#   'scifi': 80},
#  'harmony': {'astronomy': 41,
#   'biology': 83,
#   'cook': 9,
#   'love': 17,
#   'math': 1,
#   'scifi': 29},
#  'yet': {'astronomy': 803,
#   'biology': 980,
#   'cook': 101,
#   'love': 431,
#   'math': 23,
#   'scifi': 769},
#  'your': {'astronomy': 252,
#   'biology': 261,
#   'cook': 389,
#   'love': 1706,
#   'math': 45,
#   'scifi': 1174},
#  'eyes': {'astronomy': 169,
#   'biology': 272,
#   'cook': 33,
#   'love': 445,
#   'math': 0,
#   'scifi': 841},
#  'are': {'astronomy': 5823,
#   'biology': 11389,
#   'cook': 3011,
#   'love': 1620,
#   'math': 2631,
#   'scifi': 2665},
#  'fixed': {'astronomy': 271,
#   'biology': 135,
#   'cook': 20,
#   'love': 93,
#   'math': 504,
#   'scifi': 140},
#  'upon': {'astronomy': 1408,
#   'biology': 774,
#   'cook': 457,
#   'love': 447,
#   'math': 135,
#   'scifi': 2369},
#  'alone': {'astronomy': 185,
#   'biology': 490,
#   'cook': 76,
#   'love': 184,
#   'math': 14,
#   'scifi': 392},
#  'dante': {'astronomy': 9,
#   'biology': 1,
#   'cook': 0,
#   'love': 1,
#   'math': 0,
#   'scifi': 2},
#  'truth': {'astronomy': 286,
#   'biology': 173,
#   'cook': 14,
#   'love': 122,
#   'math': 22,
#   'scifi': 158},
#  'within': {'astronomy': 420,
#   'biology': 530,
#   'cook': 235,
#   'love': 178,
#   'math': 20,
#   'scifi': 498},
#  'thy': {'astronomy': 199,
#   'biology': 15,
#   'cook': 9,
#   'love': 5,
#   'math': 0,
#   'scifi': 89},
#  'mind': {'astronomy': 250,
#   'biology': 406,
#   'cook': 50,
#   'love': 463,
#   'math': 14,
#   'scifi': 490},
#  'rehearse': {'astronomy': 0,
#   'biology': 0,
#   'cook': 0,
#   'love': 10,
#   'math': 0,
#   'scifi': 2},
#  'boúndless': {'astronomy': 0,
#   'biology': 0,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 1},
#  'universe': {'astronomy': 412,
#   'biology': 15,
#   'cook': 3,
#   'love': 2,
#   'math': 2,
#   'scifi': 140},
#  'boundless': {'astronomy': 23,
#   'biology': 7,
#   'cook': 1,
#   'love': 2,
#   'math': 0,
#   'scifi': 12},
#  'better': {'astronomy': 192,
#   'biology': 277,
#   'cook': 215,
#   'love': 504,
#   'math': 10,
#   'scifi': 256},
#  'worse': {'astronomy': 12,
#   'biology': 23,
#   'cook': 13,
#   'love': 101,
#   'math': 0,
#   'scifi': 67},
#  'think': {'astronomy': 139,
#   'biology': 317,
#   'cook': 68,
#   'love': 1186,
#   'math': 60,
#   'scifi': 409},
#  'mould': {'astronomy': 7,
#   'biology': 12,
#   'cook': 70,
#   'love': 2,
#   'math': 0,
#   'scifi': 11},
#  'hopes': {'astronomy': 19,
#   'biology': 10,
#   'cook': 5,
#   'love': 87,
#   'math': 3,
#   'scifi': 106},
#  'fears': {'astronomy': 16,
#   'biology': 2,
#   'cook': 0,
#   'love': 54,
#   'math': 1,
#   'scifi': 83},
#  'could': {'astronomy': 1075,
#   'biology': 833,
#   'cook': 132,
#   'love': 2570,
#   'math': 33,
#   'scifi': 2121},
#  'find': {'astronomy': 504,
#   'biology': 629,
#   'cook': 103,
#   'love': 310,
#   'math': 1007,
#   'scifi': 449},
#  'statelier': {'astronomy': 0,
#   'biology': 0,
#   'cook': 0,
#   'love': 1,
#   'math': 0,
#   'scifi': 1},
#  'than': {'astronomy': 2059,
#   'biology': 2993,
#   'cook': 746,
#   'love': 1416,
#   'math': 479,
#   'scifi': 1372},
#  'his': {'astronomy': 5565,
#   'biology': 2955,
#   'cook': 513,
#   'love': 5929,
#   'math': 295,
#   'scifi': 7210},
#  'peers': {'astronomy': 4,
#   'biology': 2,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 5},
#  'yonder': {'astronomy': 5,
#   'biology': 25,
#   'cook': 4,
#   'love': 0,
#   'math': 0,
#   'scifi': 20},
#  'hundred': {'astronomy': 318,
#   'biology': 270,
#   'cook': 32,
#   'love': 68,
#   'math': 26,
#   'scifi': 411},
#  'million': {'astronomy': 129,
#   'biology': 64,
#   'cook': 4,
#   'love': 8,
#   'math': 0,
#   'scifi': 47},
#  'spheres': {'astronomy': 65,
#   'biology': 19,
#   'cook': 0,
#   'love': 1,
#   'math': 8,
#   'scifi': 35},
#  'tennyson': {'astronomy': 17,
#   'biology': 5,
#   'cook': 0,
#   'love': 2,
#   'math': 0,
#   'scifi': 2},
#  'was': {'astronomy': 7824,
#   'biology': 3572,
#   'cook': 923,
#   'love': 9349,
#   'math': 288,
#   'scifi': 10646},
#  'glancing': {'astronomy': 1,
#   'biology': 7,
#   'cook': 0,
#   'love': 18,
#   'math': 0,
#   'scifi': 11},
#  'times': {'astronomy': 762,
#   'biology': 492,
#   'cook': 142,
#   'love': 108,
#   'math': 431,
#   'scifi': 274},
#  'newspaper': {'astronomy': 0,
#   'biology': 12,
#   'cook': 1,
#   'love': 26,
#   'math': 0,
#   'scifi': 11},
#  'morning': {'astronomy': 179,
#   'biology': 108,
#   'cook': 91,
#   'love': 319,
#   'math': 2,
#   'scifi': 279},
#  'train': {'astronomy': 57,
#   'biology': 54,
#   'cook': 4,
#   'love': 42,
#   'math': 14,
#   'scifi': 213},
#  'my': {'astronomy': 556,
#   'biology': 747,
#   'cook': 255,
#   'love': 2747,
#   'math': 83,
#   'scifi': 7971},
#  'fell': {'astronomy': 121,
#   'biology': 32,
#   'cook': 13,
#   'love': 60,
#   'math': 0,
#   'scifi': 291},
#  'on': {'astronomy': 5730,
#   'biology': 9820,
#   'cook': 3569,
#   'love': 3599,
#   'math': 1822,
#   'scifi': 4963},
#  'following': {'astronomy': 275,
#   'biology': 375,
#   'cook': 214,
#   'love': 92,
#   'math': 433,
#   'scifi': 189},
#  'item': {'astronomy': 2,
#   'biology': 6,
#   'cook': 6,
#   'love': 3,
#   'math': 2,
#   'scifi': 8},
#  'strange': {'astronomy': 114,
#   'biology': 165,
#   'cook': 13,
#   'love': 70,
#   'math': 2,
#   'scifi': 423},
#  'light': {'astronomy': 1438,
#   'biology': 349,
#   'cook': 357,
#   'love': 150,
#   'math': 32,
#   'scifi': 696},
#  'marson': {'astronomy': 0,
#   'biology': 0,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 1},
#  'monday': {'astronomy': 6,
#   'biology': 0,
#   'cook': 1,
#   'love': 20,
#   'math': 0,
#   'scifi': 17},
#  'afternoon': {'astronomy': 22,
#   'biology': 12,
#   'cook': 23,
#   'love': 71,
#   'math': 0,
#   'scifi': 45},
#  'dr': {'astronomy': 227,
#   'biology': 812,
#   'cook': 179,
#   'love': 98,
#   'math': 28,
#   'scifi': 54},
#  'krueger': {'astronomy': 0,
#   'biology': 0,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 1},
#  'who': {'astronomy': 1421,
#   'biology': 1617,
#   'cook': 478,
#   'love': 1388,
#   'math': 38,
#   'scifi': 1596},
#  'charge': {'astronomy': 105,
#   'biology': 119,
#   'cook': 84,
#   'love': 82,
#   'math': 3,
#   'scifi': 158},
#  'central': {'astronomy': 231,
#   'biology': 200,
#   'cook': 80,
#   'love': 7,
#   'math': 35,
#   'scifi': 55},
#  'bureau': {'astronomy': 8,
#   'biology': 15,
#   'cook': 3,
#   'love': 5,
#   'math': 1,
#   'scifi': 2},
#  'kiel': {'astronomy': 3,
#   'biology': 0,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 3},
#  'telegraphed': {'astronomy': 2,
#   'biology': 0,
#   'cook': 1,
#   'love': 1,
#   'math': 0,
#   'scifi': 4},
#  'correspondents': {'astronomy': 3,
#   'biology': 4,
#   'cook': 2,
#   'love': 2,
#   'math': 0,
#   'scifi': 3},
#  'projection': {'astronomy': 8,
#   'biology': 29,
#   'cook': 1,
#   'love': 2,
#   'math': 81,
#   'scifi': 11},
#  'lumineuse': {'astronomy': 0,
#   'biology': 1,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 1},
#  'dans': {'astronomy': 10,
#   'biology': 33,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 1},
#  'région': {'astronomy': 0,
#   'biology': 0,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 1},
#  'australe': {'astronomy': 0,
#   'biology': 0,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 1},
#  'du': {'astronomy': 74,
#   'biology': 32,
#   'cook': 1,
#   'love': 11,
#   'math': 3,
#   'scifi': 2},
#  'terminateur': {'astronomy': 0,
#   'biology': 0,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 1},
#  'de': {'astronomy': 622,
#   'biology': 296,
#   'cook': 88,
#   'love': 108,
#   'math': 95,
#   'scifi': 33},
#  'observée': {'astronomy': 0,
#   'biology': 0,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 1},
#  'par': {'astronomy': 12,
#   'biology': 17,
#   'cook': 5,
#   'love': 3,
#   'math': 6,
#   'scifi': 5},
#  'javelle': {'astronomy': 0,
#   'biology': 1,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 3},
#  'courant': {'astronomy': 0,
#   'biology': 0,
#   'cook': 0,
#   'love': 0,
#   'math': 1,
#   'scifi': 1},
#  'heuresperrotin': {'astronomy': 0,
#   'biology': 0,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 1},
#  'plain': {'astronomy': 107,
#   'biology': 127,
#   'cook': 149,
#   'love': 62,
#   'math': 20,
#   'scifi': 124},
#  'am': {'astronomy': 122,
#   'biology': 322,
#   'cook': 89,
#   'love': 1255,
#   'math': 42,
#   'scifi': 649},
#  'ray': {'astronomy': 32,
#   'biology': 23,
#   'cook': 4,
#   'love': 0,
#   'math': 1,
#   'scifi': 73},
#  'had': {'astronomy': 2875,
#   'biology': 2119,
#   'cook': 400,
#   'love': 6562,
#   'math': 264,
#   'scifi': 7130},
#  'been': {'astronomy': 3623,
#   'biology': 4823,
#   'cook': 849,
#   'love': 2659,
#   'math': 191,
#   'scifi': 2111},
#  'observed': {'astronomy': 556,
#   'biology': 412,
#   'cook': 52,
#   'love': 81,
#   'math': 17,
#   'scifi': 164},
#  'disc': {'astronomy': 74,
#   'biology': 24,
#   'cook': 1,
#   'love': 0,
#   'math': 4,
#   'scifi': 20},
#  'planet': {'astronomy': 923,
#   'biology': 30,
#   'cook': 1,
#   'love': 0,
#   'math': 4,
#   'scifi': 161},
#  'near': {'astronomy': 437,
#   'biology': 583,
#   'cook': 166,
#   'love': 161,
#   'math': 16,
#   'scifi': 360},
#  'terminator': {'astronomy': 0,
#   'biology': 0,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 5},
#  'say': {'astronomy': 429,
#   'biology': 506,
#   'cook': 99,
#   'love': 889,
#   'math': 145,
#   'scifi': 435},
#  'zone': {'astronomy': 108,
#   'biology': 42,
#   'cook': 18,
#   'love': 0,
#   'math': 0,
#   'scifi': 4},
#  'twilight': {'astronomy': 42,
#   'biology': 5,
#   'cook': 0,
#   'love': 14,
#   'math': 0,
#   'scifi': 31},
#  'separating': {'astronomy': 14,
#   'biology': 45,
#   'cook': 53,
#   'love': 4,
#   'math': 2,
#   'scifi': 9},
#  'day': {'astronomy': 970,
#   'biology': 501,
#   'cook': 209,
#   'love': 617,
#   'math': 26,
#   'scifi': 794},
#  'night': {'astronomy': 420,
#   'biology': 100,
#   'cook': 74,
#   'love': 265,
#   'math': 0,
#   'scifi': 600},
#  'news': {'astronomy': 25,
#   'biology': 18,
#   'cook': 3,
#   'love': 96,
#   'math': 0,
#   'scifi': 68},
#  'doubly': {'astronomy': 5,
#   'biology': 6,
#   'cook': 0,
#   'love': 9,
#   'math': 0,
#   'scifi': 19},
#  'interesting': {'astronomy': 199,
#   'biology': 209,
#   'cook': 28,
#   'love': 76,
#   'math': 9,
#   'scifi': 43},
#  'me': {'astronomy': 301,
#   'biology': 983,
#   'cook': 158,
#   'love': 2103,
#   'math': 17,
#   'scifi': 4292},
#  'because': {'astronomy': 504,
#   'biology': 407,
#   'cook': 139,
#   'love': 313,
#   'math': 72,
#   'scifi': 288},
#  'singular': {'astronomy': 68,
#   'biology': 61,
#   'cook': 8,
#   'love': 5,
#   'math': 0,
#   'scifi': 51},
#  'dream': {'astronomy': 30,
#   'biology': 12,
#   'cook': 2,
#   'love': 41,
#   'math': 0,
#   'scifi': 89},
#  'sunrise': {'astronomy': 27,
#   'biology': 3,
#   'cook': 0,
#   'love': 1,
#   'math': 0,
#   'scifi': 14},
#  'moon': {'astronomy': 1240,
#   'biology': 19,
#   'cook': 2,
#   'love': 28,
#   'math': 9,
#   'scifi': 128},
#  'quickened': {'astronomy': 3,
#   'biology': 0,
#   'cook': 0,
#   'love': 4,
#   'math': 0,
#   'scifi': 6},
#  'imagination': {'astronomy': 141,
#   'biology': 56,
#   'cook': 9,
#   'love': 61,
#   'math': 0,
#   'scifi': 124},
#  'as': {'astronomy': 9294,
#   'biology': 12822,
#   'cook': 3741,
#   'love': 5934,
#   'math': 2521,
#   'scifi': 7335},
#  'wonders': {'astronomy': 35,
#   'biology': 8,
#   'cook': 2,
#   'love': 9,
#   'math': 2,
#   'scifi': 23},
#  'beyond': {'astronomy': 232,
#   'biology': 291,
#   'cook': 26,
#   'love': 209,
#   'math': 68,
#   'scifi': 264},
#  'our': {'astronomy': 2386,
#   'biology': 1671,
#   'cook': 395,
#   'love': 389,
#   'math': 251,
#   'scifi': 2979},
#  'little': {'astronomy': 687,
#   'biology': 876,
#   'cook': 1355,
#   'love': 1194,
#   'math': 19,
#   'scifi': 1043},
#  'globe': {'astronomy': 323,
#   'biology': 89,
#   'cook': 12,
#   'love': 4,
#   'math': 1,
#   'scifi': 77},
#  'nevertobeforgotten': {'astronomy': 0,
#   'biology': 0,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 1},
#  'experience': {'astronomy': 107,
#   'biology': 146,
#   'cook': 56,
#   'love': 32,
#   'math': 12,
#   'scifi': 98},
#  'mine': {'astronomy': 27,
#   'biology': 21,
#   'cook': 9,
#   'love': 74,
#   'math': 8,
#   'scifi': 175},
#  'an': {'astronomy': 3678,
#   'biology': 4828,
#   'cook': 1631,
#   'love': 2003,
#   'math': 1159,
#   'scifi': 2804},
#  'aged': {'astronomy': 21,
#   'biology': 12,
#   'cook': 3,
#   'love': 2,
#   'math': 0,
#   'scifi': 22},
#  'astronomer': {'astronomy': 317,
#   'biology': 1,
#   'cook': 0,
#   'love': 0,
#   'math': 3,
#   'scifi': 32},
#  'several': {'astronomy': 383,
#   'biology': 902,
#   'cook': 244,
#   'love': 94,
#   'math': 46,
#   'scifi': 399},
#  'years': {'astronomy': 1436,
#   'biology': 886,
#   'cook': 109,
#   'love': 295,
#   'math': 140,
#   'scifi': 424},
#  'ago': {'astronomy': 193,
#   'biology': 221,
#   'cook': 33,
#   'love': 111,
#   'math': 7,
#   'scifi': 99},
#  'extraordinary': {'astronomy': 118,
#   'biology': 124,
#   'cook': 1,
#   'love': 53,
#   'math': 0,
#   'scifi': 72},
#  'man': {'astronomy': 729,
#   'biology': 2630,
#   'cook': 185,
#   'love': 839,
#   'math': 109,
#   'scifi': 1272},
#  'living': {'astronomy': 149,
#   'biology': 815,
#   'cook': 63,
#   'love': 97,
#   'math': 11,
#   'scifi': 157},
#  'life': {'astronomy': 816,
#   'biology': 1776,
#   'cook': 121,
#   'love': 395,
#   'math': 53,
#   'scifi': 842},
#  'recluse': {'astronomy': 5,
#   'biology': 0,
#   'cook': 1,
#   'love': 0,
#   'math': 0,
#   'scifi': 3},
#  'own': {'astronomy': 652,
#   'biology': 592,
#   'cook': 132,
#   'love': 1062,
#   'math': 13,
#   'scifi': 762},
#  'observatory': {'astronomy': 264,
#   'biology': 1,
#   'cook': 0,
#   'love': 0,
#   'math': 1,
#   'scifi': 24},
#  'which': {'astronomy': 9010,
#   'biology': 10828,
#   'cook': 2082,
#   'love': 2307,
#   'math': 2153,
#   'scifi': 5103},
#  'situated': {'astronomy': 164,
#   'biology': 108,
#   'cook': 16,
#   'love': 10,
#   'math': 19,
#   'scifi': 35},
#  'lonely': {'astronomy': 6,
#   'biology': 6,
#   'cook': 0,
#   'love': 11,
#   'math': 0,
#   'scifi': 29},
#  'part': {'astronomy': 793,
#   'biology': 1307,
#   'cook': 363,
#   'love': 354,
#   'math': 135,
#   'scifi': 482},
#  'country': {'astronomy': 242,
#   'biology': 462,
#   'cook': 118,
#   'love': 153,
#   'math': 12,
#   'scifi': 316},
#  'any': {'astronomy': 1939,
#   'biology': 2817,
#   'cook': 1099,
#   'love': 1819,
#   'math': 1378,
#   'scifi': 1550},
#  'rate': {'astronomy': 136,
#   'biology': 170,
#   'cook': 8,
#   'love': 55,
#   'math': 70,
#   'scifi': 53},
#  'believed': {'astronomy': 160,
#   'biology': 99,
#   'cook': 10,
#   'love': 133,
#   'math': 1,
#   'scifi': 75},
#  'he': {'astronomy': 5313,
#   'biology': 3110,
#   'cook': 496,
#   'love': 7990,
#   'math': 617,
#   'scifi': 7610},
#  'opened': {'astronomy': 82,
#   'biology': 43,
#   'cook': 16,
#   'love': 93,
#   'math': 2,
#   'scifi': 172},
#  'up': {'astronomy': 983,
#   'biology': 1390,
#   'cook': 1161,
#   'love': 1050,
#   'math': 72,
#   'scifi': 1383},
#  'communication': {'astronomy': 38,
#   'biology': 35,
#   'cook': 0,
#   'love': 34,
#   'math': 0,
#   'scifi': 43},
#  'inhabitants': {'astronomy': 120,
#   'biology': 131,
#   'cook': 7,
#   'love': 5,
#   'math': 0,
#   'scifi': 91},
#  'means': {'astronomy': 643,
#   'biology': 494,
#   'cook': 113,
#   'love': 209,
#   'math': 117,
#   'scifi': 354},
#  'powerful': {'astronomy': 166,
#   'biology': 117,
#   'cook': 10,
#   'love': 18,
#   'math': 0,
#   'scifi': 104},
#  'lights': {'astronomy': 79,
#   'biology': 11,
#   'cook': 1,
#   'love': 25,
#   'math': 0,
#   'scifi': 44},
#  'flashing': {'astronomy': 12,
#   'biology': 2,
#   'cook': 1,
#   'love': 1,
#   'math': 0,
#   'scifi': 21},
#  'manner': {'astronomy': 254,
#   'biology': 622,
#   'cook': 93,
#   'love': 283,
#   'math': 146,
#   'scifi': 212},
#  'signallantern': {'astronomy': 0,
#   'biology': 0,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 1},
#  'heliograph': {'astronomy': 0,
#   'biology': 0,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 4},
#  'him': {'astronomy': 1368,
#   'biology': 686,
#   'cook': 137,
#   'love': 3306,
#   'math': 59,
#   'scifi': 2706},
#  'down': {'astronomy': 546,
#   'biology': 684,
#   'cook': 283,
#   'love': 514,
#   'math': 52,
#   'scifi': 836},
#  'monomaniac': {'astronomy': 0,
#   'biology': 0,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 1},
#  'but': {'astronomy': 4846,
#   'biology': 5839,
#   'cook': 2307,
#   'love': 4736,
#   'math': 842,
#   'scifi': 5336},
#  'knows': {'astronomy': 52,
#   'biology': 78,
#   'cook': 22,
#   'love': 80,
#   'math': 4,
#   'scifi': 65},
#  'perhaps': {'astronomy': 396,
#   'biology': 420,
#   'cook': 78,
#   'love': 341,
#   'math': 7,
#   'scifi': 282},
#  'not': {'astronomy': 5218,
#   'biology': 6531,
#   'cook': 2966,
#   'love': 6545,
#   'math': 766,
#   'scifi': 5508},
#  'so': {'astronomy': 2909,
#   'biology': 3754,
#   'cook': 820,
#   'love': 3100,
#   'math': 541,
#   'scifi': 2386},
#  'crazy': {'astronomy': 0,
#   'biology': 4,
#   'cook': 0,
#   'love': 9,
#   'math': 0,
#   'scifi': 5},
#  'after': {'astronomy': 1043,
#   'biology': 1203,
#   'cook': 559,
#   'love': 888,
#   'math': 92,
#   'scifi': 1056},
#  'all': {'astronomy': 3446,
#   'biology': 4275,
#   'cook': 1730,
#   'love': 3203,
#   'math': 777,
#   'scifi': 3177},
#  'when': {'astronomy': 2228,
#   'biology': 3200,
#   'cook': 2583,
#   'love': 1688,
#   'math': 633,
#   'scifi': 2072},
#  'evening': {'astronomy': 189,
#   'biology': 65,
#   'cook': 20,
#   'love': 339,
#   'math': 0,
#   'scifi': 193},
#  'came': {'astronomy': 267,
#   'biology': 252,
#   'cook': 29,
#   'love': 484,
#   'math': 0,
#   'scifi': 817},
#  'turned': {'astronomy': 125,
#   'biology': 75,
#   'cook': 45,
#   'love': 262,
#   'math': 8,
#   'scifi': 488},
#  'books': {'astronomy': 89,
#   'biology': 41,
#   'cook': 25,
#   'love': 62,
#   'math': 109,
#   'scifi': 82},
#  'gathered': {'astronomy': 29,
#   'biology': 49,
#   'cook': 44,
#   'love': 12,
#   'math': 0,
#   'scifi': 68},
#  'great': {'astronomy': 2129,
#   'biology': 1774,
#   'cook': 228,
#   'love': 786,
#   'math': 65,
#   'scifi': 1178},
#  'deal': {'astronomy': 69,
#   'biology': 53,
#   'cook': 39,
#   'love': 227,
#   'math': 0,
#   'scifi': 63},
#  'about': {'astronomy': 1178,
#   'biology': 1300,
#   'cook': 1058,
#   'love': 1024,
#   'math': 90,
#   'scifi': 1462},
#  'fiery': {'astronomy': 50,
#   'biology': 8,
#   'cook': 2,
#   'love': 3,
#   'math': 0,
#   'scifi': 23},
#  'including': {'astronomy': 162,
#   'biology': 230,
#   'cook': 120,
#   'love': 63,
#   'math': 11,
#   'scifi': 119},
#  'fact': {'astronomy': 614,
#   'biology': 806,
#   'cook': 95,
#   'love': 160,
#   'math': 134,
#   'scifi': 328},
#  'stout': {'astronomy': 3,
#   'biology': 9,
#   'cook': 122,
#   'love': 6,
#   'math': 2,
#   'scifi': 10},
#  'daniel': {'astronomy': 33,
#   'biology': 4,
#   'cook': 3,
#   'love': 0,
#   'math': 7,
#   'scifi': 4},
#  'lambert': {'astronomy': 4,
#   'biology': 2,
#   'cook': 1,
#   'love': 0,
#   'math': 0,
#   'scifi': 1},
#  'jump': {'astronomy': 4,
#   'biology': 3,
#   'cook': 1,
#   'love': 9,
#   'math': 0,
#   'scifi': 14},
#  'height': {'astronomy': 231,
#   'biology': 185,
#   'cook': 84,
#   'love': 20,
#   'math': 11,
#   'scifi': 114},
#  'there': {'astronomy': 2487,
#   'biology': 3885,
#   'cook': 673,
#   'love': 1954,
#   'math': 458,
#   'scifi': 2051},
#  'greatest': {'astronomy': 260,
#   'biology': 192,
#   'cook': 24,
#   'love': 110,
#   'math': 47,
#   'scifi': 105},
#  'ease': {'astronomy': 13,
#   'biology': 15,
#   'cook': 15,
#   'love': 65,
#   'math': 3,
#   'scifi': 47},
#  'very': {'astronomy': 1402,
#   'biology': 1595,
#   'cook': 1767,
#   'love': 2708,
#   'math': 123,
#   'scifi': 1076},
#  'likely': {'astronomy': 88,
#   'biology': 89,
#   'cook': 24,
#   'love': 136,
#   'math': 5,
#   'scifi': 61},
#  'seeking': {'astronomy': 25,
#   'biology': 16,
#   'cook': 3,
#   'love': 16,
#   'math': 13,
#   'scifi': 32},
#  'information': {'astronomy': 165,
#   'biology': 197,
#   'cook': 117,
#   'love': 117,
#   'math': 13,
#   'scifi': 146},
#  'resolved': {'astronomy': 49,
#   'biology': 15,
#   'cook': 1,
#   'love': 93,
#   'math': 11,
#   'scifi': 101},
#  'walk': {'astronomy': 23,
#   'biology': 46,
#   'cook': 11,
#   'love': 187,
#   'math': 2,
#   'scifi': 69},
#  'over': {'astronomy': 762,
#   'biology': 976,
#   'cook': 1361,
#   'love': 674,
#   'math': 58,
#   'scifi': 996},
#  'consult': {'astronomy': 5,
#   'biology': 10,
#   'cook': 1,
#   'love': 23,
#   'math': 4,
#   'scifi': 12},
#  'old': {'astronomy': 526,
#   'biology': 628,
#   'cook': 372,
#   'love': 465,
#   'math': 76,
#   'scifi': 461},
#  'friend': {'astronomy': 108,
#   'biology': 57,
#   'cook': 31,
#   'love': 395,
#   'math': 1,
#   'scifi': 268},
#  'professor': {'astronomy': 257,
#   'biology': 438,
#   'cook': 155,
#   'love': 12,
#   'math': 17,
#   'scifi': 403},
#  'gazen': {'astronomy': 0,
#   'biology': 0,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 156},
#  'wellknown': {'astronomy': 53,
#   'biology': 50,
#   'cook': 11,
#   'love': 7,
#   'math': 3,
#   'scifi': 15},
#  'made': {'astronomy': 1333,
#   'biology': 943,
#   'cook': 597,
#   'love': 778,
#   'math': 134,
#   'scifi': 875},
#  'mark': {'astronomy': 46,
#   'biology': 107,
#   'cook': 65,
#   'love': 11,
#   'math': 11,
#   'scifi': 66},
#  'series': {'astronomy': 158,
#   'biology': 477,
#   'cook': 73,
#   'love': 12,
#   'math': 326,
#   'scifi': 57},
#  'splendid': {'astronomy': 115,
#   'biology': 102,
#   'cook': 4,
#   'love': 7,
#   'math': 0,
#   'scifi': 48},
#  'researches': {'astronomy': 124,
#   'biology': 85,
#   'cook': 1,
#   'love': 1,
#   'math': 4,
#   'scifi': 9},
#  'spectroscope': {'astronomy': 49,
#   'biology': 0,
#   'cook': 1,
#   'love': 0,
#   'math': 1,
#   'scifi': 10},
#  'into': {'astronomy': 1661,
#   'biology': 2190,
#   'cook': 2115,
#   'love': 985,
#   'math': 290,
#   'scifi': 1744},
#  'constitution': {'astronomy': 64,
#   'biology': 149,
#   'cook': 12,
#   'love': 13,
#   'math': 3,
#   'scifi': 10},
#  'sun': {'astronomy': 2219,
#   'biology': 157,
#   'cook': 40,
#   'love': 25,
#   'math': 15,
#   'scifi': 432},
#  'celestial': {'astronomy': 360,
#   'biology': 4,
#   'cook': 1,
#   'love': 0,
#   'math': 3,
#   'scifi': 35},
#  'bodies': {'astronomy': 624,
#   'biology': 282,
#   'cook': 9,
#   'love': 5,
#   'math': 14,
#   'scifi': 174},
#  'fine': {'astronomy': 116,
#   'biology': 250,
#   'cook': 523,
#   'love': 145,
#   'math': 8,
#   'scifi': 67},
#  'clear': {'astronomy': 212,
#   'biology': 223,
#   'cook': 172,
#   'love': 64,
#   'math': 33,
#   'scifi': 185},
#  'sky': {'astronomy': 356,
#   'biology': 87,
#   'cook': 0,
#   'love': 24,
#   'math': 0,
#   'scifi': 187},
#  'cloudless': {'astronomy': 10,
#   'biology': 3,
#   'cook': 0,
#   'love': 2,
#   'math': 0,
#   'scifi': 10},
#  'deep': {'astronomy': 159,
#   'biology': 163,
#   'cook': 175,
#   'love': 74,
#   'math': 3,
#   'scifi': 210},
#  'dark': {'astronomy': 223,
#   'biology': 183,
#   'cook': 171,
#   'love': 82,
#   'math': 1,
#   'scifi': 274},
#  'blue': {'astronomy': 102,
#   'biology': 237,
#   'cook': 104,
#   'love': 60,
#   'math': 0,
#   'scifi': 107},
#  'revealed': {'astronomy': 110,
#   'biology': 17,
#   'cook': 1,
#   'love': 8,
#   'math': 0,
#   'scifi': 34},
#  'highest': {'astronomy': 138,
#   'biology': 251,
#   'cook': 12,
#   'love': 31,
#   'math': 35,
#   'scifi': 63},
#  'heavens': {'astronomy': 701,
#   'biology': 12,
#   'cook': 1,
#   'love': 13,
#   'math': 2,
#   'scifi': 78},
#  'silvery': {'astronomy': 13,
#   'biology': 14,
#   'cook': 3,
#   'love': 2,
#   'math': 0,
#   'scifi': 11},
#  'lustre': {'astronomy': 27,
#   'biology': 14,
#   'cook': 0,
#   'love': 2,
#   'math': 0,
#   'scifi': 12},
#  'milky': {'astronomy': 152,
#   'biology': 8,
#   'cook': 9,
#   'love': 0,
#   'math': 0,
#   'scifi': 8},
#  'way': {'astronomy': 717,
#   'biology': 636,
#   'cook': 415,
#   'love': 596,
#   'math': 159,
#   'scifi': 765},
#  'belt': {'astronomy': 41,
#   'biology': 25,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 41},
#  'orion': {'astronomy': 147,
#   'biology': 1,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 2},
#  'shone': {'astronomy': 32,
#   'biology': 8,
#   'cook': 1,
#   'love': 10,
#   'math': 0,
#   'scifi': 38},
#  'conspicuously': {'astronomy': 6,
#   'biology': 60,
#   'cook': 5,
#   'love': 4,
#   'math': 0,
#   'scifi': 3},
#  'east': {'astronomy': 219,
#   'biology': 173,
#   'cook': 17,
#   'love': 29,
#   'math': 4,
#   'scifi': 88},
#  'sirius': {'astronomy': 111,
#   'biology': 5,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 2},
#  'blazed': {'astronomy': 6,
#   'biology': 0,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 13},
#  'gem': {'astronomy': 5,
#   'biology': 0,
#   'cook': 6,
#   'love': 0,
#   'math': 1,
#   'scifi': 6},
#  'more': {'astronomy': 2449,
#   'biology': 3921,
#   'cook': 1183,
#   'love': 1672,
#   'math': 388,
#   'scifi': 1647},
#  'south': {'astronomy': 364,
#   'biology': 468,
#   'cook': 42,
#   'love': 20,
#   'math': 4,
#   'scifi': 139},
#  'looked': {'astronomy': 77,
#   'biology': 84,
#   'cook': 21,
#   'love': 433,
#   'math': 4,
#   'scifi': 425},
#  'soon': {'astronomy': 211,
#   'biology': 307,
#   'cook': 234,
#   'love': 738,
#   'math': 9,
#   'scifi': 504},
#  'found': {'astronomy': 970,
#   'biology': 1213,
#   'cook': 558,
#   'love': 418,
#   'math': 351,
#   'scifi': 797},
#  'farther': {'astronomy': 53,
#   'biology': 102,
#   'cook': 5,
#   'love': 122,
#   'math': 9,
#   'scifi': 83},
#  'north': {'astronomy': 310,
#   'biology': 574,
#   'cook': 183,
#   'love': 18,
#   'math': 8,
#   'scifi': 139},
#  'large': {'astronomy': 514,
#   'biology': 1031,
#   'cook': 800,
#   'love': 131,
#   'math': 52,
#   'scifi': 223},
#  'red': {'astronomy': 158,
#   'biology': 357,
#   'cook': 499,
#   'love': 40,
#   'math': 2,
#   'scifi': 277},
#  'star': {'astronomy': 1098,
#   'biology': 19,
#   'cook': 4,
#   'love': 10,
#   'math': 4,
#   'scifi': 100},
#  'amongst': {'astronomy': 95,
#   'biology': 163,
#   'cook': 30,
#   'love': 25,
#   'math': 5,
#   'scifi': 30},
#  'white': {'astronomy': 175,
#   'biology': 636,
#   'cook': 2109,
#   'love': 85,
#   'math': 20,
#   'scifi': 281},
#  'encircling': {'astronomy': 7,
#   'biology': 4,
#   'cook': 8,
#   'love': 1,
#   'math': 0,
#   'scifi': 7},
#  'constellations': {'astronomy': 339,
#   'biology': 2,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 7},
#  'quite': {'astronomy': 316,
#   'biology': 477,
#   'cook': 337,
#   'love': 682,
#   'math': 19,
#   'scifi': 360},
#  'arrived': {'astronomy': 97,
#   'biology': 80,
#   'cook': 11,
#   'love': 81,
#   'math': 2,
#   'scifi': 139},
#  'busily': {'astronomy': 2,
#   'biology': 4,
#   'cook': 2,
#   'love': 3,
#   'math': 0,
#   'scifi': 9},
#  'engaged': {'astronomy': 65,
#   'biology': 39,
#   'cook': 6,
#   'love': 139,
#   'math': 1,
#   'scifi': 78},
#  'writing': {'astronomy': 103,
#   'biology': 66,
#   'cook': 49,
#   'love': 78,
#   'math': 61,
#   'scifi': 71},
#  'computing': {'astronomy': 6,
#   'biology': 0,
#   'cook': 0,
#   'love': 0,
#   'math': 19,
#   'scifi': 1},
#  'desk': {'astronomy': 10,
#   'biology': 2,
#   'cook': 1,
#   'love': 14,
#   'math': 2,
#   'scifi': 20},
#  'hope': {'astronomy': 158,
#   'biology': 124,
#   'cook': 30,
#   'love': 464,
#   'math': 3,
#   'scifi': 423},
#  'im': {'astronomy': 4,
#   'biology': 13,
#   'cook': 17,
#   'love': 259,
#   'math': 24,
#   'scifi': 67},
#  'disturbing': {'astronomy': 54,
#   'biology': 19,
#   'cook': 4,
#   'love': 6,
#   'math': 2,
#   'scifi': 9},
#  'said': {'astronomy': 436,
#   'biology': 489,
#   'cook': 310,
#   'love': 1831,
#   'math': 121,
#   'scifi': 1474},
#  'shook': {'astronomy': 4,
#   'biology': 5,
#   'cook': 3,
#   'love': 59,
#   'math': 0,
#   'scifi': 82},
#  'hands': {'astronomy': 103,
#   'biology': 153,
#   'cook': 77,
#   'love': 162,
#   'math': 5,
#   'scifi': 391},
#  'know': {'astronomy': 435,
#   'biology': 482,
#   'cook': 114,
#   'love': 1185,
#   'math': 71,
#   'scifi': 683},
#  'astronomers': {'astronomy': 344,
#   'biology': 5,
#   'cook': 0,
#   'love': 0,
#   'math': 1,
#   'scifi': 12},
#  'must': {'astronomy': 1409,
#   'biology': 1842,
#   'cook': 509,
#   'love': 1678,
#   'math': 623,
#   'scifi': 1217},
#  'work': {'astronomy': 1436,
#   'biology': 1171,
#   'cook': 802,
#   'love': 398,
#   'math': 73,
#   'scifi': 815},
#  'cometh': {'astronomy': 42,
#   'biology': 0,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 1},
#  'dont': {'astronomy': 3,
#   'biology': 41,
#   'cook': 39,
#   'love': 352,
#   'math': 2,
#   'scifi': 118},
#  'mention': {'astronomy': 71,
#   'biology': 53,
#   'cook': 24,
#   'love': 69,
#   'math': 12,
#   'scifi': 25},
#  'replied': {'astronomy': 15,
#   'biology': 19,
#   'cook': 7,
#   'love': 241,
#   'math': 8,
#   'scifi': 460},
#  'cordially': {'astronomy': 1,
#   'biology': 0,
#   'cook': 1,
#   'love': 11,
#   'math': 1,
#   'scifi': 1},
#  'observing': {'astronomy': 77,
#   'biology': 50,
#   'cook': 2,
#   'love': 42,
#   'math': 4,
#   'scifi': 26},
#  'one': {'astronomy': 3238,
#   'biology': 4733,
#   'cook': 3746,
#   'love': 1806,
#   'math': 1659,
#   'scifi': 2839},
#  'nebulas': {'astronomy': 2,
#   'biology': 0,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 1},
#  'just': {'astronomy': 360,
#   'biology': 527,
#   'cook': 325,
#   'love': 617,
#   'math': 150,
#   'scifi': 451},
#  'now': {'astronomy': 1431,
#   'biology': 1829,
#   'cook': 221,
#   'love': 1113,
#   'math': 453,
#   'scifi': 1784},
#  'wont': {'astronomy': 9,
#   'biology': 11,
#   'cook': 13,
#   'love': 76,
#   'math': 0,
#   'scifi': 47},
#  'be': {'astronomy': 7070,
#   'biology': 9407,
#   'cook': 3508,
#   'love': 6268,
#   'math': 5037,
#   'scifi': 4433},
#  'sight': {'astronomy': 183,
#   'biology': 150,
#   'cook': 16,
#   'love': 105,
#   'math': 6,
#   'scifi': 293},
#  'long': {'astronomy': 792,
#   'biology': 1195,
#   'cook': 1108,
#   'love': 643,
#   'math': 70,
#   'scifi': 815},
#  'time': {'astronomy': 1818,
#   'biology': 1517,
#   'cook': 542,
#   'love': 1001,
#   'math': 168,
#   'scifi': 1661},
#  'what': {'astronomy': 1034,
#   'biology': 1140,
#   'cook': 263,
#   'love': 2132,
#   'math': 1523,
#   'scifi': 1759},
#  'mysterious': {'astronomy': 90,
#   'biology': 30,
#   'cook': 2,
#   'love': 17,
#   'math': 0,
#   'scifi': 78},
#  'have': {'astronomy': 4934,
#   'biology': 8040,
#   'cook': 1690,
#   'love': 4305,
#   'math': 1490,
#   'scifi': 3631},
#  'seen': {'astronomy': 775,
#   'biology': 912,
#   'cook': 164,
#   'love': 318,
#   'math': 98,
#   'scifi': 502},
#  'anything': {'astronomy': 133,
#   'biology': 129,
#   'cook': 82,
#   'love': 334,
#   'math': 3,
#   'scifi': 180},
#  'laughed': {'astronomy': 2,
#   'biology': 7,
#   'cook': 3,
#   'love': 90,
#   'math': 0,
#   'scifi': 55},
#  'though': {'astronomy': 677,
#   'biology': 986,
#   'cook': 160,
#   'love': 754,
#   'math': 23,
#   'scifi': 540},
#  'did': {'astronomy': 543,
#   'biology': 301,
#   'cook': 72,
#   'love': 1137,
#   'math': 130,
#   'scifi': 1266},
#  'look': {'astronomy': 176,
#   'biology': 196,
#   'cook': 91,
#   'love': 456,
#   'math': 12,
#   'scifi': 337},
#  'believe': {'astronomy': 148,
#   'biology': 286,
#   'cook': 41,
#   'love': 339,
#   'math': 5,
#   'scifi': 264},
#  'something': {'astronomy': 130,
#   'biology': 220,
#   'cook': 55,
#   'love': 447,
#   'math': 7,
#   'scifi': 289},
#  'kind': {'astronomy': 237,
#   'biology': 598,
#   'cook': 122,
#   'love': 307,
#   'math': 70,
#   'scifi': 287},
#  'has': {'astronomy': 3121,
#   'biology': 4465,
#   'cook': 1095,
#   'love': 935,
#   'math': 703,
#   'scifi': 998},
#  'oh': {'astronomy': 17,
#   'biology': 27,
#   'cook': 10,
#   'love': 563,
#   'math': 5,
#   'scifi': 104},
#  'certainly': {'astronomy': 183,
#   'biology': 206,
#   'cook': 43,
#   'love': 286,
#   'math': 8,
#   'scifi': 158},
#  'nice': {'astronomy': 8,
#   'biology': 17,
#   'cook': 107,
#   'love': 47,
#   'math': 0,
#   'scifi': 9},
#  'monsieur': {'astronomy': 0,
#   'biology': 0,
#   'cook': 3,
#   'love': 15,
#   'math': 0,
#   'scifi': 51},
#  'perrotin': {'astronomy': 0,
#   'biology': 0,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 2},
#  'director': {'astronomy': 31,
#   'biology': 25,
#   'cook': 12,
#   'love': 6,
#   'math': 8,
#   'scifi': 19},
#  'finest': {'astronomy': 32,
#   'biology': 42,
#   'cook': 29,
#   'love': 16,
#   'math': 0,
#   'scifi': 9},
#  'telescopes': {'astronomy': 116,
#   'biology': 1,
#   'cook': 0,
#   'love': 0,
#   'math': 2,
#   'scifi': 7},
#  'existence': {'astronomy': 328,
#   'biology': 325,
#   'cook': 13,
#   'love': 23,
#   'math': 24,
#   'scifi': 171},
#  'careful': {'astronomy': 69,
#   'biology': 72,
#   'cook': 88,
#   'love': 15,
#   'math': 10,
#   'scifi': 41},
#  'do': {'astronomy': 788,
#   'biology': 1563,
#   'cook': 767,
#   'love': 1989,
#   'math': 149,
#   'scifi': 1345},
#  'account': {'astronomy': 321,
#   'biology': 359,
#   'cook': 52,
#   'love': 170,
#   'math': 73,
#   'scifi': 145},
#  'outside': {'astronomy': 122,
#   'biology': 156,
#   'cook': 94,
#   'love': 50,
#   'math': 9,
#   'scifi': 130},
#  'responded': {'astronomy': 2,
#   'biology': 6,
#   'cook': 1,
#   'love': 2,
#   'math': 0,
#   'scifi': 45},
#  'else': {'astronomy': 110,
#   'biology': 77,
#   'cook': 41,
#   'love': 257,
#   'math': 49,
#   'scifi': 125},
#  'should': {'astronomy': 800,
#   'biology': 1164,
#   'cook': 757,
#   'love': 1230,
#   'math': 285,
#   'scifi': 1081},
#  'ascribe': {'astronomy': 20,
#   'biology': 13,
#   'cook': 0,
#   'love': 1,
#   'math': 0,
#   'scifi': 9},
#  'small': {'astronomy': 610,
#   'biology': 1109,
#   'cook': 1152,
#   'love': 170,
#   'math': 74,
#   'scifi': 359},
#  'comet': {'astronomy': 468,
#   'biology': 0,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 3},
#  'due': {'astronomy': 334,
#   'biology': 287,
#   'cook': 56,
#   'love': 67,
#   'math': 55,
#   'scifi': 104},
#  'aurora': {'astronomy': 82,
#   'biology': 2,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 4},
#  'writer': {'astronomy': 87,
#   'biology': 44,
#   'cook': 133,
#   'love': 13,
#   'math': 1,
#   'scifi': 18},
#  'nature': {'astronomy': 844,
#   'biology': 851,
#   'cook': 69,
#   'love': 126,
#   'math': 27,
#   'scifi': 462},
#  'suggested': {'astronomy': 116,
#   'biology': 127,
#   'cook': 7,
#   'love': 50,
#   'math': 13,
#   'scifi': 54},
#  'range': {'astronomy': 65,
#   'biology': 212,
#   'cook': 27,
#   'love': 9,
#   'math': 6,
#   'scifi': 68},
#  'snowy': {'astronomy': 10,
#   'biology': 34,
#   'cook': 8,
#   'love': 5,
#   'math': 0,
#   'scifi': 27},
#  'alps': {'astronomy': 62,
#   'biology': 90,
#   'cook': 1,
#   'love': 0,
#   'math': 14,
#   'scifi': 19},
#  'even': {'astronomy': 1095,
#   'biology': 1395,
#   'cook': 643,
#   'love': 557,
#   'math': 118,
#   'scifi': 995},
#  'bright': {'astronomy': 246,
#   'biology': 276,
#   'cook': 152,
#   'love': 30,
#   'math': 0,
#   'scifi': 82},
#  'cloud': {'astronomy': 124,
#   'biology': 26,
#   'cook': 2,
#   'love': 14,
#   'math': 0,
#   'scifi': 70},
#  'reflecting': {'astronomy': 36,
#   'biology': 11,
#   'cook': 0,
#   'love': 5,
#   'math': 0,
#   'scifi': 13},
#  'possibly': {'astronomy': 91,
#   'biology': 88,
#   'cook': 32,
#   'love': 51,
#   'math': 2,
#   'scifi': 72},
#  'martians': {'astronomy': 4,
#   'biology': 0,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 271},
#  'forest': {'astronomy': 40,
#   'biology': 181,
#   'cook': 17,
#   'love': 3,
#   'math': 3,
#   'scifi': 211},
#  'fires': {'astronomy': 25,
#   'biology': 11,
#   'cook': 4,
#   'love': 4,
#   'math': 0,
#   'scifi': 29},
#  'america': {'astronomy': 143,
#   'biology': 479,
#   'cook': 50,
#   'love': 15,
#   'math': 5,
#   'scifi': 64},
#  'started': {'astronomy': 55,
#   'biology': 18,
#   'cook': 8,
#   'love': 41,
#   'math': 5,
#   'scifi': 122},
#  'rival': {'astronomy': 20,
#   'biology': 35,
#   'cook': 4,
#   'love': 4,
#   'math': 0,
#   'scifi': 7},
#  'illumination': {'astronomy': 39,
#   'biology': 3,
#   'cook': 0,
#   'love': 3,
#   'math': 0,
#   'scifi': 11},
#  'strikes': {'astronomy': 10,
#   'biology': 21,
#   'cook': 2,
#   'love': 7,
#   'math': 0,
#   'scifi': 8},
#  'likeliest': {'astronomy': 0,
#   'biology': 0,
#   'cook': 0,
#   'love': 4,
#   'math': 0,
#   'scifi': 1},
#  'these': {'astronomy': 2549,
#   'biology': 3745,
#   'cook': 592,
#   'love': 343,
#   'math': 816,
#   'scifi': 1484},
#  'notions': {'astronomy': 18,
#   'biology': 17,
#   'cook': 2,
#   'love': 21,
#   'math': 14,
#   'scifi': 21},
#  'mountain': {'astronomy': 260,
#   'biology': 218,
#   'cook': 5,
#   'love': 2,
#   'math': 1,
#   'scifi': 96},
#  'peaks': {'astronomy': 36,
#   'biology': 5,
#   'cook': 2,
#   'love': 2,
#   'math': 1,
#   'scifi': 12},
#  'catching': {'astronomy': 5,
#   'biology': 26,
#   'cook': 3,
#   'love': 11,
#   'math': 0,
#   'scifi': 13},
#  'sunshine': {'astronomy': 33,
#   'biology': 68,
#   'cook': 7,
#   'love': 12,
#   'math': 0,
#   'scifi': 24},
#  'might': {'astronomy': 696,
#   'biology': 689,
#   'cook': 113,
#   'love': 1051,
#   'math': 65,
#   'scifi': 942},
#  'glare': {'astronomy': 9,
#   'biology': 5,
#   'cook': 0,
#   'love': 5,
#   'math': 0,
#   'scifi': 29},
#  'city': {'astronomy': 152,
#   'biology': 131,
#   'cook': 49,
#   'love': 36,
#   'math': 8,
#   'scifi': 261},
#  'searchlightin': {'astronomy': 0,
#   'biology': 0,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 1},
#  'short': {'astronomy': 192,
#   'biology': 337,
#   'cook': 323,
#   'love': 196,
#   'math': 15,
#   'scifi': 216},
#  'signal': {'astronomy': 8,
#   'biology': 9,
#   'cook': 1,
#   'love': 6,
#   'math': 0,
#   'scifi': 77},
#  'dear': {'astronomy': 20,
#   'biology': 14,
#   'cook': 44,
#   'love': 720,
#   'math': 10,
#   'scifi': 292},
#  'exclaimed': {'astronomy': 6,
#   'biology': 10,
#   'cook': 4,
#   'love': 65,
#   'math': 0,
#   'scifi': 148},
#  'smiling': {'astronomy': 4,
#   'biology': 1,
#   'cook': 1,
#   'love': 74,
#   'math': 0,
#   'scifi': 47},
#  'incredulously': {'astronomy': 0,
#   'biology': 0,
#   'cook': 0,
#   'love': 2,
# ...
#   'cook': 6,
#   'love': 12,
#   'math': 0,
#   'scifi': 40},
#  'point': {'astronomy': 534,
#   'biology': 515,
#   'cook': 152,
#   'love': 196,
#   'math': 1622,
#   'scifi': 454},
#  'appeared': {'astronomy': 249,
#   'biology': 187,
#   'cook': 12,
#   'love': 153,
#   'math': 7,
#   'scifi': 365},
#  'side': {'astronomy': 297,
#   'biology': 629,
#   'cook': 203,
#   'love': 290,
#   'math': 133,
#   'scifi': 444},
#  'hallo': {'astronomy': 0,
#   'biology': 0,
#   'cook': 1,
#   'love': 3,
#   'math': 0,
#   'scifi': 5},
#  'involuntarily': {'astronomy': 9,
#   'biology': 1,
#   'cook': 0,
#   'love': 9,
#   'math': 0,
#   'scifi': 10},
#  'theres': {'astronomy': 1,
#   'biology': 3,
#   'cook': 5,
#   'love': 79,
#   'math': 0,
#   'scifi': 42},
#  'really': {'astronomy': 175,
#   'biology': 142,
#   'cook': 40,
#   'love': 439,
#   'math': 18,
#   'scifi': 169},
#  'tone': {'astronomy': 11,
#   'biology': 14,
#   'cook': 4,
#   'love': 115,
#   'math': 2,
#   'scifi': 114},
#  'surprise': {'astronomy': 41,
#   'biology': 37,
#   'cook': 9,
#   'love': 108,
#   'math': 0,
#   'scifi': 137},
#  'unmingled': {'astronomy': 0,
#   'biology': 0,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 8},
#  'doubt': {'astronomy': 301,
#   'biology': 410,
#   'cook': 38,
#   'love': 219,
#   'math': 4,
#   'scifi': 183},
#  'distinct': {'astronomy': 108,
#   'biology': 566,
#   'cook': 219,
#   'love': 17,
#   'math': 61,
#   'scifi': 41},
#  'let': {'astronomy': 245,
#   'biology': 343,
#   'cook': 771,
#   'love': 344,
#   'math': 954,
#   'scifi': 405},
#  'hastily': {'astronomy': 11,
#   'biology': 7,
#   'cook': 1,
#   'love': 28,
#   'math': 0,
#   'scifi': 36},
#  'yielded': {'astronomy': 32,
#   'biology': 40,
#   'cook': 3,
#   'love': 12,
#   'math': 0,
#   'scifi': 48},
#  'declared': {'astronomy': 31,
#   'biology': 34,
#   'cook': 4,
#   'love': 41,
#   'math': 0,
#   'scifi': 41},
#  'pause': {'astronomy': 7,
#   'biology': 25,
#   'cook': 4,
#   'love': 71,
#   'math': 0,
#   'scifi': 30},
#  'hidden': {'astronomy': 35,
#   'biology': 66,
#   'cook': 7,
#   'love': 4,
#   'math': 0,
#   'scifi': 63},
#  'till': {'astronomy': 144,
#   'biology': 177,
#   'cook': 221,
#   'love': 352,
#   'math': 8,
#   'scifi': 119},
#  'each': {'astronomy': 880,
#   'biology': 1809,
#   'cook': 743,
#   'love': 333,
#   'math': 1103,
#   'scifi': 671},
#  'silence': {'astronomy': 39,
#   'biology': 32,
#   'cook': 6,
#   'love': 127,
#   'math': 0,
#   'scifi': 189},
#  'saw': {'astronomy': 183,
#   'biology': 218,
#   'cook': 24,
#   'love': 450,
#   'math': 36,
#   'scifi': 806},
#  'ejaculated': {'astronomy': 0,
#   'biology': 0,
#   'cook': 1,
#   'love': 0,
#   'math': 0,
#   'scifi': 8},
#  'length': {'astronomy': 303,
#   'biology': 312,
#   'cook': 297,
#   'love': 86,
#   'math': 272,
#   'scifi': 316},
#  'hellas': {'astronomy': 0,
#   'biology': 0,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 1},
#  'system': {'astronomy': 821,
#   'biology': 444,
#   'cook': 51,
#   'love': 23,
#   'math': 333,
#   'scifi': 252},
#  'daresay': {'astronomy': 0,
#   'biology': 1,
#   'cook': 3,
#   'love': 2,
#   'math': 0,
#   'scifi': 6},
#  'possess': {'astronomy': 91,
#   'biology': 211,
#   'cook': 24,
#   'love': 14,
#   'math': 4,
#   'scifi': 49},
#  'put': {'astronomy': 160,
#   'biology': 220,
#   'cook': 1368,
#   'love': 252,
#   'math': 109,
#   'scifi': 249},
#  'glass': {'astronomy': 91,
#   'biology': 55,
#   'cook': 195,
#   'love': 30,
#   'math': 8,
#   'scifi': 66},
#  'awaited': {'astronomy': 6,
#   'biology': 1,
#   'cook': 1,
#   'love': 6,
#   'math': 0,
#   'scifi': 31},
#  'result': {'astronomy': 279,
#   'biology': 450,
#   'cook': 42,
#   'love': 33,
#   'math': 224,
#   'scifi': 113},
#  'observation': {'astronomy': 384,
#   'biology': 102,
#   'cook': 17,
#   'love': 44,
#   'math': 4,
#   'scifi': 71},
#  'eager': {'astronomy': 15,
#   'biology': 32,
#   'cook': 3,
#   'love': 71,
#   'math': 0,
#   'scifi': 56},
#  'interest': {'astronomy': 197,
#   'biology': 122,
#   'cook': 20,
#   'love': 159,
#   'math': 65,
#   'scifi': 147},
#  'steady': {'astronomy': 23,
#   'biology': 17,
#   'cook': 11,
#   'love': 41,
#   'math': 0,
#   'scifi': 28},
#  'possible': {'astronomy': 301,
#   'biology': 343,
#   'cook': 140,
#   'love': 237,
#   'math': 70,
#   'scifi': 276},
#  'steadiness': {'astronomy': 3,
#   'biology': 1,
#   'cook': 0,
#   'love': 9,
#   'math': 0,
#   'scifi': 2},
#  'puzzles': {'astronomy': 3,
#   'biology': 1,
#   'cook': 2,
#   'love': 1,
#   'math': 0,
#   'scifi': 2},
#  'flash': {'astronomy': 15,
#   'biology': 2,
#   'cook': 3,
#   'love': 17,
#   'math': 0,
#   'scifi': 59},
#  'necessarily': {'astronomy': 110,
#   'biology': 115,
#   'cook': 21,
#   'love': 25,
#   'math': 12,
#   'scifi': 39},
#  'mock': {'astronomy': 0,
#   'biology': 1,
#   'cook': 23,
#   'love': 4,
#   'math': 0,
#   'scifi': 12},
#  'gravity': {'astronomy': 142,
#   'biology': 30,
#   'cook': 4,
#   'love': 16,
#   'math': 38,
#   'scifi': 49},
#  'lighthouse': {'astronomy': 4,
#   'biology': 2,
#   'cook': 0,
#   'love': 1,
#   'math': 0,
#   'scifi': 5},
#  'kaiser': {'astronomy': 2,
#   'biology': 0,
#   'cook': 1,
#   'love': 0,
#   'math': 0,
#   'scifi': 1},
#  'autumn': {'astronomy': 66,
#   'biology': 90,
#   'cook': 73,
#   'love': 23,
#   'math': 1,
#   'scifi': 15},
#  'manoeuvres': {'astronomy': 0,
#   'biology': 0,
#   'cook': 0,
#   'love': 1,
#   'math': 0,
#   'scifi': 2},
#  'warlike': {'astronomy': 3,
#   'biology': 3,
#   'cook': 2,
#   'love': 0,
#   'math': 0,
#   'scifi': 15},
#  'advertisement': {'astronomy': 0,
#   'biology': 0,
#   'cook': 3,
#   'love': 1,
#   'math': 0,
#   'scifi': 4},
#  'soap': {'astronomy': 3,
#   'biology': 3,
#   'cook': 11,
#   'love': 1,
#   'math': 0,
#   'scifi': 2},
#  'seriously': {'astronomy': 22,
#   'biology': 32,
#   'cook': 3,
#   'love': 54,
#   'math': 1,
#   'scifi': 25},
#  'asked': {'astronomy': 52,
#   'biology': 70,
#   'cook': 19,
#   'love': 241,
#   'math': 15,
#   'scifi': 352},
#  'confess': {'astronomy': 18,
#   'biology': 7,
#   'cook': 1,
#   'love': 44,
#   'math': 0,
#   'scifi': 45},
#  'mystery': {'astronomy': 58,
#   'biology': 21,
#   'cook': 6,
#   'love': 17,
#   'math': 1,
#   'scifi': 57},
#  'pondering': {'astronomy': 4,
#   'biology': 0,
#   'cook': 1,
#   'love': 3,
#   'math': 0,
#   'scifi': 2},
#  'deeply': {'astronomy': 29,
#   'biology': 53,
#   'cook': 54,
#   'love': 38,
#   'math': 1,
#   'scifi': 52},
#  'struck': {'astronomy': 51,
#   'biology': 74,
#   'cook': 4,
#   'love': 96,
#   'math': 1,
#   'scifi': 169},
#  'sudden': {'astronomy': 75,
#   'biology': 61,
#   'cook': 10,
#   'love': 91,
#   'math': 1,
#   'scifi': 135},
#  'added': {'astronomy': 110,
#   'biology': 146,
#   'cook': 200,
#   'love': 204,
#   'math': 322,
#   'scifi': 156},
#  'wonder': {'astronomy': 63,
#   'biology': 63,
#   'cook': 10,
#   'love': 174,
#   'math': 1,
#   'scifi': 132},
#  'trying': {'astronomy': 30,
#   'biology': 40,
#   'cook': 18,
#   'love': 118,
#   'math': 0,
#   'scifi': 51},
#  'saying': {'astronomy': 56,
#   'biology': 49,
#   'cook': 8,
#   'love': 166,
#   'math': 30,
#   'scifi': 72},
#  'attached': {'astronomy': 66,
#   'biology': 147,
#   'cook': 101,
#   'love': 75,
#   'math': 7,
#   'scifi': 63},
#  'employed': {'astronomy': 116,
#   'biology': 79,
#   'cook': 9,
#   'love': 29,
#   'math': 15,
#   'scifi': 33},
#  'nebulæ': {'astronomy': 142,
#   'biology': 1,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 4},
#  'renewed': {'astronomy': 25,
#   'biology': 12,
#   'cook': 0,
#   'love': 21,
#   'math': 3,
#   'scifi': 44},
#  'thats': {'astronomy': 0,
#   'biology': 4,
#   'cook': 5,
#   'love': 131,
#   'math': 0,
#   'scifi': 59},
#  'most': {'astronomy': 1608,
#   'biology': 1896,
#   'cook': 484,
#   'love': 855,
#   'math': 117,
#   'scifi': 746},
#  'remarkable': {'astronomy': 347,
#   'biology': 326,
#   'cook': 51,
#   'love': 20,
#   'math': 11,
#   'scifi': 88},
#  'thing': {'astronomy': 181,
#   'biology': 179,
#   'cook': 48,
#   'love': 612,
#   'math': 39,
#   'scifi': 374},
#  'professional': {'astronomy': 14,
#   'biology': 9,
#   'cook': 1,
#   'love': 11,
#   'math': 0,
#   'scifi': 7},
#  'resigning': {'astronomy': 0,
#   'biology': 0,
#   'cook': 0,
#   'love': 3,
#   'math': 0,
#   'scifi': 1},
#  'instrument': {'astronomy': 167,
#   'biology': 30,
#   'cook': 6,
#   'love': 36,
#   'math': 5,
#   'scifi': 45},
#  'demanded': {'astronomy': 18,
#   'biology': 15,
#   'cook': 1,
#   'love': 17,
#   'math': 0,
#   'scifi': 26},
#  'looking': {'astronomy': 74,
#   'biology': 101,
#   'cook': 25,
#   'love': 239,
#   'math': 5,
#   'scifi': 155},
#  'where': {'astronomy': 870,
#   'biology': 1229,
#   'cook': 357,
#   'love': 488,
#   'math': 505,
#   'scifi': 927},
#  'distinguish': {'astronomy': 44,
#   'biology': 96,
#   'cook': 39,
#   'love': 14,
#   'math': 10,
#   'scifi': 43},
#  'faint': {'astronomy': 88,
#   'biology': 28,
#   'cook': 13,
#   'love': 57,
#   'math': 0,
#   'scifi': 93},
#  'coloured': {'astronomy': 28,
#   'biology': 364,
#   'cook': 15,
#   'love': 13,
#   'math': 10,
#   'scifi': 9},
#  'darker': {'astronomy': 19,
#   'biology': 57,
#   'cook': 132,
#   'love': 6,
#   'math': 0,
#   'scifi': 10},
#  'background': {'astronomy': 18,
#   'biology': 4,
#   'cook': 2,
#   'love': 16,
#   'math': 2,
#   'scifi': 18},
#  'tell': {'astronomy': 92,
#   'biology': 67,
#   'cook': 22,
#   'love': 381,
#   'math': 4,
#   'scifi': 232},
#  'substance': {'astronomy': 79,
#   'biology': 244,
#   'cook': 127,
#   'love': 17,
#   'math': 9,
#   'scifi': 34},
#  'burning': {'astronomy': 80,
#   'biology': 18,
#   'cook': 33,
#   'love': 15,
#   'math': 0,
#   'scifi': 98},
#  'splitting': {'astronomy': 5,
#   'biology': 5,
#   'cook': 26,
#   'love': 0,
#   'math': 0,
#   'scifi': 2},
#  'comes': {'astronomy': 141,
#   'biology': 223,
#   'cook': 62,
#   'love': 86,
#   'math': 10,
#   'scifi': 69},
#  'prism': {'astronomy': 38,
#   'biology': 10,
#   'cook': 0,
#   'love': 0,
#   'math': 5,
#   'scifi': 3},
#  'lines': {'astronomy': 353,
#   'biology': 222,
#   'cook': 553,
#   'love': 56,
#   'math': 825,
#   'scifi': 152},
#  'different': {'astronomy': 695,
#   'biology': 1105,
#   'cook': 155,
#   'love': 171,
#   'math': 182,
#   'scifi': 255},
#  'colours': {'astronomy': 43,
#   'biology': 569,
#   'cook': 3,
#   'love': 3,
#   'math': 0,
#   'scifi': 36},
#  'spectrum': {'astronomy': 148,
#   'biology': 8,
#   'cook': 0,
#   'love': 0,
#   'math': 2,
#   'scifi': 8},
#  'gas': {'astronomy': 99,
#   'biology': 61,
#   'cook': 32,
#   'love': 4,
#   'math': 14,
#   'scifi': 45},
#  'origin': {'astronomy': 222,
#   'biology': 417,
#   'cook': 18,
#   'love': 11,
#   'math': 287,
#   'scifi': 32},
#  'blaze': {'astronomy': 15,
#   'biology': 0,
#   'cook': 2,
#   'love': 2,
#   'math': 0,
#   'scifi': 12},
#  'electricalfor': {'astronomy': 0,
#   'biology': 0,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 1},
#  'instance': {'astronomy': 278,
#   'biology': 461,
#   'cook': 23,
#   'love': 36,
#   'math': 54,
#   'scifi': 53},
#  'volcanic': {'astronomy': 184,
#   'biology': 55,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 33},
#  'eruption': {'astronomy': 90,
#   'biology': 5,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 19},
#  'lake': {'astronomy': 125,
#   'biology': 192,
#   'cook': 15,
#   'love': 24,
#   'math': 1,
#   'scifi': 102},
#  'fire': {'astronomy': 207,
#   'biology': 67,
#   'cook': 398,
#   'love': 94,
#   'math': 2,
#   'scifi': 221},
#  'kilauea': {'astronomy': 2,
#   'biology': 0,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 1},
#  'identify': {'astronomy': 27,
#   'biology': 22,
#   'cook': 15,
#   'love': 8,
#   'math': 3,
#   'scifi': 17},
#  'scarcely': {'astronomy': 125,
#   'biology': 180,
#   'cook': 110,
#   'love': 135,
#   'math': 1,
#   'scifi': 183},
#  'ere': {'astronomy': 15,
#   'biology': 13,
#   'cook': 9,
#   'love': 7,
#   'math': 3,
#   'scifi': 78},
#  'cried': {'astronomy': 5,
#   'biology': 7,
#   'cook': 4,
#   'love': 308,
#   'math': 0,
#   'scifi': 498},
#  'wonderful': {'astronomy': 117,
#   'biology': 122,
#   'cook': 3,
#   'love': 61,
#   'math': 0,
#   'scifi': 95},
#  'changed': {'astronomy': 95,
#   'biology': 197,
#   'cook': 29,
#   'love': 60,
#   'math': 32,
#   'scifi': 113},
#  'eureka': {'astronomy': 0,
#   'biology': 0,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 1},
#  'thallium': {'astronomy': 0,
#   'biology': 0,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 2},
#  'green': {'astronomy': 95,
#   'biology': 352,
#   'cook': 430,
#   'love': 40,
#   'math': 3,
#   'scifi': 300},
#  'line': {'astronomy': 416,
#   'biology': 361,
#   'cook': 183,
#   'love': 89,
#   'math': 1359,
#   'scifi': 263},
#  'thousand': {'astronomy': 274,
#   'biology': 174,
#   'cook': 24,
#   'love': 89,
#   'math': 7,
#   'scifi': 359},
#  'astonished': {'astronomy': 23,
#   'biology': 19,
#   'cook': 1,
#   'love': 45,
#   'math': 0,
#   'scifi': 44},
#  'turn': {'astronomy': 140,
#   'biology': 135,
#   'cook': 266,
#   'love': 121,
#   'math': 20,
#   'scifi': 153},
#  'hurriedly': {'astronomy': 1,
#   'biology': 0,
#   'cook': 2,
#   'love': 9,
#   'math': 0,
#   'scifi': 14},
#  'note': {'astronomy': 128,
#   'biology': 183,
#   'cook': 33,
#   'love': 77,
#   'math': 26,
#   'scifi': 85},
#  'also': {'astronomy': 1148,
#   'biology': 1579,
#   'cook': 411,
#   'love': 132,
#   'math': 615,
#   'scifi': 395},
#  'book': {'astronomy': 317,
#   'biology': 108,
#   'cook': 129,
#   'love': 80,
#   'math': 67,
#   'scifi': 77},
#  'purpose': {'astronomy': 176,
#   'biology': 248,
#   'cook': 93,
#   'love': 102,
#   'math': 33,
#   'scifi': 140},
#  'lying': {'astronomy': 48,
#   'biology': 102,
#   'cook': 19,
#   'love': 5,
#   'math': 7,
#   'scifi': 80},
#  'further': {'astronomy': 300,
#   'biology': 422,
#   'cook': 42,
#   'love': 50,
#   'math': 56,
#   'scifi': 245},
#  'orders': {'astronomy': 35,
#   'biology': 176,
#   'cook': 8,
#   'love': 37,
#   'math': 8,
#   'scifi': 65},
#  'plainly': {'astronomy': 34,
#   'biology': 58,
#   'cook': 9,
#   'love': 16,
#   'math': 18,
#   'scifi': 36},
#  'hear': {'astronomy': 69,
#   'biology': 137,
#   'cook': 21,
#   'love': 329,
#   'math': 0,
#   'scifi': 186},
#  'ticking': {'astronomy': 0,
#   'biology': 7,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 2},
#  'watch': {'astronomy': 49,
#   'biology': 80,
#   'cook': 17,
#   'love': 51,
#   'math': 0,
#   'scifi': 124},
#  'laid': {'astronomy': 96,
#   'biology': 116,
#   'cook': 21,
#   'love': 52,
#   'math': 7,
#   'scifi': 108},
#  'end': {'astronomy': 364,
#   'biology': 446,
#   'cook': 179,
#   'love': 219,
#   'math': 71,
#   'scifi': 424},
#  'sodium': {'astronomy': 39,
#   'biology': 42,
#   'cook': 4,
#   'love': 0,
#   'math': 2,
#   'scifi': 3},
#  'yellow': {'astronomy': 68,
#   'biology': 257,
#   'cook': 675,
#   'love': 39,
#   'math': 2,
#   'scifi': 80},
#  'bands': {'astronomy': 56,
#   'biology': 33,
#   'cook': 6,
#   'love': 3,
#   'math': 0,
#   'scifi': 21},
#  'unmistakable': {'astronomy': 9,
#   'biology': 17,
#   'cook': 4,
#   'love': 0,
#   'math': 0,
#   'scifi': 7},
#  'stillness': {'astronomy': 4,
#   'biology': 7,
#   'cook': 0,
#   'love': 4,
#   'math': 0,
#   'scifi': 34},
#  'reigned': {'astronomy': 11,
#   'biology': 1,
#   'cook': 3,
#   'love': 1,
#   'math': 0,
#   'scifi': 23},
#  'she': {'astronomy': 416,
#   'biology': 423,
#   'cook': 169,
#   'love': 8245,
#   'math': 49,
#   'scifi': 3052},
#  'goes': {'astronomy': 74,
#   'biology': 125,
#   'cook': 28,
#   'love': 54,
#   'math': 5,
#   'scifi': 30},
#  'excited': {'astronomy': 49,
#   'biology': 68,
#   'cook': 1,
#   'love': 26,
#   'math': 0,
#   'scifi': 92},
#  'couple': {'astronomy': 15,
#   'biology': 20,
#   'cook': 18,
#   'love': 55,
#   'math': 0,
#   'scifi': 42},
#  'indium': {'astronomy': 0,
#   'biology': 0,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 1},
#  'ensued': {'astronomy': 5,
#   'biology': 3,
#   'cook': 0,
#   'love': 4,
#   'math': 0,
#   'scifi': 12},
#  'gone': {'astronomy': 75,
#   'biology': 159,
#   'cook': 14,
#   'love': 322,
#   'math': 0,
#   'scifi': 259},
#  'once': {'astronomy': 457,
#   'biology': 555,
#   'cook': 226,
#   'love': 321,
#   'math': 90,
#   'scifi': 584},
#  'taken': {'astronomy': 322,
#   'biology': 418,
#   'cook': 119,
#   'love': 210,
#   'math': 264,
#   'scifi': 274},
#  'lithium': {'astronomy': 4,
#   'biology': 0,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 2},
#  'hey': {'astronomy': 0,
#   'biology': 0,
#   'cook': 0,
#   'love': 2,
#   'math': 2,
#   'scifi': 1},
#  'prestoand': {'astronomy': 0,
#   'biology': 0,
#   'cook': 0,
#   'love': 0,
#   'math': 0,
#   'scifi': 1},
#  'whats': {'astronomy': 0,
#   'biology': 0,
#   'cook': 3,
#   'love': 35,
#   'math': 0,
#   'scifi': 27},
#  'matter': {'astronomy': 454,
#   'biology': 657,
#   'cook': 93,
#   'love': 163,
#   'math': 41,
#   'scifi': 374},
#  'words': {'astronomy': 269,
#   'biology': 206,
#   'cook': 29,
#   'love': 197,
#   'math': 69,
#   'scifi': 392},
#  'removed': {'astronomy': 116,
#   'biology': 111,
#   'cook': 116,
#   'love': 55,
#   'math': 3,
#   'scifi': 83},
#  'gazed': {'astronomy': 1,
#   'biology': 3,
#   'cook': 2,
#   'love': 4,
#   'math': 0,
#   'scifi': 83},
#  'anxiously': {'astronomy': 6,
#   'biology': 1,
#   'cook': 1,
#   'love': 13,
#   'math': 0,
#   'scifi': 20},
#  'continued': {'astronomy': 104,
#   'biology': 156,
#   'cook': 31,
#   'love': 235,
#   'math': 7,
#   'scifi': 261},
#  ...}

# %%
print(clase_pred)
# Out:
# ('math', [-64.01658229151884, -65.45760138576652, -52.13111845030627, -60.098117007459976, -60.35521506762848, -65.00624834656617])

# %% [markdown]
# ## Predicciones

# %%
libros_test
# Out:
# {'astronomy': [8, 9, 14, 6],
#  'biology': [14, 9, 7, 4],
#  'cook': [15, 5, 1, 4],
#  'love': [3, 6],
#  'math': [7, 4],
#  'scifi': [5, 14, 9]}

# %% [markdown]
# ### Predicción de una sola clase del conjunto de prueba

# %%
predicciones = []
clase ='cook'
for i in libros_test[clase]:
    archivo_txt = todos_los_libros[clase][i-1]
    libro_prueba = open(archivo_txt).read().split()
    clase_pred,lv = clasifica(libro_prueba, frecuencias, frecuencas_clases, clases)
    predicciones.append((clase, clase_pred))
    print(archivo_txt,"\t",clase, clase_pred, max(lv))
# Out:
# books/cook15.txt 	 cook cook -1518898.995940336
# books/cook5.txt 	 cook cook -90135.59417074463
# books/cook1.txt 	 cook cook -226433.52709767333
# books/cook4.txt 	 cook cook -411598.76262885705

# %% [markdown]
# ### Predicción con el conjunto de prueba total

# %%
predicciones = []
for clase in clases:
    for i in libros_test[clase]:
        archivo_txt = todos_los_libros[clase][i-1]
        libro_prueba = open(archivo_txt).read().split()
        clase_pred,lv = clasifica(libro_prueba, frecuencias, frecuencas_clases, clases)
        predicciones.append((clase, clase_pred))
        print(archivo_txt,"\t",clase, clase_pred, max(lv))
# Out:
# books/scifi5.txt 	 scifi scifi -679710.8783578923
# books/scifi14.txt 	 scifi scifi -679872.2727311624
# books/scifi9.txt 	 scifi scifi -245092.78916056195
# books/love3.txt 	 love love -816604.4531492734
# books/love6.txt 	 love love -577709.8707934468
# books/math7.txt 	 math math -1025115.2625764803
# books/math4.txt 	 math math -344699.2802793393
# books/biology14.txt 	 biology biology -1314832.8301602185
# books/biology9.txt 	 biology biology -1084579.0949648353
# books/biology7.txt 	 biology biology -688104.3427273345
# books/biology4.txt 	 biology biology -444444.2243203145
# books/astronomy8.txt 	 astronomy astronomy -750421.3085850711
# books/astronomy9.txt 	 astronomy astronomy -614177.874480448
# books/astronomy14.txt 	 astronomy astronomy -815908.1568948702
# books/astronomy6.txt 	 astronomy astronomy -185593.69778855477
# books/cook15.txt 	 cook cook -1518898.995940336
# books/cook5.txt 	 cook cook -90135.59417074463
# books/cook1.txt 	 cook cook -226433.52709767333
# books/cook4.txt 	 cook cook -411598.76262885705

# %%
porcentaje_clasificación = sum( [ p[0] == p[1] for p in predicciones] ) / len(predicciones)
print("porcentaje_clasificación =", porcentaje_clasificación, "=", '{:f}'.format(porcentaje_clasificación*100),"%")
# Out:
# porcentaje_clasificación = 1.0 = 100.000000 %

# %% [markdown]
# ### Matriz de Confusión

# %%
matriz_confusion = [[ 0 for c in clases] for c in clases]

for cc in predicciones:
    real, prediccion = cc
    j = clases.index(prediccion)
    i = clases.index(real)
    matriz_confusion[i][j] += 1
    
print("Matriz de confusion")
for i in range(len(matriz_confusion)):
    clase = clases[i]
    print(clase[:4], matriz_confusion[i])
print("porcentaje_clasificación =", porcentaje_clasificación, "=", '{:f}'.format(porcentaje_clasificación*100),"%")
# Out:
# Matriz de confusion
# scif [3, 0, 0, 0, 0, 0]
# love [0, 2, 0, 0, 0, 0]
# math [0, 0, 2, 0, 0, 0]
# biol [0, 0, 0, 4, 0, 0]
# astr [0, 0, 0, 0, 4, 0]
# cook [0, 0, 0, 0, 0, 4]
# porcentaje_clasificación = 1.0 = 100.000000 %
